# %% [markdown]
# ## Using BeautifulSoup/Selenium to Scrape BaseballSavant

# %% [markdown]
# First, importing needed packages:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 20,10
import numpy as np
import glob
from scipy import stats
from bs4 import BeautifulSoup
import requests
import re
from IPython.core.display import display, HTML    # make sure Jupyter knows to display it as HTML

# %% [markdown]
# Importing selenium and setting chrome driver:

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
#Data from 2015-2020, players with at least 200 PA in that given season:
savant_url = 'https://baseballsavant.mlb.com/leaderboard/custom?year=2020,2019,2018,2017,2016,2015&type=batter&filter=&sort=16&sortDir=desc&min=200&selections=player_age,b_total_pa,b_game,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,solidcontact_percent,hard_hit_percent,z_swing_percent,oz_swing_percent,pull_percent,straightaway_percent,opposite_percent,groundballs_percent,flyballs_percent,linedrives_percent,sprint_speed,&chart=true&x=player_age&y=player_age&r=no&chartType=beeswarm'

# %% [markdown]
# If using wOBA, insert this link above:
# https://baseballsavant.mlb.com/leaderboard/custom?year=2020,2019,2018,2017,2016,2015&type=batter&filter=&sort=16&sortDir=desc&min=200&selections=player_age,b_total_pa,b_game,woba,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,solidcontact_percent,hard_hit_percent,z_swing_percent,oz_swing_percent,pull_percent,straightaway_percent,opposite_percent,groundballs_percent,flyballs_percent,linedrives_percent,sprint_speed,&chart=true&x=player_age&y=player_age&r=no&chartType=beeswarm

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(savant_url)

# %%
driver.page_source[:1000]
# Out:
# '<html lang="en_US" class=" device-desktop"><head>\n    <title>Statcast Custom Leaderboards | baseballsavant.com </title>\n\n    <!-- meta meta tag -->\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge">\n    <meta http-equiv="Cache-Control" content="no-cache">\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="Expires" content="-1">\n    <meta name="keywords" content="Baseball Savant">\n    <!-- -->\n    <meta property="og:title" content="Statcast Custom Leaderboards">\n    <meta itemprop="name" content="Statcast Custom Leaderboards baseballsavant.com">\n    \n    <meta property="og:site_name" content="baseballsavant.com">\n    <meta property="og:type" content="website">\n    \n    <meta property="og:image" content="https://baseballsavant.mlb.com/site-core/images/statcast-logo-gcp-social.png">\n    <meta itemprop="image" content="https://baseballsavant.mlb.com/site-core/images/statcast-logo-gcp-social.png">\n     <meta name="twitter:card" content='

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
headers = soup.find('div', id='sortable_stats').find_all('th')

# %% [markdown]
# Finding Table Rows:

# %%
columns = [col.get_text() for col in headers]

# %%
print(columns)
# Out:
# ['Rk.', 'Player', 'Year', 'Age', 'PA', 'G', 'Avg EV (MPH)', 'Avg LA (°)', 'Barrel%', 'Solid Contact %', 'Hard Hit %', 'Zone Swing %', 'Out of Zone Swing %', 'Pull %', 'Straight Away %', 'Oppo %', 'GB%', 'FB%', 'LD %', 'Sprint Speed']

# %%
savant_df = pd.DataFrame(columns=columns)
savant_df.head()
# Out:
# Empty DataFrame
# Columns: [Rk., Player, Year, Age, PA, G, Avg EV (MPH), Avg LA (°), Barrel%, Solid Contact %, Hard Hit %, Zone Swing %, Out of Zone Swing %, Pull %, Straight Away %, Oppo %, GB%, FB%, LD %, Sprint Speed]
# Index: []

# %% [markdown]
# Finding Stats:

# %%
stats_test = soup.find('div', id='sortable_stats').find_all('tr')

# %%
stats = [col.get_text() for col in stats_test]

# %%
stat_lines = soup.find('div', id='sortable_stats').find_all('tr')
compiled_stats = []
for line_item in stat_lines:
    ind_stat_line = [item.get_text() for item in line_item.find_all('td')]
    compiled_stats.append(ind_stat_line)
    final_stats = compiled_stats[1:]

# %% [markdown]
# Pulling links to player pages:

# %%
player_links = soup.find('div', id='sortable_stats').find_all('tr')
compiled_links = []
for line_item in player_links:
    ind_link = [item.get("href") for item in line_item.find_all('a')]
    compiled_links.append(ind_link)
    final_link = compiled_links[1:]

# %%
print(final_link)
# Out:
# [['/savant-player/457454'], ['/savant-player/572114'], ['/savant-player/608336'], ['/savant-player/572761'], ['/savant-player/572761'], ['/savant-player/457803'], ['/savant-player/608336'], ['/savant-player/519346'], ['/savant-player/656555'], ['/savant-player/624415'], ['/savant-player/608336'], ['/savant-player/595885'], ['/savant-player/435063'], ['/savant-player/545361'], ['/savant-player/572122'], ['/savant-player/641598'], ['/savant-player/519346'], ['/savant-player/519390'], ['/savant-player/457803'], ['/savant-player/545350'], ['/savant-player/474832'], ['/savant-player/455139'], ['/savant-player/572761'], ['/savant-player/592206'], ['/savant-player/545361'], ['/savant-player/594807'], ['/savant-player/448801'], ['/savant-player/656555'], ['/savant-player/593934'], ['/savant-player/474892'], ['/savant-player/594807'], ['/savant-player/455139'], ['/savant-player/457759'], ['/savant-player/572761'], ['/savant-player/472528'], ['/savant-player/446263'], ['/savant-player/656555'], ['/savant-player/458675'], ['/savant-player/572122'], ['/savant-player/500871'], ['/savant-player/474832'], ['/savant-player/474892'], ['/savant-player/571970'], ['/savant-player/663586'], ['/savant-player/543768'], ['/savant-player/545361'], ['/savant-player/593934'], ['/savant-player/592450'], ['/savant-player/518692'], ['/savant-player/461235'], ['/savant-player/434158'], ['/savant-player/458675'], ['/savant-player/458015'], ['/savant-player/472528'], ['/savant-player/457803'], ['/savant-player/592669'], ['/savant-player/608596'], ['/savant-player/501981'], ['/savant-player/621514'], ['/savant-player/596142'], ['/savant-player/572122'], ['/savant-player/666560'], ['/savant-player/461235'], ['/savant-player/518614'], ['/savant-player/593934'], ['/savant-player/571431'], ['/savant-player/474832'], ['/savant-player/429667'], ['/savant-player/543685'], ['/savant-player/594828'], ['/savant-player/645277'], ['/savant-player/606192'], ['/savant-player/502110'], ['/savant-player/650402'], ['/savant-player/572122'], ['/savant-player/571974'], ['/savant-player/656305'], ['/savant-player/592206'], ['/savant-player/542583'], ['/savant-player/493316'], ['/savant-player/444379'], ['/savant-player/502110'], ['/savant-player/592200'], ['/savant-player/553993'], ['/savant-player/605141'], ['/savant-player/664040'], ['/savant-player/656371'], ['/savant-player/457477'], ['/savant-player/425784'], ['/savant-player/606157'], ['/savant-player/571875'], ['/savant-player/545350'], ['/savant-player/592178'], ['/savant-player/474892'], ['/savant-player/608070'], ['/savant-player/571602'], ['/savant-player/571745'], ['/savant-player/488771'], ['/savant-player/429665'], ['/savant-player/572287'], ['/savant-player/621566'], ['/savant-player/640449'], ['/savant-player/592178'], ['/savant-player/572816'], ['/savant-player/543510'], ['/savant-player/519390'], ['/savant-player/606192'], ['/savant-player/572073'], ['/savant-player/521692'], ['/savant-player/656941'], ['/savant-player/489138'], ['/savant-player/670541'], ['/savant-player/572821'], ['/savant-player/489267'], ['/savant-player/446334'], ['/savant-player/521692'], ['/savant-player/471083'], ['/savant-player/446263'], ['/savant-player/624424'], ['/savant-player/553993'], ['/savant-player/424325'], ['/savant-player/502082'], ['/savant-player/643393'], ['/savant-player/605141'], ['/savant-player/434158'], ['/savant-player/596115'], ['/savant-player/592178'], ['/savant-player/434158'], ['/savant-player/641355'], ['/savant-player/475253'], ['/savant-player/476704'], ['/savant-player/475253'], ['/savant-player/553993'], ['/savant-player/489149'], ['/savant-player/621566'], ['/savant-player/543228'], ['/savant-player/448801'], ['/savant-player/592122'], ['/savant-player/434778'], ['/savant-player/624415'], ['/savant-player/476704'], ['/savant-player/461235'], ['/savant-player/543768'], ['/savant-player/543685'], ['/savant-player/458015'], ['/savant-player/435263'], ['/savant-player/446263'], ['/savant-player/429665'], ['/ ...

# %% [markdown]
# Building DataFrame:

# %%
savant_df = pd.DataFrame(final_stats, columns=columns)
num_cols = ['Age','G','PA','Year','Avg EV (MPH)','Avg LA (°)','Barrel%','Solid Contact %','Hard Hit %','Zone Swing %','Out of Zone Swing %','Pull %','Straight Away %','Oppo %','GB%','FB%','LD %','Sprint Speed']
savant_df[num_cols] = savant_df[num_cols].apply(pd.to_numeric, errors='coerce', axis=1)
savant_df.set_index(savant_df['Rk.'], inplace=True)
savant_df.drop(columns='Rk.',inplace=True)
savant_df['Player Link'] = final_link
savant_df.head()
# Out:
#                       Player    Year   Age     PA      G  Avg EV (MPH)  \
# Rk.
# 1     Saltalamacchia, Jarrod  2016.0  31.0  292.0   92.0          89.2
# 2              Schimpf, Ryan  2016.0  28.0  330.0   89.0          90.3
# 3                Gallo, Joey  2017.0  24.0  532.0  145.0          93.3
# 4            Carpenter, Matt  2018.0  33.0  677.0  156.0          90.7
# 5            Carpenter, Matt  2017.0  32.0  622.0  145.0          89.9
#
#      Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  Zone Swing %  \
# Rk.
# 1          21.4     11.6              6.8        35.4          65.7
# 2          29.7     16.7              8.0        41.4          64.7
# 3          23.0     22.1              8.3        52.2          72.7
# 4          21.6     13.7             11.5        44.7          57.1
# 5          22.7      8.2              8.4        37.7          55.1
#
#      Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# Rk.
# 1                   23.9    44.2             34.0    21.8  31.3  43.5  19.7
# 2                   23.4    41.4             33.9    24.7  20.1  42.0  21.8
# 3                   28.2    50.2             29.2    20.6  29.2  37.9  22.1
# 4                   18.5    47.6             30.7    21.7  28.3  37.8  28.5
# 5                   14.0    45.9             31.4    22.7  29.0  37.7  26.6
#
#      Sprint Speed              Player Link
# Rk.
# 1            25.6  [/savant-player/457454]
# 2            28.2  [/savant-player/572114]
# 3            27.8  [/savant-player/608336]
# 4            26.5  [/savant-player/572761]
# 5            26.6  [/savant-player/572761]

# %%
savant_df.Player.value_counts()
# Out:
#  Cabrera, Asdrubal    6
#  Cruz, Nelson         6
#  Lindor, Francisco    6
#  Franco, Maikel       6
#  Blackmon, Charlie    6
#                      ..
#  Van Slyke, Scott     1
#  Herrera, Elian       1
#  Bandy, Jett          1
#  Collins, Tyler       1
#  Field, Johnny        1
# Name: Player, Length: 646, dtype: int64

# %%
savant_df
# Out:
#                        Player    Year   Age     PA      G  Avg EV (MPH)  \
# Rk.
# 1      Saltalamacchia, Jarrod  2016.0  31.0  292.0   92.0          89.2
# 2               Schimpf, Ryan  2016.0  28.0  330.0   89.0          90.3
# 3                 Gallo, Joey  2017.0  24.0  532.0  145.0          93.3
# 4             Carpenter, Matt  2018.0  33.0  677.0  156.0          90.7
# 5             Carpenter, Matt  2017.0  32.0  622.0  145.0          89.9
# ...                       ...     ...   ...    ...    ...           ...
# 1889        Jankowski, Travis  2016.0  25.0  383.0  131.0          86.2
# 1890             LeMahieu, DJ  2016.0  28.0  635.0  146.0          91.7
# 1891        Jankowski, Travis  2018.0  27.0  387.0  117.0          85.6
# 1892           Slater, Austin  2018.0  26.0  225.0   74.0          87.3
# 1893        Yelich, Christian  2015.0  24.0  525.0  126.0          91.7
#
#       Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  Zone Swing %  \
# Rk.
# 1           21.4     11.6              6.8        35.4          65.7
# 2           29.7     16.7              8.0        41.4          64.7
# 3           23.0     22.1              8.3        52.2          72.7
# 4           21.6     13.7             11.5        44.7          57.1
# 5           22.7      8.2              8.4        37.7          55.1
# ...          ...      ...              ...         ...           ...
# 1889         0.8      1.3              1.3        26.9          56.9
# 1890         5.9      4.9              5.6        47.5          59.2
# 1891         3.3      0.7              1.1        19.3          59.2
# 1892         2.6      2.3              0.8        35.1          65.9
# 1893         0.0      4.8              5.6        45.1          63.7
#
#       Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# Rk.
# 1                    23.9    44.2             34.0    21.8  31.3  43.5  19.7
# 2                    23.4    41.4             33.9    24.7  20.1  42.0  21.8
# 3                    28.2    50.2             29.2    20.6  29.2  37.9  22.1
# 4                    18.5    47.6             30.7    21.7  28.3  37.8  28.5
# 5                    14.0    45.9             31.4    22.7  29.0  37.7  26.6
# ...                   ...     ...              ...     ...   ...   ...   ...
# 1889                 21.4    20.2             43.3    36.6  62.2  10.1  26.5
# 1890                 23.0    20.8             42.0    37.2  52.9  10.1  33.7
# 1891                 18.7    30.1             39.9    30.1  60.1  10.1  25.4
# 1892                 28.0    23.7             36.6    39.7  63.4   9.2  22.9
# 1893                 24.5    26.7             46.4    26.9  63.7   8.5  27.5
#
#       Sprint Speed              Player Link
# Rk.
# 1             25.6  [/savant-player/457454]
# 2             28.2  [/savant-player/572114]
# 3             27.8  [/savant-player/608336]
# 4             26.5  [/savant-player/572761]
# 5             26.6  [/savant-player/572761]
# ...            ...                      ...
# 1889          29.5  [/savant-player/608671]
# 1890          27.1  [/savant-player/518934]
# 1891          29.0  [/savant-player/608671]
# 1892          28.0  [/savant-player/596103]
# 1893          28.8  [/savant-player/592885]
#
# [1893 rows x 20 columns]

# %% [markdown]
# Driver's work here is done.

# %%
driver.close()

# %% [markdown]
# ### Use player links to pull position data from their individual BS page:

# %% [markdown]
# First, make a list of all the links to feed into a soup generator:

# %%
link_list = savant_df['Player Link'].to_list()

# %%
from collections import defaultdict

# %%
savant_page_list = [('https://baseballsavant.mlb.com' + str(link).strip("'[]")) for link in link_list]

# %%
print(savant_page_list)
# Out:
# ['https://baseballsavant.mlb.com/savant-player/457454', 'https://baseballsavant.mlb.com/savant-player/572114', 'https://baseballsavant.mlb.com/savant-player/608336', 'https://baseballsavant.mlb.com/savant-player/572761', 'https://baseballsavant.mlb.com/savant-player/572761', 'https://baseballsavant.mlb.com/savant-player/457803', 'https://baseballsavant.mlb.com/savant-player/608336', 'https://baseballsavant.mlb.com/savant-player/519346', 'https://baseballsavant.mlb.com/savant-player/656555', 'https://baseballsavant.mlb.com/savant-player/624415', 'https://baseballsavant.mlb.com/savant-player/608336', 'https://baseballsavant.mlb.com/savant-player/595885', 'https://baseballsavant.mlb.com/savant-player/435063', 'https://baseballsavant.mlb.com/savant-player/545361', 'https://baseballsavant.mlb.com/savant-player/572122', 'https://baseballsavant.mlb.com/savant-player/641598', 'https://baseballsavant.mlb.com/savant-player/519346', 'https://baseballsavant.mlb.com/savant-player/519390', 'https://baseballsavant.mlb.com/savant-player/457803', 'https://baseballsavant.mlb.com/savant-player/545350', 'https://baseballsavant.mlb.com/savant-player/474832', 'https://baseballsavant.mlb.com/savant-player/455139', 'https://baseballsavant.mlb.com/savant-player/572761', 'https://baseballsavant.mlb.com/savant-player/592206', 'https://baseballsavant.mlb.com/savant-player/545361', 'https://baseballsavant.mlb.com/savant-player/594807', 'https://baseballsavant.mlb.com/savant-player/448801', 'https://baseballsavant.mlb.com/savant-player/656555', 'https://baseballsavant.mlb.com/savant-player/593934', 'https://baseballsavant.mlb.com/savant-player/474892', 'https://baseballsavant.mlb.com/savant-player/594807', 'https://baseballsavant.mlb.com/savant-player/455139', 'https://baseballsavant.mlb.com/savant-player/457759', 'https://baseballsavant.mlb.com/savant-player/572761', 'https://baseballsavant.mlb.com/savant-player/472528', 'https://baseballsavant.mlb.com/savant-player/446263', 'https://baseballsavant.mlb.com/savant-player/656555', 'https://baseballsavant.mlb.com/savant-player/458675', 'https://baseballsavant.mlb.com/savant-player/572122', 'https://baseballsavant.mlb.com/savant-player/500871', 'https://baseballsavant.mlb.com/savant-player/474832', 'https://baseballsavant.mlb.com/savant-player/474892', 'https://baseballsavant.mlb.com/savant-player/571970', 'https://baseballsavant.mlb.com/savant-player/663586', 'https://baseballsavant.mlb.com/savant-player/543768', 'https://baseballsavant.mlb.com/savant-player/545361', 'https://baseballsavant.mlb.com/savant-player/593934', 'https://baseballsavant.mlb.com/savant-player/592450', 'https://baseballsavant.mlb.com/savant-player/518692', 'https://baseballsavant.mlb.com/savant-player/461235', 'https://baseballsavant.mlb.com/savant-player/434158', 'https://baseballsavant.mlb.com/savant-player/458675', 'https://baseballsavant.mlb.com/savant-player/458015', 'https://baseballsavant.mlb.com/savant-player/472528', 'https://baseballsavant.mlb.com/savant-player/457803', 'https://baseballsavant.mlb.com/savant-player/592669', 'https://baseballsavant.mlb.com/savant-player/608596', 'https://baseballsavant.mlb.com/savant-player/501981', 'https://baseballsavant.mlb.com/savant-player/621514', 'https://baseballsavant.mlb.com/savant-player/596142', 'https://baseballsavant.mlb.com/savant-player/572122', 'https://baseballsavant.mlb.com/savant-player/666560', 'https://baseballsavant.mlb.com/savant-player/461235', 'https://baseballsavant.mlb.com/savant-player/518614', 'https://baseballsavant.mlb.com/savant-player/593934', 'https://baseballsavant.mlb.com/savant-player/571431', 'https://baseballsavant.mlb.com/savant-player/474832', 'https://baseballsavant.mlb.com/savant-player/429667', 'https://baseballsavant.mlb.com/savant-player/543685', 'https://baseballsavant.mlb.com/savant-player/594828', 'https://baseballsavant.mlb.com/savant-player/645277', 'https://baseballsavant.mlb.com/savant-player/606192', 'https://baseballsavant.mlb.com/savant- ...

# %% [markdown]
# Defining a Function to generate the soup objects:

# %%
def Soup_Generator(link_list):
    '''
    Takes in a list of players and returns Beautiful Soup objects.
    '''
    response_list = [requests.get(url) for url in link_list]
    soup_list = []
    for response in response_list:
        page = response.text
        soup_list.append(BeautifulSoup(page,'html'))
    return soup_list

# %% [markdown]
# Find Player Position Data:

# %%
position_list = []
for player in link_soup:
    position = player.find('div', style='font-size: .8rem;')
    position_list.append(str(position.text))

# %%
print(position_list)
# Out:
# ['\n                    C | B/T: S/R | 6\' 4" 235LBS | Age: 35\n                ', '\n                    3B | B/T: L/R | 5\' 9" 180LBS | Age: 32\n                ', '\n                    CF | B/T: L/R | 6\' 5" 250LBS | Age: 27\n                ', '\n                    3B | B/T: L/R | 6\' 4" 210LBS | Age: 35\n                ']

# %%
final_position = []
for position in position_list:
    position = position.strip("\n")
    position = position.strip(" ")
    final_position.append(position[0:2].strip(" "))
print(final_position)
# Out:
# ['C', '3B', 'CF', '3B']

# %% [markdown]
# Defining function for position generation:

# %%
def Position_Puller(soup_list):
    '''
    Takes in a list of Beautiful Soup Objects from BasebalL Savant
    and returns each player's position.
    '''
    position_list = []
    for player in soup_list:
        position = player.find('div', style='font-size: .8rem;')
        position_list.append(str(position.text))
    final_position = []
    for position in position_list:
        position = position.strip("\n")
        position = position.strip(" ")
        final_position.append(position[0:2].strip(" "))
    return final_position

# %%
link_soup = Soup_Generator(savant_page_list[0:20])

# %%
#Verify first 20:
Position_Puller(link_soup)
# Out:
# ['C',
#  '3B',
#  'CF',
#  '3B',
#  '3B',
#  'RF',
#  'CF',
#  '1B',
#  '1B',
#  '2B',
#  'CF',
#  '1B',
#  '1B',
#  'CF',
#  '3B',
#  'C',
#  '1B',
#  'C',
#  'RF',
#  'CF']

# %% [markdown]
# Creating a list of names that can feed into the BBREF code:

# %%
player_column = savant_df.Player

# %%
player_column.drop_duplicates(inplace=True)

# %%
player_list = player_column.tolist()

# %%
player_list_split = [player.split(', ') for player in player_list]
for player in player_list_split:
    player[0] = player[0].strip()

final_player_list = [(player[1] + ' ' + player[0]) for player in player_list_split]

# %%
final_player_list
# Out:
# ['Jarrod Saltalamacchia',
#  'Ryan Schimpf',
#  'Joey Gallo',
#  'Matt Carpenter',
#  'Jay Bruce',
#  'Eric Thames',
#  'Rhys Hoskins',
#  'Cavan Biggio',
#  'Greg Bird',
#  'Mike Napoli',
#  'Mike Trout',
#  'Kyle Seager',
#  'Mitch Garver',
#  'Stephen Vogt',
#  'Jake Marisnick',
#  'Brandon Belt',
#  'Robinson Chirinos',
#  'Nick Castellanos',
#  'Adam Duvall',
#  'Chris Davis',
#  'Miguel Sano',
#  'Chris Carter',
#  'Justin Turner',
#  'Luis Valbuena',
#  'Lucas Duda',
#  'Colby Rasmus',
#  'Eduardo Escobar',
#  'Max Muncy',
#  'Austin Riley',
#  'Travis Shaw',
#  'Aaron Judge',
#  'Freddie Freeman',
#  'Brandon Moss',
#  'Curtis Granderson',
#  'Joey Votto',
#  'Hunter Renfroe',
#  'Tom Murphy',
#  'Khris Davis',
#  'Christin Stewart',
#  'Gary Sanchez',
#  'ByungHo Park',
#  'Daniel Descalso',
#  'Matt Adams',
#  'Ryan Howard',
#  'Anthony Rendon',
#  'Evan Gattis',
#  'Ozzie Albies',
#  'Teoscar Hernandez',
#  'J.D. Martinez',
#  'Gleyber Torres',
#  'John Ryan Murphy',
#  'Matt Chapman',
#  'Jesus Aguilar',
#  'Yoenis Cespedes',
#  'John Jaso',
#  'Curt Casali',
#  'Eugenio Suarez',
#  'Mookie Betts',
#  'Brandon Lowe',
#  'Isan Diaz',
#  'Alejandro De Aza',
#  'Rene Rivera',
#  'Aristides Aquino',
#  'Jake Lamb',
#  'Kris Bryant',
#  'Jose Ramirez',
#  'Matt Davidson',
#  'Mitch Haniger',
#  'Jason Castro',
#  'Edwin Encarnacion',
#  'Mike Zunino',
#  'Matt Olson',
#  'Clint Frazier',
#  'Corey Dickerson',
#  'James McCann',
#  'Joey Rickard',
#  'Salvador Perez',
#  'Kyle Schwarber',
#  'Tyler Moore',
#  'Yordan Alvarez',
#  'Brian Dozier',
#  'Adam Rosales',
#  'Evan Longoria',
#  'Miguel Montero',
#  'Michael Conforto',
#  'David Ross',
#  'Lonnie Chisenhall',
#  'Tony Kemp',
#  'Trevor Story',
#  'Cody Bellinger',
#  'Justin Smoak',
#  'Jed Lowrie',
#  'Logan Morrison',
#  'Yan Gomes',
#  'Tyler Austin',
#  'Kendrys Morales',
#  'Brian McCann',
#  'Alex Bregman',
#  'Wilmer Flores',
#  'Max Kepler',
#  'Jett Bandy',
#  'Carson Kelly',
#  'Eddie Rosario',
#  'Paul Goldschmidt',
#  'Chris Iannetta',
#  'Austin Meadows',
#  'Gregory Polanco',
#  'Todd Frazier',
#  'Matt Joyce',
#  'Jedd Gyorko',
#  'Randal Grichuk',
#  'Erik Kratz',
#  'Neil Walker',
#  'Justin Upton',
#  'Ronald Acuna Jr.',
#  'Christian Villanueva',
#  'Scott Kingery',
#  'Marcus Semien',
#  'Daniel Vogelbach',
#  'Brian Goodwin',
#  'Steve Pearce',
#  'Leonys Martin',
#  'Yonder Alonso',
#  'Austin Hedges',
#  'Mike Yastrzemski',
#  'Will Middlebrooks',
#  'Manny Pina',
#  'Dylan Moore',
#  'Jorge Polanco',
#  'Dioner Navarro',
#  'AJ Pollock',
#  'Mark Reynolds',
#  'Kurt Suzuki',
#  'Mark Canha',
#  'Josh VanMeter',
#  'Rougned Odor',
#  'Francisco Lindor',
#  'Chris Herrmann',
#  'Chris Young',
#  'Kole Calhoun',
#  'Joc Pederson',
#  'Brad Miller',
#  'Jason Kipnis',
#  'Bryce Harper',
#  'Paul DeJong',
#  'Carlos Gomez',
#  'Jordan Luplow',
#  'Alex Gordon',
#  'Ian Kinsler',
#  'David Ortiz',
#  'David Dahl',
#  'Pete Alonso',
#  'Omar Narvaez',
#  'Mike Moustakas',
#  'Hunter Dozier',
#  'Dansby Swanson',
#  'Adeiny Hechavarria',
#  'Andrew Benintendi',
#  'Corey Seager',
#  'Christian Yelich',
#  'Asdrubal Cabrera',
#  'Jose Bautista',
#  'Nolan Arenado',
#  'Derek Dietrich',
#  'Lourdes Gurriel Jr.',
#  'Brandon Nimmo',
#  'Mitch Moreland',
#  'Dexter Fowler',
#  'Nelson Cruz',
#  'Keston Hiura',
#  'Renato Nunez',
#  'Josh Phegley',
#  'Mark Teixeira',
#  'Josh Reddick',
#  'Josh Donaldson',
#  'Chase Utley',
#  'Didi Gregorius',
#  'Mark Trumbo',
#  'Tyler White',
#  'Jorge Soler',
#  'Enrique Hernandez',
#  'Gordon Beckham',
#  'Rowdy Tellez',
#  'Matt Kemp',
#  'Yasmani Grandal',
#  'Zack Cozart',
#  'Christian Walker',
#  'Devin Mesoraco',
#  'Matt Wieters',
#  'Phillip Ervin',
#  'Michael Chavis',
#  'Tyler Flowers',
#  'Josh Harrison',
#  'Ramon Laureano',
#  'Anthony Santander',
#  'Byron Buxton',
#  'Tim Beckham',
#  'Luke Voit',
#  'Ronny Rodriguez',
#  'Clint Barmes',
#  'Yoan Moncada',
#  'Danny Jansen',
#  'Hank Conger',
#  'Victor Martinez',
#  'Juan Soto',
#  'Josh Bell',
#  'Ji-Man Choi',
#  'Welington Castillo',
#  'Charlie Blackmon',
#  'Anthony Rizzo',
#  'Manny Machado',
#  'Sandy Leon',
#  'Franmil Reyes',
#  'Albert Pujols',
#  'Logan Forsythe',
#  'Whit Merrifield',
#  'Harrison Bader',
#  'Jeimer Candelario',
#  'Carlos Beltran',
#  'Daniel Murphy',
#  'Robbie Grossman',
#  'Freddy Galvis',
#  'Alex Rios',
#  'Jayson Werth',
#  'Dustin Fowler',
#  'Carlos Asuaje',
#  'Johnny Field',
#  'Daniel Palka',
#  'C.J. Cron',
#  'Geovany Soto',
#  'Francisco Mejia',
#  'Xander Bogaerts',
#  'Carlos Santana',
#  'Stephen Drew',
#  'Jeff McNeil',
#  'Adam LaRoche',
#  'Chris Taylor',
#  'Wil Myers',
#  'Ian Happ',
#  'Keon Broxton',
#  'Cliff Pennington',
#  'Buster Posey',
#  'Troy Tulowitzki',
#  'Aledmys Diaz',
#  'Carlos Correa',
#  'Tyler Collins',
#  'Austin Jackson',
#  'Aaron Hicks',
#  'Francisco Cervelli',
#  'Andrew McCutchen',
#  'Adam Jones',
#  'Brandon Guyer',
#  'Michael Saunders',
#  'Jake Bauers',
#  'Niko Goodrum',
#  'Yadier Molina',
#  'Grady Sizemore',
#  'J.T. Realmuto',
#  'Scooter Gennett',
#  'Jose Peraza',
#  'Stephen Piscotty',
#  'Jackie Bradley Jr.',
#  'Trevor Plouffe',
#  'Jorge Bonifacio',
#  'Kyle Lewis',
#  'Brandon Dixon',
#  'Chris Owings',
#  'Adrian Beltre',
#  'T.J. Rivera',
#  'Aaron Hill',
#  'Andrew Knapp',
#  'George Springer',
#  'Billy McKinney',
#  'Austin Barnes',
#  'Ryan Cordell',
#  'Oscar Mercado',
#  'Alex Rodriguez',
#  'Nick Solak',
#  "Ryan O'Hearn",
#  'Christian Vazquez',
#  'Ehire Adrianza',
#  'Martin Maldonado',
#  'Bryan Reynolds',
#  "Travis d'Arnaud",
#  'Chris Gimenez',
#  'Adrian Gonzalez',
#  'Ty France',
#  'Jeff Mathis',
#  'Chad Pinder',
#  'Roberto Perez',
#  'Miguel Cabrera',
#  'Jimmy Rollins',
#  'Adam Lind',
#  'JaCoby Jones',
#  'Adalberto Mondesi',
#  'Fernando Tatis Jr.',
#  'Avisail Garcia',
#  'Tommy La Stella',
#  'Matt Holliday',
#  'Willson Contreras',
#  'Addison Russell',
#  'Jhonny Peralta',
#  'Hanley Ramirez',
#  'Luis Urias',
#  'Marcell Ozuna',
#  'Seth Smith',
#  'Aramis Ramirez',
#  'Jung Ho Kang',
#  'Steven Souza Jr.',
#  'Nick Ahmed',
#  'Kyle Tucker',
#  'Taylor Motter',
#  'Scott Schebler',
#  'Danny Espinosa',
#  'Giancarlo Stanton',
#  'Nicky Delmonico',
#  'Ryon Healy',
#  'Jacob Stallings',
#  'Evan White',
#  'Cameron Rupp',
#  'Domingo Santana',
#  'Starlin Castro',
#  'Johan Camargo',
#  'Brian Anderson',
#  'Chris Johnson',
#  'Alberto Callaspo',
#  'Omar Infante',
#  'Trayce Thompson',
#  'Caleb Joseph',
#  'Alex Avila',
#  'Derek Norris',
#  'Chase Headley',
#  'Shohei Ohtani',
#  'Kevin Plawecki',
#  'Ronald Guzman',
#  'Ben Gamel',
#  'Nick Hundley',
#  'Bo Bichette',
#  'Danny Santana',
#  'Alex Guerrero',
#  'Jonny Gomes',
#  'Mike Tauchman',
#  'Ketel Marte',
#  'Austin Nola',
#  'Blake Swihart',
#  'Jake Cave',
#  'Rafael Devers',
#  'Cody Asche',
#  'Tommy Joseph',
#  'Jesse Winker',
#  'Hernan Perez',
#  'Yasiel Puig',
#  'Yangervis Solarte',
#  'Eloy Jimenez',
#  'Franklin Gutierrez',
#  'Coco Crisp',
#  'Marwin Gonzalez',
#  'Aaron Altherr',
#  'Jace Peterson',
#  'Ryan Zimmerman',
#  'Nick Senzel',
#  'Jurickson Profar',
#  'Adam Eaton',
#  'Darin Ruf',
#  'Mikie Mahtook',
#  'J.J. Hardy',
#  'Lorenzo Cain',
#  'Jorge Alfaro',
#  'Joe Panik',
#  'Guillermo Heredia',
#  'Gio Urshela',
#  'Howie Kendrick',
#  'Matt Szczur',
#  'Kevin Pillar',
#  'Alen Hanson',
#  'Cesar Hernandez',
#  'Daniel Robertson',
#  'Pablo Sandoval',
#  'Alcides Escobar',
#  'Jose Osuna',
#  'Eric Campbell',
#  'Russell Martin',
#  'Willy Adames',
#  'Adam Frazier',
#  'Hanser Alberto',
#  'Tim Anderson',
#  'Jose Reyes',
#  'Cameron Maybin',
#  'Hunter Pence',
#  'Angel Pagan',
#  'Oswaldo Arcia',
#  'Chris Coghlan',
#  'John Hicks',
#  'Yolmer Sanchez',
#  'Marlon Byrd',
#  'Shin-Soo Choo',
#  'Lewis Brinson',
#  'Miguel Andujar',
#  'Ryan Flaherty',
#  'Scott Van Slyke',
#  'Torii Hunter',
#  'Nick Williams',
#  'Javier Baez',
#  'Gerardo Parra',
#  'Devon Travis',
#  'Eric Sogard',
#  'Juan Uribe',
#  'Greg Garcia',
#  'Jose Altuve',
#  'Maikel Franco',
#  'Luis Arraez',
#  'Stevie Wilkerson',
#  'Ian Desmond',
#  'Justin Maxwell',
#  'David DeJesus',
#  'Alex Dickerson',
#  'Carlos Perez',
#  'Tyler Naquin',
#  'Kelly Johnson',
#  'Willie Calhoun',
#  'Pedro Severino',
#  'Dwight Smith',
#  'Prince Fielder',
#  'B.J. Upton',
#  'Adam Engel',
#  'Jonathan Lucroy',
#  'Jose Martinez',
#  'Brett Gardner',
#  'Jordy Mercer',
#  'Tyler Saladino',
#  'Yuli Gurriel',
#  'Brett Lawrie',
#  'Jefry Marte',
#  'Ender Inciarte',
#  'Carlos Gonzalez',
#  'Manuel Margot',
#  'Nomar Mazara',
#  'Tucker Barnhart',
#  'Christian Bethancourt',
#  'Joey Wendle',
#  'J.D. Davis',
#  'Brett Eibner',
#  'Starling Marte',
#  'Trea Turner',
#  'DJ LeMahieu',
#  'Justin Bour',
#  'Carlos Ruiz',
#  'Elias Diaz',
#  'Odubel Herrera',
#  'Victor Robles',
#  'Miguel Rojas',
#  'Matt Duffy',
#  'Clint Robinson',
#  'Sean Rodriguez',
#  'Patrick Kivlehan',
#  'Kolten Wong',
#  'Michael A. Taylor',
#  'Daniel Nava',
#  'Tommy Edman',
#  'Jose Abreu',
#  'Ruben Tejada',
#  'Melky Cabrera',
#  'Rajai Davis',
#  'Robinson Cano',
#  'James Loney',
#  'Ben Zobrist',
#  'Steven Duggar',
#  'Delino DeShields',
#  'Willians Astudillo',
#  'Jeff Francoeur',
#  'Brandon Crawford',
#  'Garrett Hampson',
#  'J.P. Crawford',
#  'Brock Holt',
#  'Michael Brantley',
#  'Elian Herrera',
#  'Ryan Goins',
#  'Hyun Soo Kim',
#  'David Murphy',
#  'Nick Swisher',
#  'Kirk Nieuwenhuis',
#  'Desmond Jennings',
#  'Trey Mancini',
#  'Preston Tucker',
#  'Wilmer Difo',
#  'Kevin Kiermaier',
#  'Erick Aybar',
#  'Orlando Arcia',
#  'Dixon Machado',
#  'Gregor Blanco',
#  'Jason Heyward',
#  'Jonathan Schoop',
#  'Luke Maile',
#  'David Freese',
#  'Ryan McMahon',
#  'Greg Allen',
#  'Cheslor Cuthbert',
#  'Elvis Andrus',
#  'Brandon Drury',
#  'Tony Wolters',
#  'Conor Gillaspie',
#  'Nick Markakis',
#  'Austin Romine',
#  'Vladimir Guerrero Jr.',
#  'Isiah Kiner-Falefa',
#  'Tim Locastro',
#  'Dustin Ackley',
#  'Bobby Wilson',
#  'A.J. Ellis',
#  'Billy Butler',
#  'Tommy Pham',
#  'Andre Ethier',
#  'Danny Valencia',
#  'Peter Bourjos',
#  'Eduardo Nunez',
#  'Rickie Weeks Jr.',
#  'Andrelton Simmons',
#  'Raimel Tapia',
#  'Darwin Barney',
#  'Bruce Maxwell',
#  'Jonathan Villar',
#  'Dustin Pedroia',
#  'Jacoby Ellsbury',
#  'Jean Segura',
#  'Gorkys Hernandez',
#  'Kevan Smith',
#  'Mallex Smith',
#  'Mike Aviles',
#  "Chase d'Arnaud",
#  'Grayson Greiner',
#  'Colin Moran',
#  'Ryan Braun',
#  'Billy Hamilton',
#  'Ryan Raburn',
#  'David Fletcher',
#  'Michael Bourn',
#  'Matt Beaty',
#  'Harold Castro',
#  'Mike Freeman',
#  'Donovan Solano',
#  'Domonic Brown',
#  'Pedro Alvarez',
#  'Yasmany Tomas',
#  'Nolan Reimold',
#  'JT Riddle',
#  'Kevin Newman',
#  'Rio Ruiz',
#  'Jake Smolinski',
#  'Dawel Lugo',
#  'Alexi Amarista',
#  'Johnny Giavotella',
#  'Amed Rosario',
#  'Ryan Rua',
#  'Victor Caratini',
#  'David Peralta',
#  'Denard Span',
#  'Victor Reyes',
#  'Brett Wallace',
#  'Martin Prado',
#  'Jose Pirela',
#  'Juan Lagares',
#  'Brandon Barnes',
#  'Wilson Ramos',
#  'Jeremy Hazelbaker',
#  'Bradley Zimmer',
#  'Kennys Vargas',
#  'Michael Cuddyer',
#  'Eric Hosmer',
#  'Jarrod Dyson',
#  'Rusney Castillo',
#  'Travis Snider',
#  'Alex Verdugo',
#  'Luis Rengifo',
#  'JB Shuck',
#  'Joe Mauer',
#  'Ronald Torreyes',
#  'Max Stassi',
#  'Luis Robert',
#  'Cory Spangenberg',
#  'Ezequiel Carrera',
#  'Andrew Romine',
#  'Ryan Hanigan',
#  'Charlie Culberson',
#  'Dae-Ho Lee',
#  'Paulo Orlando',
#  'Shane Victorino',
#  'Allen Cordoba',
#  'Yandy Diaz',
#  'Andres Blanco',
#  'Tyler Goeddel',
#  'Albert Almora Jr.',
#  'Yunel Escobar',
#  'Tyler Holt',
#  'Justin Morneau',
#  'Garrett Cooper',
#  'Jose Iglesias',
#  'Jimmy Paredes',
#  'A.J. Pierzynski',
#  'Jon Jay',
#  'Ichiro Suzuki',
#  'Yairo Munoz',
#  'Norichika Aoki',
#  'Brandon Phillips',
#  'Ildemaro Vargas',
#  'Chris Colabello',
#  'Alexei Ramirez',
#  'Richie Martin',
#  'Casey McGehee',
#  'Leury Garcia',
#  'Josh Naylor',
#  'Jon Berti',
#  'Trent Grisham',
#  'Harold Ramirez',
#  'David Bote',
#  'Alex Presley',
#  'Rosell Herrera',
#  'Gregorio Petit',
#  'Adam Haseley',
#  'Shane Peterson',
#  'Dee Strange-Gordon',
#  'Anthony Gose',
#  'Jason Bourgeois',
#  'Nicky Lopez',
#  "Shawn O'Malley",
#  'Joey Butler',
#  'Ben Revere',
#  'Abraham Almonte',
#  'Ike Davis',
#  'Chris Denorfia',
#  'Cristhian Adames',
#  'Brayan Pena',
#  'Wilin Rosario',
#  'Phil Gosselin',
#  'Ivan De Jesus Jr.',
#  'Rafael Ortega',
#  'Adonis Garcia',
#  'Ramon Flores',
#  'Billy Burns',
#  'Michael Morse',
#  'Ben Paulsen',
#  'Kelby Tomlinson',
#  'Will Venable',
#  'Sam Fuld',
#  'Skip Schumaker',
#  'Travis Jankowski',
#  'Austin Slater']

# %%
len(final_player_list)
# Out:
# 646

# %%
#Checking to make sure length of unique names matches player list.
savant_df.Player.value_counts()
# Out:
#  Cabrera, Asdrubal    6
#  Cruz, Nelson         6
#  Lindor, Francisco    6
#  Franco, Maikel       6
#  Blackmon, Charlie    6
#                      ..
#  Van Slyke, Scott     1
#  Herrera, Elian       1
#  Bandy, Jett          1
#  Collins, Tyler       1
#  Field, Johnny        1
# Name: Player, Length: 646, dtype: int64

# %% [markdown]
# ## Moving in BBREF Data

# %% [markdown]
# Creating a Baseball reference URL based on a player list input:

# %%
def Player_URL_Generator(player_list):
    '''
    Takes a list of player names, with each name being an entry of first name and last name.
    Returns a URL on baseball reference to each player's original page.
    '''
    separated_names = [player.split(" ") for player in player_list]
    url_list = []
    for i, player in enumerate(separated_names):
        #Stripping punctuation from names:
        new_name = [name.replace(".","") for name in player]
        new_name = [name.replace("'","") for name in new_name]
        #print(len(new_name))
        #In other words, if a player has 3 names not two:
        if len(new_name) == 3:
            comb_name = [new_name[0], new_name[1]+new_name[2]]
            #print(comb_name)
            if len(comb_name[1]) <= 5:
                url = 'https://www.baseball-reference.com/players/{}/{}{}01.shtml'.format(comb_name[1][0].lower(), comb_name[1].lower(), comb_name[0][0:2].lower())
            else:
                url = 'https://www.baseball-reference.com/players/{}/{}{}01.shtml'.format(comb_name[1][0].lower(), comb_name[1][0:5].lower(), comb_name[0][0:2].lower())
        else:    
            if len(new_name[1]) <= 5:
                url = 'https://www.baseball-reference.com/players/{}/{}{}01.shtml'.format(new_name[1][0].lower(), new_name[1].lower(), new_name[0][0:2].lower())
            else:
                url = 'https://www.baseball-reference.com/players/{}/{}{}01.shtml'.format(new_name[1][0].lower(), new_name[1][0:5].lower(), new_name[0][0:2].lower())
        url_list.append(url)
    return url_list

# %% [markdown]
# Testing URL Generator w/ edge cases (apostrophes, periods in name, spaces in name, etc.)

# %%
Player_URL_Generator(["Tyler O'Neill", "Chase d'Arnaud", "C.J. Cron", 'Tommy La Stella','Alejandro De Aza'])
# Out:
# ['https://www.baseball-reference.com/players/o/oneilty01.shtml',
#  'https://www.baseball-reference.com/players/d/darnach01.shtml',
#  'https://www.baseball-reference.com/players/c/croncj01.shtml',
#  'https://www.baseball-reference.com/players/l/lasteto01.shtml',
#  'https://www.baseball-reference.com/players/d/deazaal01.shtml']

# %% [markdown]
# From the Player URL Function, generating a BS4 object:

# %%
def Player_Soup_Generator(player_list):
    '''
    Takes in a list of players and returns Beautiful Soup objects.
    '''
    url_list = Player_URL_Generator(player_list)
    response_list = [requests.get(url) for url in url_list]
    soup_list = []
    for response in response_list:
        page = response.text
        soup_object = BeautifulSoup(page,'lxml')
        name = player.title.text.split("Stats")[0]
        if player_list[i].strip() != name.strip():
            #Add in code for updating URL in this case
        soup_list.append(BeautifulSoup(page,'lxml'))
    return soup_list
# Out:
#   File "<ipython-input-27-c9c2f4fa2970>", line 14
#     soup_list.append(BeautifulSoup(page,'lxml'))
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# Pull the years the player played from baseball reference:

# %%
def Pull_Player_Seasons(player_soup):
    '''
    Takes in a player's soup object.
    Returns a list of the season the player played in.
    '''
    seasons = player_soup.find_all('tr', attrs={'id':re.compile('batting_standard.')})
    #seasons = player_soup.find_all('tr', attrs={'data-stat':re.compile('')})
    seasons_played = []
    for season in seasons:
        season_item = [str(item.get_text()) for item in season.find_all('th')]
        seasons_played.append(season_item)
    return seasons_played

# %% [markdown]
# Pull the year by year stas from BBREF:

# %%
def Pull_Player_Stats(player_soup):
    '''
    Takes in a player's soup object.
    Returns a list of stat lines by season.
    '''
    stat_line = player_soup.find_all('tr', attrs={'id':re.compile('batting_standard.')})
    career_stats = []
    for season in stat_line:
        season_stat_line = [item.get_text() for item in season.find_all('td')]
        career_stats.append(season_stat_line)
    for i,year in enumerate(career_stats):
        career_stats[i].insert(0,Pull_Player_Seasons(player_soup)[i][0])
    return career_stats

# %% [markdown]
# From the years and stats, build a pandas dataframe:

# %%
def Player_Dataframe_Builder(player_soup_list):
    '''
    Takes in a list of BeautifulSoup Objects, returns a data frame of their Baseball-Reference stats.
    '''
    i=0
    
    for player in player_soup_list:
        header = player.find_all('th', attrs={'class': 'poptip'})
        columns = [col.get_text() for col in header]
        current_player_df = pd.DataFrame(Pull_Player_Stats(player), columns=columns)
        if i ==0:
            compiled_player_df = pd.DataFrame(columns=columns)
            compiled_player_df['Name'] = ''
            i += 1
        #Adding Player Name as a column:
        name = player.title.text.split("Stats")[0]
        current_player_df['Name'] = name
            
        compiled_player_df = pd.concat([compiled_player_df, current_player_df], ignore_index=True)
    num_cols = ['Age', 'G', 'PA', 'AB', 'R','H','2B','3B','HR','RBI','SB','CS','BB','SO','BA','OBP','SLG','OPS','OPS+','TB','GDP','HBP','SH','SF','IBB']
    compiled_player_df[num_cols] = compiled_player_df[num_cols].apply(pd.to_numeric, errors='coerce', axis=1)
    return compiled_player_df

# %% [markdown]
# Test Case, using the final_player_list from the BasebalL Savant Data:

# %%
my_soup_list = Player_Soup_Generator(final_player_list)

# %% [markdown]
# Testing for players whose URL and names don't match using the normal method:

# %%
for i, player in enumerate(my_soup_list):
    name = player.title.text.split("Stats")[0]
    if final_player_list[i].strip() != name.strip():
        print('WRONG!')
        print(name, final_player_list[i])

# %%
multiple_player_df = Player_Dataframe_Builder(my_soup_list)

# %%
multiple_player_df.Name.value_counts()

# %%
multiple_player_df.head()

# %%
my_list = ['Eloy Jimenez','Jose Abreu','Mike Trout','Adam Eaton','Frank Thomas']

# %%
url_list = Player_URL_Generator(my_list)
response_list = [requests.get(url) for url in url_list]
soup_list = []
for response in response_list:
    page = response.text
    soup_list.append(BeautifulSoup(page,'lxml'))

# %%
for i, player in enumerate(soup_list):
    name = player.title.text.split("Stats")[0]
    print(name)
    print(my_list[i])
    if str(name) != str(my_list[i]):
        print('WRONG!')
    else:
        print('MATC!')
