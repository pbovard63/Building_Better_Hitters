# %% [markdown]
# # Code on Scraping Data from Fangraphs:

# %% [markdown]
# First, importing needed packages:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 20,10
import numpy as np
import glob
from scipy import stats
from bs4 import BeautifulSoup
import requests
import re
from IPython.core.display import display, HTML    # make sure Jupyter knows to display it as HTML

# %% [markdown]
# Importing selenium and setting chrome driver:

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %% [markdown]
# Next step: Try to find a WAR or wRC+ list for each season

# %%
#Data from 2015-2020, players with at least 200 PA in that given season:
wrc_url = 'https://www.fangraphs.com/leaders/season-stat-grid?position=B&seasonStart=2015&seasonEnd=2020&stat=wRC%2B&pastMinPt=200&curMinPt=0&mode=normal'

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(wrc_url)

# %%
driver.page_source[:1000]
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml"><head id="Head1"><script src="https://js-agent.newrelic.com/nr-1194.min.js"></script><script type="text/javascript">ezstandalone.selectedPlaceholders = {};eval(ez_write_tag([[728,90],\'fangraphs_com-medrectangle-2\',\'ezslot_0\',100,\'0\',\'0\']));eval(ez_write_tag([[970,250],\'fangraphs_com-box-2\',\'ezslot_1\',104,\'0\',\'0\']));eval(ez_write_tag([[970,250],\'fangraphs_com-box-2\',\'ezslot_2\',104,\'0\',\'1\']));eval(ez_write_tag([[970,250],\'fangraphs_com-box-2\',\'ezslot_3\',104,\'0\',\'2\']));eval(ez_write_tag([[160,600],\'fangraphs_com-box-4\',\'ezslot_4\',125,\'0\',\'0\']));eval(ez_write_tag([[160,600],\'fangraphs_com-banner-1\',\'ezslot_5\',126,\'0\',\'0\']));eval(ez_write_tag([[970,250],\'fangraphs_com-medrectangle-1\',\'ezslot_6\',113,\'0\',\'0\']));eval(ez_write_tag([[970,250],\'fangraphs_com-medrectangle-1\',\'ezslot_7\',113,\'0\',\'1\']));eval(ez_write_tag([[970,250],\'fangraphs_com-medrectangle-1\',\'ezslot_8\',113,\'0\',\'2\']));eval(ez_write_tag([[970,250],\'fangraphs_com-large-mobile-banner-1\',\'ezs'

# %% [markdown]
# Using Selenium to set page to Infinite Rows:

# %%
players_dropdown = driver.find_element_by_xpath('//*[@id="root-season-grid"]/div/div[3]/div[3]/div[1]/select')
players_dropdown.send_keys("Infinity")

# %% [markdown]
# Once page is at inifinte rows, run the Beautiful soup code:

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
headers = soup.find('div', class_='table-scroll').find_all('th')
print(headers)
# Out:
# [<th class="th-rank fixed">#</th>, <th class="align-left fixed" data-col="0" data-stat="Name">Name</th>, <th class="align-right" data-col="1" data-stat="2015">2015</th>, <th class="align-right" data-col="2" data-stat="2016">2016</th>, <th class="align-right" data-col="3" data-stat="2017">2017</th>, <th class="align-right" data-col="4" data-stat="2018">2018</th>, <th class="align-right" data-col="5" data-stat="2019">2019</th>, <th class="align-right highlight-sort" data-col="6" data-stat="2020">2020</th>]

# %% [markdown]
# Setting up and Verifying ultimate Dataframe rows are right:

# %%
columns = [col.get_text() for col in headers]

# %%
print(columns)
# Out:
# ['#', 'Name', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
wrc_df = pd.DataFrame(columns=columns)
wrc_df.head()
# Out:
# Empty DataFrame
# Columns: [#, Name, 2015, 2016, 2017, 2018, 2019, 2020]
# Index: []

# %% [markdown]
# Finding Stats:

# %%
stats_test = soup.find('div', class_='table-scroll').find_all('tr')
print(stats_test)
# Out:
# [<tr><th class="th-rank fixed">#</th><th class="align-left fixed" data-col="0" data-stat="Name">Name</th><th class="align-right" data-col="1" data-stat="2015">2015</th><th class="align-right" data-col="2" data-stat="2016">2016</th><th class="align-right" data-col="3" data-stat="2017">2017</th><th class="align-right" data-col="4" data-stat="2018">2018</th><th class="align-right" data-col="5" data-stat="2019">2019</th><th class="align-right highlight-sort" data-col="6" data-stat="2020">2020</th></tr>, <tr class="is-selected__invalid"><td class="fixed">1</td><td class="align-left fixed" data-stat="Name"><a href="//www.fangraphs.com/statss.aspx?playerid=14843">Michael Lorenzen</a></td><td class="align-right" data-stat="2015"></td><td class="align-right" data-stat="2016"></td><td class="align-right" data-stat="2017"></td><td class="align-right" data-stat="2018"></td><td class="align-right" data-stat="2019"></td><td class="align-right highlight-sort" data-stat="2020">366</td></tr>, <tr class="is-selected__invalid"><td class="fixed">2</td><td class="align-left fixed" data-stat="Name"><a href="//www.fangraphs.com/statss.aspx?playerid=22217">Luis Campusano</a></td><td class="align-right" data-stat="2015"></td><td class="align-right" data-stat="2016"></td><td class="align-right" data-stat="2017"></td><td class="align-right" data-stat="2018"></td><td class="align-right" data-stat="2019"></td><td class="align-right highlight-sort" data-stat="2020">337</td></tr>, <tr class="is-selected__invalid"><td class="fixed">3</td><td class="align-left fixed" data-stat="Name"><a href="//www.fangraphs.com/statss.aspx?playerid=15654">Billy McKinney</a></td><td class="align-right" data-stat="2015"></td><td class="align-right" data-stat="2016"></td><td class="align-right" data-stat="2017"></td><td class="align-right" data-stat="2018"></td><td class="align-right" data-stat="2019">79</td><td class="align-right highlight-sort" data-stat="2020">286</td></tr>, <tr class="is-selected__invalid"><td class="fixed">4</td><td class="align-left fixed" data-stat="Name"><a href="//www.fangraphs.com/statss.aspx?playerid=21646">Rafael Marchan</a></td><td class="align-right" data-stat="2015"></td><td class="align-right" data-stat="2016"></td><td class="align-right" data-stat="2017"></td><td class="align-right" data-stat="2018"></td><td class="align-right" data-stat="2019"></td><td class="align-right highlight-sort" data-stat="2020">277</td></tr>, <tr class="is-selected__invalid"><td class="fixed">5</td><td class="align-left fixed" data-stat="Name"><a href="//www.fangraphs.com/statss.aspx?playerid=18395">Travis Blankenhorn</a></td><td class="align-right" data-stat="2015"></td><td class="align-right" data-stat="2016"></td><td class="align-right" data-stat="2017"></td><td class="align-right" data-stat="2018"></td><td class="align-right" data-stat="2019"></td><td class="align-right highlight-sort" data-stat="2020">219</td></tr>, <tr class="is-selected__invalid"><td class="fixed">6</td><td class="align-left fixed" data-stat="Name"><a href="//www.fangraphs.com/statss.aspx?playerid=11602">Yolmer Sánchez</a></td><td class="align-right" data-stat="2015">63</td><td class="align-right" data-stat="2016"></td><td class="align-right" data-stat="2017">95</td><td class="align-right" data-stat="2018">87</td><td class="align-right" data-stat="2019">74</td><td class="align-right highlight-sort" data-stat="2020">213</td></tr>, <tr class="is-selected__invalid"><td class="fixed">7</td><td class="align-left fixed" data-stat="Name"><a href="//www.fangraphs.com/statss.aspx?playerid=17932">Andrew Stevenson</a></td><td class="align-right" data-stat="2015"></td><td class="align-right" data-stat="2016"></td><td class="align-right" data-stat="2017"></td><td class="align-right" data-stat="2018"></td><td class="align-right" data-stat="2019"></td><td class="align-right highlight-sort" data-stat="2020">206</td></tr>, <tr class="is-selected__invalid"><td class="fixed">8</td><td class="align-left fixed" dat ...

# %%
stats = [col.get_text() for col in stats_test]

# %%
stat_lines = soup.find('div', class_='table-scroll').find_all('tr')
compiled_stats = []
for line_item in stat_lines:
    ind_stat_line = [item.get_text() for item in line_item.find_all('td')]
    compiled_stats.append(ind_stat_line)
    final_stats = compiled_stats[1:]

# %% [markdown]
# Building Dataframe with scraped data:

# %%
wrc_df = pd.DataFrame(final_stats, columns=columns)
#num_cols = ['Age','G','PA','Year','Avg EV (MPH)','Avg LA (°)','Barrel%','Solid Contact %','Hard Hit %','Zone Swing %','Out of Zone Swing %','Pull %','Straight Away %','Oppo %','GB%','FB%','LD %','Sprint Speed']
#savant_df[num_cols] = savant_df[num_cols].apply(pd.to_numeric, errors='coerce', axis=1)
wrc_df.set_index(wrc_df['#'], inplace=True)
wrc_df.drop(columns='#',inplace=True)
wrc_df.replace("", '0', inplace=True)
wrc_df.head()
# Out:
#                  Name 2015 2016 2017 2018 2019 2020
# #
# 1    Michael Lorenzen    0    0    0    0    0  366
# 2      Luis Campusano    0    0    0    0    0  337
# 3      Billy McKinney    0    0    0    0   79  286
# 4      Rafael Marchan    0    0    0    0    0  277
# 5  Travis Blankenhorn    0    0    0    0    0  219

# %%
wrc_df.columns
# Out:
# Index(['Name', '2015', '2016', '2017', '2018', '2019', '2020'], dtype='object')

# %%
wrc_df
# Out:
#                    Name 2015 2016 2017 2018 2019 2020
# #
# 1      Michael Lorenzen    0    0    0    0    0  366
# 2        Luis Campusano    0    0    0    0    0  337
# 3        Billy McKinney    0    0    0    0   79  286
# 4        Rafael Marchan    0    0    0    0    0  277
# 5    Travis Blankenhorn    0    0    0    0    0  219
# ..                  ...  ...  ...  ...  ...  ...  ...
# 837       Richie Martin    0    0    0    0   50    0
# 838        Jung Ho Kang  128  132    0    0    0    0
# 839       Yasmany Tomás   87  109    0    0    0    0
# 840       Dustin Fowler    0    0    0   66    0    0
# 841     Rusney Castillo   73    0    0    0    0    0
#
# [841 rows x 7 columns]

# %% [markdown]
# Closing driver:

# %%
driver.close()

# %%
wrc_df.head()
# Out:
#                  Name 2015 2016 2017 2018 2019 2020
# #
# 1    Michael Lorenzen    0    0    0    0    0  366
# 2      Luis Campusano    0    0    0    0    0  337
# 3      Billy McKinney    0    0    0    0   79  286
# 4      Rafael Marchan    0    0    0    0    0  277
# 5  Travis Blankenhorn    0    0    0    0    0  219

# %% [markdown]
# Next Step: changing dataframe data to include rows of each player's yearly performance, to merge with baseball savant data

# %%
wrc_pivot_df = wrc_df.T
wrc_pivot_df.head()
# Out:
# #                    1               2               3               4  \
# Name  Michael Lorenzen  Luis Campusano  Billy McKinney  Rafael Marchan
# 2015                 0               0               0               0
# 2016                 0               0               0               0
# 2017                 0               0               0               0
# 2018                 0               0               0               0
#
# #                      5               6                 7            8  \
# Name  Travis Blankenhorn  Yolmer Sánchez  Andrew Stevenson  Austin Dean
# 2015                   0              63                 0            0
# 2016                   0               0                 0            0
# 2017                   0              95                 0            0
# 2018                   0              87                 0            0
#
# #             9              10  ...       832            833         834  \
# Name  Juan Soto  Ke'Bryan Hayes  ...  Ryan Rua  Taylor Motter  Dae-Ho Lee
# 2015          0               0  ...         0              0           0
# 2016          0               0  ...        90              0         103
# 2017          0               0  ...         0             57           0
# 2018        145               0  ...         0              0           0
#
# #              835           836            837           838            839  \
# Name  Hyun Soo Kim  ByungHo Park  Richie Martin  Jung Ho Kang  Yasmany Tomás
# 2015             0             0              0           128             87
# 2016           121            79              0           132            109
# 2017            61             0              0             0              0
# 2018             0             0              0             0              0
#
# #               840              841
# Name  Dustin Fowler  Rusney Castillo
# 2015              0               73
# 2016              0                0
# 2017              0                0
# 2018             66                0
#
# [5 rows x 841 columns]

# %%
wrc_pivot_df.columns = wrc_pivot_df.iloc[0]
final_wrc_pivot_df = wrc_pivot_df[1:]

# %%
final_wrc_pivot_df.head()
# Out:
# Name Michael Lorenzen Luis Campusano Billy McKinney Rafael Marchan  \
# 2015                0              0              0              0
# 2016                0              0              0              0
# 2017                0              0              0              0
# 2018                0              0              0              0
# 2019                0              0             79              0
#
# Name Travis Blankenhorn Yolmer Sánchez Andrew Stevenson Austin Dean Juan Soto  \
# 2015                  0             63                0           0         0
# 2016                  0              0                0           0         0
# 2017                  0             95                0           0         0
# 2018                  0             87                0           0       145
# 2019                  0             74                0           0       142
#
# Name Ke'Bryan Hayes  ... Ryan Rua Taylor Motter Dae-Ho Lee Hyun Soo Kim  \
# 2015              0  ...        0             0          0            0
# 2016              0  ...       90             0        103          121
# 2017              0  ...        0            57          0           61
# 2018              0  ...        0             0          0            0
# 2019              0  ...        0             0          0            0
#
# Name ByungHo Park Richie Martin Jung Ho Kang Yasmany Tomás Dustin Fowler  \
# 2015            0             0          128            87             0
# 2016           79             0          132           109             0
# 2017            0             0            0             0             0
# 2018            0             0            0             0            66
# 2019            0            50            0             0             0
#
# Name Rusney Castillo
# 2015              73
# 2016               0
# 2017               0
# 2018               0
# 2019               0
#
# [5 rows x 841 columns]

# %% [markdown]
# ### Building new dataframe with the year/player wRC+ Data:

# %% [markdown]
# Creating Rows: (each row should be player-year)

# %%
names = final_wrc_pivot_df.columns.to_list()
years = final_wrc_pivot_df.index.to_list()

# %%
print(years)
# Out:
# ['2015', '2016', '2017', '2018', '2019', '2020']

# %%
new_df_rows = []
for name in names:
    for year in years:
        new_row = name + "-" + year
        new_df_rows.append(new_row)

# %%
#Should be 841*6 = 5046
len(new_df_rows)
# Out:
# 5046

# %%
final_wrc_df = pd.DataFrame(new_df_rows, columns=['Name-Year'])

# %%
final_wrc_df['wRC+'] = ''
final_wrc_df.head(10)
# Out:
#                Name-Year wRC+
# 0  Michael Lorenzen-2015
# 1  Michael Lorenzen-2016
# 2  Michael Lorenzen-2017
# 3  Michael Lorenzen-2018
# 4  Michael Lorenzen-2019
# 5  Michael Lorenzen-2020
# 6    Luis Campusano-2015
# 7    Luis Campusano-2016
# 8    Luis Campusano-2017
# 9    Luis Campusano-2018

# %% [markdown]
# Pulling wRC+ Data:

# %%
wrc_2015 = final_wrc_pivot_df.iloc[0].to_list()
wrc_2016 = final_wrc_pivot_df.iloc[1].to_list()
wrc_2017 = final_wrc_pivot_df.iloc[2].to_list()
wrc_2018 = final_wrc_pivot_df.iloc[3].to_list()
wrc_2019 = final_wrc_pivot_df.iloc[4].to_list()
wrc_2020 = final_wrc_pivot_df.iloc[5].to_list()

# %%
final_wrc_df['wRC+'].iloc[0::6] = wrc_2015
final_wrc_df['wRC+'].iloc[1::6] = wrc_2016
final_wrc_df['wRC+'].iloc[2::6] = wrc_2017
final_wrc_df['wRC+'].iloc[3::6] = wrc_2018
final_wrc_df['wRC+'].iloc[4::6] = wrc_2019
final_wrc_df['wRC+'].iloc[5::6] = wrc_2020

# %%
#Pulling a random sample to audit:
final_wrc_df.sample(25)
# Out:
#                     Name-Year wRC+
# 4365        Brett Eibner-2018    0
# 522         Rowdy Tellez-2015    0
# 2708          Matt Adams-2017  111
# 1870      Matt Carpenter-2019   95
# 1773       Shin-Soo Choo-2018  117
# 793       Jonathan Davis-2016    0
# 4694      Trevor Plouffe-2017   59
# 563     Michael Brantley-2020  134
# 4877       Bruce Maxwell-2020    0
# 2667        Jaylin Davis-2018    0
# 2246         Alex Gordon-2017   62
# 3655        Juan Lagares-2016    0
# 1628       Brian Goodwin-2017  103
# 4628      Chris Iannetta-2017  120
# 25    Travis Blankenhorn-2016    0
# 4202       Mark Teixeira-2017    0
# 410         James McCann-2017   94
# 2300      Carter Kieboom-2017    0
# 3688         Jefry Marte-2019    0
# 2099    Santiago Espinal-2020   76
# 743       David Fletcher-2020  125
# 1838       Andrew Romine-2017   66
# 1096       Brett Gardner-2019  115
# 3812      Ryan Zimmerman-2017  137
# 4501         Ben Paulsen-2016    0

# %% [markdown]
# Good!!!!!!
