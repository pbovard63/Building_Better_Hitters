# %% [markdown]
# # Merging Code from Fangraphs and Baseball Savant

# %% [markdown]
# First, import needed packages.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re
from IPython.core.display import display, HTML    # make sure Jupyter knows to display it as HTML
import time, os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import unicodedata

# %% [markdown]
# Now, import the functions I need:

# %%
from baseball_savant_code import *
from fangraphs_wrc_code import *

# %% [markdown]
# Add in the URL's:

# %%
savant_url = 'https://baseballsavant.mlb.com/leaderboard/custom?year=2020,2019,2018,2017,2016,2015&type=batter&filter=&sort=16&sortDir=desc&min=200&selections=player_age,b_total_pa,b_game,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,solidcontact_percent,hard_hit_percent,z_swing_percent,oz_swing_percent,pull_percent,straightaway_percent,opposite_percent,groundballs_percent,flyballs_percent,linedrives_percent,sprint_speed,&chart=true&x=player_age&y=player_age&r=no&chartType=beeswarm'
fg_url = 'https://www.fangraphs.com/leaders/season-stat-grid?position=B&seasonStart=2015&seasonEnd=2020&stat=wRC%2B&pastMinPt=200&curMinPt=0&mode=normal'

# %% [markdown]
# Create dataframes:

# %%
savant_df = Savant_DataFrame_Builder(savant_url)

# %%
fg_df = wRC_DataFrame_Shifter(fg_url)

# %%
savant_df.head()
# Out:
#                       Player    Year   Age     PA      G  Avg EV (MPH)  \
# Rk.
# 1     Saltalamacchia, Jarrod  2016.0  31.0  292.0   92.0          89.2
# 2              Schimpf, Ryan  2016.0  28.0  330.0   89.0          90.3
# 3                Gallo, Joey  2017.0  24.0  532.0  145.0          93.3
# 4            Carpenter, Matt  2018.0  33.0  677.0  156.0          90.7
# 5                 Bruce, Jay  2019.0  32.0  333.0   98.0          90.2
#
#      Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  Zone Swing %  \
# Rk.
# 1          21.4     11.6              6.8        35.4          65.7
# 2          29.7     16.7              8.0        41.4          64.7
# 3          23.0     22.1              8.3        52.2          72.7
# 4          21.6     13.7             11.5        44.7          57.1
# 5          21.4     13.4              8.2        43.7          79.6
#
#      Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# Rk.
# 1                   23.9    44.2             34.0    21.8  31.3  43.5  19.7
# 2                   23.4    41.4             33.9    24.7  20.1  42.0  21.8
# 3                   28.2    50.2             29.2    20.6  29.2  37.9  22.1
# 4                   18.5    47.6             30.7    21.7  28.3  37.8  28.5
# 5                   37.0    42.9             29.9    27.3  29.4  37.7  19.9
#
#      Sprint Speed              Player Link
# Rk.
# 1            25.6  [/savant-player/457454]
# 2            28.2  [/savant-player/572114]
# 3            27.8  [/savant-player/608336]
# 4            26.5  [/savant-player/572761]
# 5            26.7  [/savant-player/457803]

# %%
fg_df.head()
# Out:
#                Name-Year wRC+
# 0  Michael Lorenzen-2015    0
# 1  Michael Lorenzen-2016    0
# 2  Michael Lorenzen-2017    0
# 3  Michael Lorenzen-2018    0
# 4  Michael Lorenzen-2019    0

# %% [markdown]
# Excellent, both are as expected.

# %% [markdown]
# ## Merge The DF's
# *Note: this code is originally from Project_2_Savant notebook, moving here to clean up the workflow.*

# %%
fg_df.rename(columns={'Name-Year':'Player_Year_ID'}, inplace=True)

# %%
fg_df.head(2)
# Out:
#           Player_Year_ID wRC+
# 0  Michael Lorenzen-2015    0
# 1  Michael Lorenzen-2016    0

# %% [markdown]
# Function to strip accent marks from names so they can all be mapped to the savant data:

# %%
def strip_accents(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
                   if unicodedata.category(c) != 'Mn')

# %%
player_list = fg_df.Player_Year_ID.to_list()

# %%
updated_names = [strip_accents(name).replace('?','e') for name in player_list]

# %%
updated_names
# Out:
# ['Michael Lorenzen-2015',
#  'Michael Lorenzen-2016',
#  'Michael Lorenzen-2017',
#  'Michael Lorenzen-2018',
#  'Michael Lorenzen-2019',
#  'Michael Lorenzen-2020',
#  'Luis Campusano-2015',
#  'Luis Campusano-2016',
#  'Luis Campusano-2017',
#  'Luis Campusano-2018',
#  'Luis Campusano-2019',
#  'Luis Campusano-2020',
#  'Billy McKinney-2015',
#  'Billy McKinney-2016',
#  'Billy McKinney-2017',
#  'Billy McKinney-2018',
#  'Billy McKinney-2019',
#  'Billy McKinney-2020',
#  'Rafael Marchan-2015',
#  'Rafael Marchan-2016',
#  'Rafael Marchan-2017',
#  'Rafael Marchan-2018',
#  'Rafael Marchan-2019',
#  'Rafael Marchan-2020',
#  'Travis Blankenhorn-2015',
#  'Travis Blankenhorn-2016',
#  'Travis Blankenhorn-2017',
#  'Travis Blankenhorn-2018',
#  'Travis Blankenhorn-2019',
#  'Travis Blankenhorn-2020',
#  'Yolmer Sanchez-2015',
#  'Yolmer Sanchez-2016',
#  'Yolmer Sanchez-2017',
#  'Yolmer Sanchez-2018',
#  'Yolmer Sanchez-2019',
#  'Yolmer Sanchez-2020',
#  'Andrew Stevenson-2015',
#  'Andrew Stevenson-2016',
#  'Andrew Stevenson-2017',
#  'Andrew Stevenson-2018',
#  'Andrew Stevenson-2019',
#  'Andrew Stevenson-2020',
#  'Austin Dean-2015',
#  'Austin Dean-2016',
#  'Austin Dean-2017',
#  'Austin Dean-2018',
#  'Austin Dean-2019',
#  'Austin Dean-2020',
#  'Juan Soto-2015',
#  'Juan Soto-2016',
#  'Juan Soto-2017',
#  'Juan Soto-2018',
#  'Juan Soto-2019',
#  'Juan Soto-2020',
#  "Ke'Bryan Hayes-2015",
#  "Ke'Bryan Hayes-2016",
#  "Ke'Bryan Hayes-2017",
#  "Ke'Bryan Hayes-2018",
#  "Ke'Bryan Hayes-2019",
#  "Ke'Bryan Hayes-2020",
#  'Sam Huff-2015',
#  'Sam Huff-2016',
#  'Sam Huff-2017',
#  'Sam Huff-2018',
#  'Sam Huff-2019',
#  'Sam Huff-2020',
#  'Freddie Freeman-2015',
#  'Freddie Freeman-2016',
#  'Freddie Freeman-2017',
#  'Freddie Freeman-2018',
#  'Freddie Freeman-2019',
#  'Freddie Freeman-2020',
#  'Eduardo Nunez-2015',
#  'Eduardo Nunez-2016',
#  'Eduardo Nunez-2017',
#  'Eduardo Nunez-2018',
#  'Eduardo Nunez-2019',
#  'Eduardo Nunez-2020',
#  'Oscar Hernandez-2015',
#  'Oscar Hernandez-2016',
#  'Oscar Hernandez-2017',
#  'Oscar Hernandez-2018',
#  'Oscar Hernandez-2019',
#  'Oscar Hernandez-2020',
#  'Marcell Ozuna-2015',
#  'Marcell Ozuna-2016',
#  'Marcell Ozuna-2017',
#  'Marcell Ozuna-2018',
#  'Marcell Ozuna-2019',
#  'Marcell Ozuna-2020',
#  "Brian O'Grady-2015",
#  "Brian O'Grady-2016",
#  "Brian O'Grady-2017",
#  "Brian O'Grady-2018",
#  "Brian O'Grady-2019",
#  "Brian O'Grady-2020",
#  'DJ LeMahieu-2015',
#  'DJ LeMahieu-2016',
#  'DJ LeMahieu-2017',
#  'DJ LeMahieu-2018',
#  'DJ LeMahieu-2019',
#  'DJ LeMahieu-2020',
#  'Randy Arozarena-2015',
#  'Randy Arozarena-2016',
#  'Randy Arozarena-2017',
#  'Randy Arozarena-2018',
#  'Randy Arozarena-2019',
#  'Randy Arozarena-2020',
#  'Brandon Belt-2015',
#  'Brandon Belt-2016',
#  'Brandon Belt-2017',
#  'Brandon Belt-2018',
#  'Brandon Belt-2019',
#  'Brandon Belt-2020',
#  'Tyler Stephenson-2015',
#  'Tyler Stephenson-2016',
#  'Tyler Stephenson-2017',
#  'Tyler Stephenson-2018',
#  'Tyler Stephenson-2019',
#  'Tyler Stephenson-2020',
#  'Alejandro Kirk-2015',
#  'Alejandro Kirk-2016',
#  'Alejandro Kirk-2017',
#  'Alejandro Kirk-2018',
#  'Alejandro Kirk-2019',
#  'Alejandro Kirk-2020',
#  'Jose Abreu-2015',
#  'Jose Abreu-2016',
#  'Jose Abreu-2017',
#  'Jose Abreu-2018',
#  'Jose Abreu-2019',
#  'Jose Abreu-2020',
#  'Dominic Smith-2015',
#  'Dominic Smith-2016',
#  'Dominic Smith-2017',
#  'Dominic Smith-2018',
#  'Dominic Smith-2019',
#  'Dominic Smith-2020',
#  'Jorge Ona-2015',
#  'Jorge Ona-2016',
#  'Jorge Ona-2017',
#  'Jorge Ona-2018',
#  'Jorge Ona-2019',
#  'Jorge Ona-2020',
#  'Mike Trout-2015',
#  'Mike Trout-2016',
#  'Mike Trout-2017',
#  'Mike Trout-2018',
#  'Mike Trout-2019',
#  'Mike Trout-2020',
#  'Ramon Urias-2015',
#  'Ramon Urias-2016',
#  'Ramon Urias-2017',
#  'Ramon Urias-2018',
#  'Ramon Urias-2019',
#  'Ramon Urias-2020',
#  'Nelson Cruz-2015',
#  'Nelson Cruz-2016',
#  'Nelson Cruz-2017',
#  'Nelson Cruz-2018',
#  'Nelson Cruz-2019',
#  'Nelson Cruz-2020',
#  'Jose  Ramirez-2015',
#  'Jose  Ramirez-2016',
#  'Jose  Ramirez-2017',
#  'Jose  Ramirez-2018',
#  'Jose  Ramirez-2019',
#  'Jose  Ramirez-2020',
#  'Will Smith-2015',
#  'Will Smith-2016',
#  'Will Smith-2017',
#  'Will Smith-2018',
#  'Will Smith-2019',
#  'Will Smith-2020',
#  'Salvador Perez-2015',
#  'Salvador Perez-2016',
#  'Salvador Perez-2017',
#  'Salvador Perez-2018',
#  'Salvador Perez-2019',
#  'Salvador Perez-2020',
#  'Elliot Soto-2015',
#  'Elliot Soto-2016',
#  'Elliot Soto-2017',
#  'Elliot Soto-2018',
#  'Elliot Soto-2019',
#  'Elliot Soto-2020',
#  'Brent Rooker-2015',
#  'Brent Rooker-2016',
#  'Brent Rooker-2017',
#  'Brent Rooker-2018',
#  'Brent Rooker-2019',
#  'Brent Rooker-2020',
#  'Jose Iglesias-2015',
#  'Jose Iglesias-2016',
#  'Jose Iglesias-2017',
#  'Jose Iglesias-2018',
#  'Jose Iglesias-2019',
#  'Jose Iglesias-2020',
#  'Mike Yastrzemski-2015',
#  'Mike Yastrzemski-2016',
#  'Mike Yastrzemski-2017',
#  'Mike Yastrzemski-2018',
#  'Mike Yastrzemski-2019',
#  'Mike Yastrzemski-2020',
#  'Yordan Alvarez-2015',
#  'Yordan Alvarez-2016',
#  'Yordan Alvarez-2017',
#  'Yordan Alvarez-2018',
#  'Yordan Alvarez-2019',
#  'Yordan Alvarez-2020',
#  'Ronald Acuna Jr.-2015',
#  'Ronald Acuna Jr.-2016',
#  'Ronald Acuna Jr.-2017',
#  'Ronald Acuna Jr.-2018',
#  'Ronald Acuna Jr.-2019',
#  'Ronald Acuna Jr.-2020',
#  'Phillip Evans-2015',
#  'Phillip Evans-2016',
#  'Phillip Evans-2017',
#  'Phillip Evans-2018',
#  'Phillip Evans-2019',
#  'Phillip Evans-2020',
#  'Jake Marisnick-2015',
#  'Jake Marisnick-2016',
#  'Jake Marisnick-2017',
#  'Jake Marisnick-2018',
#  'Jake Marisnick-2019',
#  'Jake Marisnick-2020',
#  'Trea Turner-2015',
#  'Trea Turner-2016',
#  'Trea Turner-2017',
#  'Trea Turner-2018',
#  'Trea Turner-2019',
#  'Trea Turner-2020',
#  'Michael Conforto-2015',
#  'Michael Conforto-2016',
#  'Michael Conforto-2017',
#  'Michael Conforto-2018',
#  'Michael Conforto-2019',
#  'Michael Conforto-2020',
#  'Mike Brosseau-2015',
#  'Mike Brosseau-2016',
#  'Mike Brosseau-2017',
#  'Mike Brosseau-2018',
#  'Mike Brosseau-2019',
#  'Mike Brosseau-2020',
#  'Anthony Rendon-2015',
#  'Anthony Rendon-2016',
#  'Anthony Rendon-2017',
#  'Anthony Rendon-2018',
#  'Anthony Rendon-2019',
#  'Anthony Rendon-2020',
#  'Cesar Puello-2015',
#  'Cesar Puello-2016',
#  'Cesar Puello-2017',
#  'Cesar Puello-2018',
#  'Cesar Puello-2019',
#  'Cesar Puello-2020',
#  'Jared Walsh-2015',
#  'Jared Walsh-2016',
#  'Jared Walsh-2017',
#  'Jared Walsh-2018',
#  'Jared Walsh-2019',
#  'Jared Walsh-2020',
#  'Wil Myers-2015',
#  'Wil Myers-2016',
#  'Wil Myers-2017',
#  'Wil Myers-2018',
#  'Wil Myers-2019',
#  'Wil Myers-2020',
#  'Luke Voit-2015',
#  'Luke Voit-2016',
#  'Luke Voit-2017',
#  'Luke Voit-2018',
#  'Luke Voit-2019',
#  'Luke Voit-2020',
#  'Bobby Dalbec-2015',
#  'Bobby Dalbec-2016',
#  'Bobby Dalbec-2017',
#  'Bobby Dalbec-2018',
#  'Bobby Dalbec-2019',
#  'Bobby Dalbec-2020',
#  'Austin Slater-2015',
#  'Austin Slater-2016',
#  'Austin Slater-2017',
#  'Austin Slater-2018',
#  'Austin Slater-2019',
#  'Austin Slater-2020',
#  'Corey Seager-2015',
#  'Corey Seager-2016',
#  'Corey Seager-2017',
#  'Corey Seager-2018',
#  'Corey Seager-2019',
#  'Corey Seager-2020',
#  'Alex Dickerson-2015',
#  'Alex Dickerson-2016',
#  'Alex Dickerson-2017',
#  'Alex Dickerson-2018',
#  'Alex Dickerson-2019',
#  'Alex Dickerson-2020',
#  'Willi Castro-2015',
#  'Willi Castro-2016',
#  'Willi Castro-2017',
#  'Willi Castro-2018',
#  'Willi Castro-2019',
#  'Willi Castro-2020',
#  'Bryce Harper-2015',
#  'Bryce Harper-2016',
#  'Bryce Harper-2017',
#  'Bryce Harper-2018',
#  'Bryce Harper-2019',
#  'Bryce Harper-2020',
#  'Brandon Lowe-2015',
#  'Brandon Lowe-2016',
#  'Brandon Lowe-2017',
#  'Brandon Lowe-2018',
#  'Brandon Lowe-2019',
#  'Brandon Lowe-2020',
#  'Tomas Nido-2015',
#  'Tomas Nido-2016',
#  'Tomas Nido-2017',
#  'Tomas Nido-2018',
#  'Tomas Nido-2019',
#  'Tomas Nido-2020',
#  'Clint Frazier-2015',
#  'Clint Frazier-2016',
#  'Clint Frazier-2017',
#  'Clint Frazier-2018',
#  'Clint Frazier-2019',
#  'Clint Frazier-2020',
#  'Fernando Tatis Jr.-2015',
#  'Fernando Tatis Jr.-2016',
#  'Fernando Tatis Jr.-2017',
#  'Fernando Tatis Jr.-2018',
#  'Fernando Tatis Jr.-2019',
#  'Fernando Tatis Jr.-2020',
#  'Deivy Grullon-2015',
#  'Deivy Grullon-2016',
#  'Deivy Grullon-2017',
#  'Deivy Grullon-2018',
#  'Deivy Grullon-2019',
#  'Deivy Grullon-2020',
#  'Mookie Betts-2015',
#  'Mookie Betts-2016',
#  'Mookie Betts-2017',
#  'Mookie Betts-2018',
#  'Mookie Betts-2019',
#  'Mookie Betts-2020',
#  'Manny Machado-2015',
#  'Manny Machado-2016',
#  'Manny Machado-2017',
#  'Manny Machado-2018',
#  'Manny Machado-2019',
#  'Manny Machado-2020',
#  'Brandon Nimmo-2015',
#  'Brandon Nimmo-2016',
#  'Brandon Nimmo-2017',
#  'Brandon Nimmo-2018',
#  'Brandon Nimmo-2019',
#  'Brandon Nimmo-2020',
#  'Teoscar Hernandez-2015',
#  'Teoscar Hernandez-2016',
#  'Teoscar Hernandez-2017',
#  'Teoscar Hernandez-2018',
#  'Teoscar Hernandez-2019',
#  'Teoscar Hernandez-2020',
#  'Jesse Winker-2015',
#  'Jesse Winker-2016',
#  'Jesse Winker-2017',
#  'Jesse Winker-2018',
#  'Jesse Winker-2019',
#  'Jesse Winker-2020',
#  'Paul Goldschmidt-2015',
#  'Paul Goldschmidt-2016',
#  'Paul Goldschmidt-2017',
#  'Paul Goldschmidt-2018',
#  'Paul Goldschmidt-2019',
#  'Paul Goldschmidt-2020',
#  'George Springer-2015',
#  'George Springer-2016',
#  'George Springer-2017',
#  'George Springer-2018',
#  'George Springer-2019',
#  'George Springer-2020',
#  'Edwin Rios-2015',
#  'Edwin Rios-2016',
#  'Edwin Rios-2017',
#  'Edwin Rios-2018',
#  'Edwin Rios-2019',
#  'Edwin Rios-2020',
#  "Travis d'Arnaud-2015",
#  "Travis d'Arnaud-2016",
#  "Travis d'Arnaud-2017",
#  "Travis d'Arnaud-2018",
#  "Travis d'Arnaud-2019",
#  "Travis d'Arnaud-2020",
#  'Jahmai Jones-2015',
#  'Jahmai Jones-2016',
#  'Jahmai Jones-2017',
#  'Jahmai Jones-2018',
#  'Jahmai Jones-2019',
#  'Jahmai Jones-2020',
#  'Luis Guillorme-2015',
#  'Luis Guillorme-2016',
#  'Luis Guillorme-2017',
#  'Luis Guillorme-2018',
#  'Luis Guillorme-2019',
#  'Luis Guillorme-2020',
#  'James McCann-2015',
#  'James McCann-2016',
#  'James McCann-2017',
#  'James McCann-2018',
#  'James McCann-2019',
#  'James McCann-2020',
#  'Giancarlo Stanton-2015',
#  'Giancarlo Stanton-2016',
#  'Giancarlo Stanton-2017',
#  'Giancarlo Stanton-2018',
#  'Giancarlo Stanton-2019',
#  'Giancarlo Stanton-2020',
#  'Tim Anderson-2015',
#  'Tim Anderson-2016',
#  'Tim Anderson-2017',
#  'Tim Anderson-2018',
#  'Tim Anderson-2019',
#  'Tim Anderson-2020',
#  'William Contreras-2015',
#  'William Contreras-2016',
#  'William Contreras-2017',
#  'William Contreras-2018',
#  'William Contreras-2019',
#  'William Contreras-2020',
#  'Miguel Rojas-2015',
#  'Miguel Rojas-2016',
#  'Miguel Rojas-2017',
#  'Miguel Rojas-2018',
#  'Miguel Rojas-2019',
#  'Miguel Rojas-2020',
#  'Darin Ruf-2015',
#  'Darin Ruf-2016',
#  'Darin Ruf-2017',
#  'Darin Ruf-2018',
#  'Darin Ruf-2019',
#  'Darin Ruf-2020',
#  'Robinson Cano-2015',
#  'Robinson Cano-2016',
#  'Robinson Cano-2017',
#  'Robinson Cano-2018',
#  'Robinson Cano-2019',
#  'Robinson Cano-2020',
#  'Eloy Jimenez-2015',
#  'Eloy Jimenez-2016',
#  'Eloy Jimenez-2017',
#  'Eloy Jimenez-2018',
#  'Eloy Jimenez-2019',
#  'Eloy Jimenez-2020',
#  'Justin Turner-2015',
#  'Justin Turner-2016',
#  'Justin Turner-2017',
#  'Justin Turner-2018',
#  'Justin Turner-2019',
#  'Justin Turner-2020',
#  'Aaron Judge-2015',
#  'Aaron Judge-2016',
#  'Aaron Judge-2017',
#  'Aaron Judge-2018',
#  'Aaron Judge-2019',
#  'Aaron Judge-2020',
#  'Rhys Hoskins-2015',
#  'Rhys Hoskins-2016',
#  'Rhys Hoskins-2017',
#  'Rhys Hoskins-2018',
#  'Rhys Hoskins-2019',
#  'Rhys Hoskins-2020',
#  'Ryan Mountcastle-2015',
#  'Ryan Mountcastle-2016',
#  'Ryan Mountcastle-2017',
#  'Ryan Mountcastle-2018',
#  'Ryan Mountcastle-2019',
#  'Ryan Mountcastle-2020',
#  'C.J. Cron-2015',
#  'C.J. Cron-2016',
#  'C.J. Cron-2017',
#  'C.J. Cron-2018',
#  'C.J. Cron-2019',
#  'C.J. Cron-2020',
#  'Max Stassi-2015',
#  'Max Stassi-2016',
#  'Max Stassi-2017',
#  'Max Stassi-2018',
#  'Max Stassi-2019',
#  'Max Stassi-2020',
#  'Dylan Moore-2015',
#  'Dylan Moore-2016',
#  'Dylan Moore-2017',
#  'Dylan Moore-2018',
#  'Dylan Moore-2019',
#  'Dylan Moore-2020',
#  'Alec Bohm-2015',
#  'Alec Bohm-2016',
#  'Alec Bohm-2017',
#  'Alec Bohm-2018',
#  'Alec Bohm-2019',
#  'Alec Bohm-2020',
#  'Lourdes Gurriel Jr.-2015',
#  'Lourdes Gurriel Jr.-2016',
#  'Lourdes Gurriel Jr.-2017',
#  'Lourdes Gurriel Jr.-2018',
#  'Lourdes Gurriel Jr.-2019',
#  'Lourdes Gurriel Jr.-2020',
#  'Yandy Diaz-2015',
#  'Yandy Diaz-2016',
#  'Yandy Diaz-2017',
#  'Yandy Diaz-2018',
#  'Yandy Diaz-2019',
#  'Yandy Diaz-2020',
#  'Jeimer Candelario-2015',
#  'Jeimer Candelario-2016',
#  'Jeimer Candelario-2017',
#  'Jeimer Candelario-2018',
#  'Jeimer Candelario-2019',
#  'Jeimer Candelario-2020',
#  'Rowdy Tellez-2015',
#  'Rowdy Tellez-2016',
#  'Rowdy Tellez-2017',
#  'Rowdy Tellez-2018',
#  'Rowdy Tellez-2019',
#  'Rowdy Tellez-2020',
#  'Mitch Moreland-2015',
#  'Mitch Moreland-2016',
#  'Mitch Moreland-2017',
#  'Mitch Moreland-2018',
#  'Mitch Moreland-2019',
#  'Mitch Moreland-2020',
#  'Kevan Smith-2015',
#  'Kevan Smith-2016',
#  'Kevan Smith-2017',
#  'Kevan Smith-2018',
#  'Kevan Smith-2019',
#  'Kevan Smith-2020',
#  'Tim Locastro-2015',
#  'Tim Locastro-2016',
#  'Tim Locastro-2017',
#  'Tim Locastro-2018',
#  'Tim Locastro-2019',
#  'Tim Locastro-2020',
#  'Luis Gonzalez-2015',
#  'Luis Gonzalez-2016',
#  'Luis Gonzalez-2017',
#  'Luis Gonzalez-2018',
#  'Luis Gonzalez-2019',
#  'Luis Gonzalez-2020',
#  'Harold Castro-2015',
#  'Harold Castro-2016',
#  'Harold Castro-2017',
#  'Harold Castro-2018',
#  'Harold Castro-2019',
#  'Harold Castro-2020',
#  'Michael Brantley-2015',
#  'Michael Brantley-2016',
#  'Michael Brantley-2017',
#  'Michael Brantley-2018',
#  'Michael Brantley-2019',
#  'Michael Brantley-2020',
#  'Kevin Plawecki-2015',
#  'Kevin Plawecki-2016',
#  'Kevin Plawecki-2017',
#  'Kevin Plawecki-2018',
#  'Kevin Plawecki-2019',
#  'Kevin Plawecki-2020',
#  'Gio Urshela-2015',
#  'Gio Urshela-2016',
#  'Gio Urshela-2017',
#  'Gio Urshela-2018',
#  'Gio Urshela-2019',
#  'Gio Urshela-2020',
#  'Garrett Cooper-2015',
#  'Garrett Cooper-2016',
#  'Garrett Cooper-2017',
#  'Garrett Cooper-2018',
#  'Garrett Cooper-2019',
#  'Garrett Cooper-2020',
#  'Andrew Knapp-2015',
#  'Andrew Knapp-2016',
#  'Andrew Knapp-2017',
#  'Andrew Knapp-2018',
#  'Andrew Knapp-2019',
#  'Andrew Knapp-2020',
#  'Ty France-2015',
#  'Ty France-2016',
#  'Ty France-2017',
#  'Ty France-2018',
#  'Ty France-2019',
#  'Ty France-2020',
#  'AJ Pollock-2015',
#  'AJ Pollock-2016',
#  'AJ Pollock-2017',
#  'AJ Pollock-2018',
#  'AJ Pollock-2019',
#  'AJ Pollock-2020',
#  'Chris Taylor-2015',
#  'Chris Taylor-2016',
#  'Chris Taylor-2017',
#  'Chris Taylor-2018',
#  'Chris Taylor-2019',
#  'Chris Taylor-2020',
#  'Sean Murphy-2015',
#  'Sean Murphy-2016',
#  'Sean Murphy-2017',
#  'Sean Murphy-2018',
#  'Sean Murphy-2019',
#  'Sean Murphy-2020',
#  'Ian Happ-2015',
#  'Ian Happ-2016',
#  'Ian Happ-2017',
#  'Ian Happ-2018',
#  'Ian Happ-2019',
#  'Ian Happ-2020',
#  'Curt Casali-2015',
#  'Curt Casali-2016',
#  'Curt Casali-2017',
#  'Curt Casali-2018',
#  'Curt Casali-2019',
#  'Curt Casali-2020',
#  'Anthony Santander-2015',
#  'Anthony Santander-2016',
#  'Anthony Santander-2017',
#  'Anthony Santander-2018',
#  'Anthony Santander-2019',
#  'Anthony Santander-2020',
#  'Jason Heyward-2015',
#  'Jason Heyward-2016',
#  'Jason Heyward-2017',
#  'Jason Heyward-2018',
#  'Jason Heyward-2019',
#  'Jason Heyward-2020',
#  'Jeff McNeil-2015',
#  'Jeff McNeil-2016',
#  'Jeff McNeil-2017',
#  'Jeff McNeil-2018',
#  'Jeff McNeil-2019',
#  'Jeff McNeil-2020',
#  'Xander Bogaerts-2015',
#  'Xander Bogaerts-2016',
#  'Xander Bogaerts-2017',
#  'Xander Bogaerts-2018',
#  'Xander Bogaerts-2019',
#  'Xander Bogaerts-2020',
#  'Josh Donaldson-2015',
#  'Josh Donaldson-2016',
#  'Josh Donaldson-2017',
#  'Josh Donaldson-2018',
#  'Josh Donaldson-2019',
#  'Josh Donaldson-2020',
#  'Tommy La Stella-2015',
#  'Tommy La Stella-2016',
#  'Tommy La Stella-2017',
#  'Tommy La Stella-2018',
#  'Tommy La Stella-2019',
#  'Tommy La Stella-2020',
#  'Keibert Ruiz-2015',
#  'Keibert Ruiz-2016',
#  'Keibert Ruiz-2017',
#  'Keibert Ruiz-2018',
#  'Keibert Ruiz-2019',
#  'Keibert Ruiz-2020',
#  'JaCoby Jones-2015',
#  'JaCoby Jones-2016',
#  'JaCoby Jones-2017',
#  'JaCoby Jones-2018',
#  'JaCoby Jones-2019',
#  'JaCoby Jones-2020',
#  'Donovan Solano-2015',
#  'Donovan Solano-2016',
#  'Donovan Solano-2017',
#  'Donovan Solano-2018',
#  'Donovan Solano-2019',
#  'Donovan Solano-2020',
#  'Mark Canha-2015',
#  'Mark Canha-2016',
#  'Mark Canha-2017',
#  'Mark Canha-2018',
#  'Mark Canha-2019',
#  'Mark Canha-2020',
#  'Eric Hosmer-2015',
#  'Eric Hosmer-2016',
#  'Eric Hosmer-2017',
#  'Eric Hosmer-2018',
#  'Eric Hosmer-2019',
#  'Eric Hosmer-2020',
#  'Cavan Biggio-2015',
#  'Cavan Biggio-2016',
#  'Cavan Biggio-2017',
#  'Cavan Biggio-2018',
#  'Cavan Biggio-2019',
#  'Cavan Biggio-2020',
#  'Robbie Grossman-2015',
#  'Robbie Grossman-2016',
#  'Robbie Grossman-2017',
#  'Robbie Grossman-2018',
#  'Robbie Grossman-2019',
#  'Robbie Grossman-2020',
#  'Austin Nola-2015',
#  'Austin Nola-2016',
#  'Austin Nola-2017',
#  'Austin Nola-2018',
#  'Austin Nola-2019',
#  'Austin Nola-2020',
#  'Alex Verdugo-2015',
#  'Alex Verdugo-2016',
#  'Alex Verdugo-2017',
#  'Alex Verdugo-2018',
#  'Alex Verdugo-2019',
#  'Alex Verdugo-2020',
#  'Kyle Lewis-2015',
#  'Kyle Lewis-2016',
#  'Kyle Lewis-2017',
#  'Kyle Lewis-2018',
#  'Kyle Lewis-2019',
#  'Kyle Lewis-2020',
#  'Kole Calhoun-2015',
#  'Kole Calhoun-2016',
#  'Kole Calhoun-2017',
#  'Kole Calhoun-2018',
#  'Kole Calhoun-2019',
#  'Kole Calhoun-2020',
#  'Kyle Tucker-2015',
#  'Kyle Tucker-2016',
#  'Kyle Tucker-2017',
#  'Kyle Tucker-2018',
#  'Kyle Tucker-2019',
#  'Kyle Tucker-2020',
#  'J.T. Realmuto-2015',
#  'J.T. Realmuto-2016',
#  'J.T. Realmuto-2017',
#  'J.T. Realmuto-2018',
#  'J.T. Realmuto-2019',
#  'J.T. Realmuto-2020',
#  'David Fletcher-2015',
#  'David Fletcher-2016',
#  'David Fletcher-2017',
#  'David Fletcher-2018',
#  'David Fletcher-2019',
#  'David Fletcher-2020',
#  'Jake Cronenworth-2015',
#  'Jake Cronenworth-2016',
#  'Jake Cronenworth-2017',
#  'Jake Cronenworth-2018',
#  'Jake Cronenworth-2019',
#  'Jake Cronenworth-2020',
#  'Brian Navarreto-2015',
#  'Brian Navarreto-2016',
#  'Brian Navarreto-2017',
#  'Brian Navarreto-2018',
#  'Brian Navarreto-2019',
#  'Brian Navarreto-2020',
#  'Bo Bichette-2015',
#  'Bo Bichette-2016',
#  'Bo Bichette-2017',
#  'Bo Bichette-2018',
#  'Bo Bichette-2019',
#  'Bo Bichette-2020',
#  'Willy Adames-2015',
#  'Willy Adames-2016',
#  'Willy Adames-2017',
#  'Willy Adames-2018',
#  'Willy Adames-2019',
#  'Willy Adames-2020',
#  'Francisco Cervelli-2015',
#  'Francisco Cervelli-2016',
#  'Francisco Cervelli-2017',
#  'Francisco Cervelli-2018',
#  'Francisco Cervelli-2019',
#  'Francisco Cervelli-2020',
#  'Aaron Hicks-2015',
#  'Aaron Hicks-2016',
#  'Aaron Hicks-2017',
#  'Aaron Hicks-2018',
#  'Aaron Hicks-2019',
#  'Aaron Hicks-2020',
#  'Yairo Munoz-2015',
#  'Yairo Munoz-2016',
#  'Yairo Munoz-2017',
#  'Yairo Munoz-2018',
#  'Yairo Munoz-2019',
#  'Yairo Munoz-2020',
#  'DJ Stewart-2015',
#  'DJ Stewart-2016',
#  'DJ Stewart-2017',
#  'DJ Stewart-2018',
#  'DJ Stewart-2019',
#  'DJ Stewart-2020',
#  'Jonathan Davis-2015',
#  'Jonathan Davis-2016',
#  'Jonathan Davis-2017',
#  'Jonathan Davis-2018',
#  'Jonathan Davis-2019',
#  'Jonathan Davis-2020',
#  'Adam Engel-2015',
#  'Adam Engel-2016',
#  'Adam Engel-2017',
#  'Adam Engel-2018',
#  'Adam Engel-2019',
#  'Adam Engel-2020',
#  'Alex Bregman-2015',
#  'Alex Bregman-2016',
#  'Alex Bregman-2017',
#  'Alex Bregman-2018',
#  'Alex Bregman-2019',
#  'Alex Bregman-2020',
#  'Brian Anderson-2015',
#  'Brian Anderson-2016',
#  'Brian Anderson-2017',
#  'Brian Anderson-2018',
#  'Brian Anderson-2019',
#  'Brian Anderson-2020',
#  'Derek Fisher-2015',
#  'Derek Fisher-2016',
#  'Derek Fisher-2017',
#  'Derek Fisher-2018',
#  'Derek Fisher-2019',
#  'Derek Fisher-2020',
#  'Jesus Aguilar-2015',
#  'Jesus Aguilar-2016',
#  'Jesus Aguilar-2017',
#  'Jesus Aguilar-2018',
#  'Jesus Aguilar-2019',
#  'Jesus Aguilar-2020',
#  'Wyatt Mathisen-2015',
#  'Wyatt Mathisen-2016',
#  'Wyatt Mathisen-2017',
#  'Wyatt Mathisen-2018',
#  'Wyatt Mathisen-2019',
#  'Wyatt Mathisen-2020',
#  'Brad Miller-2015',
#  'Brad Miller-2016',
#  'Brad Miller-2017',
#  'Brad Miller-2018',
#  'Brad Miller-2019',
#  'Brad Miller-2020',
#  'Wilmer Flores-2015',
#  'Wilmer Flores-2016',
#  'Wilmer Flores-2017',
#  'Wilmer Flores-2018',
#  'Wilmer Flores-2019',
#  'Wilmer Flores-2020',
#  'Trent Grisham-2015',
#  'Trent Grisham-2016',
#  'Trent Grisham-2017',
#  'Trent Grisham-2018',
#  'Trent Grisham-2019',
#  'Trent Grisham-2020',
#  'Andrew Susac-2015',
#  'Andrew Susac-2016',
#  'Andrew Susac-2017',
#  'Andrew Susac-2018',
#  'Andrew Susac-2019',
#  'Andrew Susac-2020',
#  'Jackie Bradley Jr.-2015',
#  'Jackie Bradley Jr.-2016',
#  'Jackie Bradley Jr.-2017',
#  'Jackie Bradley Jr.-2018',
#  'Jackie Bradley Jr.-2019',
#  'Jackie Bradley Jr.-2020',
#  'Ryan Jeffers-2015',
#  'Ryan Jeffers-2016',
#  'Ryan Jeffers-2017',
#  'Ryan Jeffers-2018',
#  'Ryan Jeffers-2019',
#  'Ryan Jeffers-2020',
#  'Daniel Robertson-2015',
#  'Daniel Robertson-2016',
#  'Daniel Robertson-2017',
#  'Daniel Robertson-2018',
#  'Daniel Robertson-2019',
#  'Daniel Robertson-2020',
#  'Lorenzo Cain-2015',
#  'Lorenzo Cain-2016',
#  'Lorenzo Cain-2017',
#  'Lorenzo Cain-2018',
#  'Lorenzo Cain-2019',
#  'Lorenzo Cain-2020',
#  'Pete Alonso-2015',
#  'Pete Alonso-2016',
#  'Pete Alonso-2017',
#  'Pete Alonso-2018',
#  'Pete Alonso-2019',
#  'Pete Alonso-2020',
#  'Renato Nunez-2015',
#  'Renato Nunez-2016',
#  'Renato Nunez-2017',
#  'Renato Nunez-2018',
#  'Renato Nunez-2019',
#  'Renato Nunez-2020',
#  'Byron Buxton-2015',
#  'Byron Buxton-2016',
#  'Byron Buxton-2017',
#  'Byron Buxton-2018',
#  'Byron Buxton-2019',
#  'Byron Buxton-2020',
#  'Kyle Seager-2015',
#  'Kyle Seager-2016',
#  'Kyle Seager-2017',
#  'Kyle Seager-2018',
#  'Kyle Seager-2019',
#  'Kyle Seager-2020',
#  'Jedd Gyorko-2015',
#  'Jedd Gyorko-2016',
#  'Jedd Gyorko-2017',
#  'Jedd Gyorko-2018',
#  'Jedd Gyorko-2019',
#  'Jedd Gyorko-2020',
#  'Andy Young-2015',
#  'Andy Young-2016',
#  'Andy Young-2017',
#  'Andy Young-2018',
#  'Andy Young-2019',
#  'Andy Young-2020',
#  'Trevor Story-2015',
#  'Trevor Story-2016',
#  'Trevor Story-2017',
#  'Trevor Story-2018',
#  'Trevor Story-2019',
#  'Trevor Story-2020',
#  'J.D. Davis-2015',
#  'J.D. Davis-2016',
#  'J.D. Davis-2017',
#  'J.D. Davis-2018',
#  'J.D. Davis-2019',
#  'J.D. Davis-2020',
#  'Yasmani Grandal-2015',
#  'Yasmani Grandal-2016',
#  'Yasmani Grandal-2017',
#  'Yasmani Grandal-2018',
#  'Yasmani Grandal-2019',
#  'Yasmani Grandal-2020',
#  'Cam Gallagher-2015',
#  'Cam Gallagher-2016',
#  'Cam Gallagher-2017',
#  'Cam Gallagher-2018',
#  'Cam Gallagher-2019',
#  'Cam Gallagher-2020',
#  'Didi Gregorius-2015',
#  'Didi Gregorius-2016',
#  'Didi Gregorius-2017',
#  'Didi Gregorius-2018',
#  'Didi Gregorius-2019',
#  'Didi Gregorius-2020',
#  'Dansby Swanson-2015',
#  'Dansby Swanson-2016',
#  'Dansby Swanson-2017',
#  'Dansby Swanson-2018',
#  'Dansby Swanson-2019',
#  'Dansby Swanson-2020',
#  'Matt Chapman-2015',
#  'Matt Chapman-2016',
#  'Matt Chapman-2017',
#  'Matt Chapman-2018',
#  'Matt Chapman-2019',
#  'Matt Chapman-2020',
#  'Adam Duvall-2015',
#  'Adam Duvall-2016',
#  'Adam Duvall-2017',
#  'Adam Duvall-2018',
#  'Adam Duvall-2019',
#  'Adam Duvall-2020',
#  'Joey Wendle-2015',
#  'Joey Wendle-2016',
#  'Joey Wendle-2017',
#  'Joey Wendle-2018',
#  'Joey Wendle-2019',
#  'Joey Wendle-2020',
#  'Christian Vazquez-2015',
#  'Christian Vazquez-2016',
#  'Christian Vazquez-2017',
#  'Christian Vazquez-2018',
#  'Christian Vazquez-2019',
#  'Christian Vazquez-2020',
#  'Vladimir Guerrero Jr.-2015',
#  'Vladimir Guerrero Jr.-2016',
#  'Vladimir Guerrero Jr.-2017',
#  'Vladimir Guerrero Jr.-2018',
#  'Vladimir Guerrero Jr.-2019',
#  'Vladimir Guerrero Jr.-2020',
#  'Jon Berti-2015',
#  'Jon Berti-2016',
#  'Jon Berti-2017',
#  'Jon Berti-2018',
#  'Jon Berti-2019',
#  'Jon Berti-2020',
#  'Jonathan Schoop-2015',
#  'Jonathan Schoop-2016',
#  'Jonathan Schoop-2017',
#  'Jonathan Schoop-2018',
#  'Jonathan Schoop-2019',
#  'Jonathan Schoop-2020',
#  'Derek Dietrich-2015',
#  'Derek Dietrich-2016',
#  'Derek Dietrich-2017',
#  'Derek Dietrich-2018',
#  ...]

# %%
fg_df.Player_Year_ID = updated_names

# %% [markdown]
# Back to Baseball Savant:

# %%
player_list = savant_df.Player.tolist()

# %%
player_list_split = [player.split(', ') for player in player_list]
for player in player_list_split:
    player[0] = player[0].strip()

final_player_list = [(player[1] + ' ' + player[0]) for player in player_list_split]

# %%
print(final_player_list)
# Out:
# ['Jarrod Saltalamacchia', 'Ryan Schimpf', 'Joey Gallo', 'Matt Carpenter', 'Jay Bruce', 'Matt Carpenter', 'Joey Gallo', 'Eric Thames', 'Cavan Biggio', 'Rhys Hoskins', 'Joey Gallo', 'Greg Bird', 'Mike Trout', 'Mike Napoli', 'Kyle Seager', 'Mitch Garver', 'Eric Thames', 'Stephen Vogt', 'Jay Bruce', 'Jake Marisnick', 'Brandon Belt', 'Robinson Chirinos', 'Matt Carpenter', 'Nick Castellanos', 'Mike Trout', 'Adam Duvall', 'Chris Davis', 'Rhys Hoskins', 'Miguel Sano', 'Chris Carter', 'Adam Duvall', 'Robinson Chirinos', 'Justin Turner', 'Matt Carpenter', 'Luis Valbuena', 'Lucas Duda', 'Rhys Hoskins', 'Colby Rasmus', 'Eduardo Escobar', 'Brandon Belt', 'Chris Carter', 'Kyle Seager', 'Max Muncy', 'Austin Riley', 'Travis Shaw', 'Mike Trout', 'Miguel Sano', 'Aaron Judge', 'Freddie Freeman', 'Brandon Moss', 'Curtis Granderson', 'Colby Rasmus', 'Hunter Renfroe', 'Luis Valbuena', 'Jay Bruce', 'Joey Votto', 'Tom Murphy', 'Khris Davis', 'Christin Stewart', 'Gary Sanchez', 'Kyle Seager', 'ByungHo Park', 'Brandon Moss', 'Daniel Descalso', 'Miguel Sano', 'Matt Adams', 'Ryan Howard', 'Brandon Belt', 'Anthony Rendon', 'Evan Gattis', 'Teoscar Hernandez', 'Ozzie Albies', 'J.D. Martinez', 'Gleyber Torres', 'Kyle Seager', 'John Ryan Murphy', 'Matt Chapman', 'Nick Castellanos', 'Jesus Aguilar', 'Yoenis Cespedes', 'John Jaso', 'Curt Casali', 'J.D. Martinez', 'Eugenio Suarez', 'Mookie Betts', 'Brandon Lowe', 'Isan Diaz', 'Alejandro De Aza', 'Aristides Aquino', 'Jake Lamb', 'Rene Rivera', 'Jake Marisnick', 'Kris Bryant', 'Chris Carter', 'Jose Ramirez', 'Mitch Haniger', 'Jason Castro', 'Edwin Encarnacion', 'Matt Davidson', 'Mike Zunino', 'Clint Frazier', 'Corey Dickerson', 'James McCann', 'Stephen Vogt', 'Matt Olson', 'Kris Bryant', 'Teoscar Hernandez', 'Joey Rickard', 'Salvador Perez', 'Kyle Schwarber', 'Tyler Moore', 'Yordan Alvarez', 'Brian Dozier', 'Adam Rosales', 'Evan Longoria', 'Michael Conforto', 'Salvador Perez', 'Miguel Montero', 'Lucas Duda', 'Eugenio Suarez', 'David Ross', 'Tony Kemp', 'Mookie Betts', 'Lonnie Chisenhall', 'Curtis Granderson', 'Cody Bellinger', 'Justin Smoak', 'Trevor Story', 'Kris Bryant', 'Curtis Granderson', 'Jed Lowrie', 'Justin Smoak', 'Matt Olson', 'Yan Gomes', 'Logan Morrison', 'Chris Davis', 'Eugenio Suarez', 'Tyler Austin', 'Kendrys Morales', 'Travis Shaw', 'Jed Lowrie', 'Brandon Moss', 'Cavan Biggio', 'Anthony Rendon', 'Joey Votto', 'Brian McCann', 'Lucas Duda', 'Edwin Encarnacion', 'Gleyber Torres', 'Alex Bregman', 'Curtis Granderson', 'Cody Bellinger', 'Justin Turner', 'Alex Bregman', 'Brandon Belt', 'Wilmer Flores', 'Joey Votto', 'Max Kepler', 'Brian Dozier', 'Max Muncy', 'Justin Turner', 'Chris Davis', 'Jett Bandy', 'Joey Gallo', 'Carson Kelly', 'Jose Ramirez', 'Eddie Rosario', 'Paul Goldschmidt', 'Eric Thames', 'Justin Smoak', 'Chris Iannetta', 'Eduardo Escobar', 'Austin Meadows', 'Michael Conforto', 'Matt Adams', 'Edwin Encarnacion', 'Gregory Polanco', 'Todd Frazier', 'Eduardo Escobar', 'Matt Joyce', 'Jedd Gyorko', 'Randal Grichuk', 'Erik Kratz', 'Neil Walker', 'Ronald Acuna Jr.', 'Justin Smoak', 'Justin Upton', 'Christian Villanueva', 'Scott Kingery', 'Daniel Vogelbach', 'Brian Goodwin', 'Steve Pearce', 'Eddie Rosario', 'Marcus Semien', 'Max Kepler', 'Leonys Martin', 'Travis Shaw', 'Austin Hedges', 'Mike Yastrzemski', 'Mike Trout', 'Yonder Alonso', 'Will Middlebrooks', 'Dylan Moore', 'Jorge Polanco', 'Marcus Semien', 'Dioner Navarro', 'Adam Duvall', 'Manny Pina', 'Matt Carpenter', 'Trevor Story', 'AJ Pollock', 'Mark Reynolds', 'Kurt Suzuki', 'Josh VanMeter', 'Rougned Odor', 'Brian Dozier', 'Mark Canha', 'Yan Gomes', 'Kyle Schwarber', 'Nick Castellanos', 'Chris Young', 'Francisco Lindor', 'Chris Herrmann', 'Kurt Suzuki', 'Brian McCann', 'Kole Calhoun', 'Kurt Suzuki', 'Joc Pederson', 'Brad Miller', 'Jason Kipnis', 'Chris Davis', 'Bryce Harper', 'Matt Adams', 'Khris Davis', 'J.D. Martinez', 'Paul DeJong', 'Aaron Judge', 'Jordan Luplow', 'Kris Bryant', 'Khris Davis', 'Adam Duvall', 'Alex Gordon', 'Ian Kinsler', 'Mike Z ...

# %%
year_list = savant_df.Year.tolist()

# %%
year_list = [int(year) for year in year_list]
print(year_list)
# Out:
# [2016, 2016, 2017, 2018, 2019, 2017, 2018, 2018, 2019, 2017, 2019, 2018, 2019, 2017, 2017, 2019, 2019, 2019, 2018, 2017, 2018, 2017, 2019, 2016, 2020, 2018, 2016, 2018, 2018, 2017, 2020, 2018, 2017, 2016, 2018, 2017, 2019, 2016, 2019, 2019, 2015, 2020, 2018, 2019, 2019, 2018, 2016, 2017, 2017, 2017, 2019, 2015, 2019, 2017, 2017, 2020, 2019, 2018, 2019, 2019, 2019, 2016, 2016, 2018, 2019, 2016, 2016, 2017, 2017, 2018, 2019, 2017, 2015, 2018, 2018, 2018, 2017, 2015, 2018, 2017, 2017, 2019, 2017, 2019, 2018, 2019, 2019, 2016, 2019, 2019, 2017, 2018, 2016, 2016, 2018, 2019, 2019, 2019, 2017, 2018, 2019, 2016, 2016, 2016, 2017, 2015, 2018, 2018, 2018, 2017, 2017, 2019, 2016, 2016, 2016, 2016, 2017, 2017, 2015, 2018, 2016, 2019, 2019, 2017, 2015, 2019, 2019, 2017, 2017, 2017, 2018, 2018, 2019, 2019, 2017, 2015, 2020, 2018, 2018, 2016, 2015, 2015, 2020, 2019, 2019, 2016, 2018, 2018, 2019, 2016, 2016, 2017, 2018, 2019, 2016, 2017, 2017, 2019, 2019, 2019, 2019, 2019, 2016, 2020, 2019, 2019, 2019, 2019, 2017, 2017, 2015, 2018, 2019, 2019, 2019, 2017, 2018, 2018, 2017, 2017, 2018, 2018, 2018, 2018, 2019, 2016, 2017, 2018, 2018, 2019, 2019, 2015, 2020, 2020, 2018, 2018, 2018, 2019, 2019, 2017, 2017, 2015, 2019, 2019, 2016, 2016, 2017, 2017, 2015, 2018, 2018, 2018, 2018, 2019, 2019, 2017, 2020, 2018, 2019, 2019, 2016, 2017, 2017, 2017, 2015, 2018, 2019, 2018, 2018, 2018, 2018, 2019, 2017, 2017, 2020, 2018, 2018, 2019, 2019, 2019, 2016, 2016, 2016, 2017, 2017, 2017, 2015, 2018, 2018, 2016, 2016, 2015, 2015, 2015, 2018, 2018, 2019, 2019, 2019, 2019, 2017, 2017, 2018, 2019, 2019, 2019, 2016, 2016, 2017, 2018, 2018, 2019, 2019, 2019, 2019, 2015, 2015, 2015, 2018, 2019, 2019, 2019, 2019, 2017, 2017, 2017, 2018, 2018, 2019, 2019, 2019, 2016, 2017, 2015, 2015, 2015, 2018, 2018, 2018, 2019, 2016, 2016, 2017, 2017, 2015, 2018, 2018, 2019, 2019, 2019, 2016, 2015, 2019, 2016, 2016, 2018, 2019, 2019, 2016, 2017, 2017, 2015, 2018, 2018, 2018, 2019, 2019, 2016, 2016, 2016, 2016, 2017, 2018, 2019, 2015, 2020, 2020, 2018, 2018, 2019, 2019, 2019, 2019, 2019, 2017, 2019, 2019, 2019, 2019, 2016, 2017, 2017, 2015, 2020, 2018, 2018, 2019, 2016, 2017, 2015, 2015, 2020, 2020, 2020, 2018, 2019, 2019, 2019, 2016, 2018, 2018, 2019, 2019, 2016, 2017, 2017, 2017, 2018, 2018, 2019, 2019, 2016, 2016, 2016, 2020, 2018, 2019, 2019, 2019, 2019, 2016, 2016, 2017, 2017, 2015, 2015, 2015, 2015, 2018, 2018, 2018, 2018, 2019, 2019, 2019, 2016, 2016, 2016, 2017, 2017, 2017, 2017, 2015, 2018, 2018, 2018, 2018, 2018, 2019, 2016, 2017, 2015, 2018, 2018, 2019, 2019, 2019, 2016, 2016, 2015, 2015, 2018, 2018, 2019, 2019, 2016, 2017, 2017, 2017, 2015, 2018, 2019, 2019, 2019, 2019, 2016, 2016, 2016, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2020, 2018, 2018, 2019, 2019, 2016, 2016, 2016, 2016, 2017, 2017, 2015, 2015, 2015, 2015, 2020, 2020, 2018, 2018, 2018, 2019, 2016, 2017, 2015, 2020, 2018, 2019, 2019, 2019, 2019, 2016, 2017, 2017, 2015, 2020, 2018, 2018, 2018, 2018, 2019, 2017, 2015, 2015, 2018, 2018, 2018, 2018, 2019, 2019, 2019, 2016, 2017, 2017, 2015, 2015, 2015, 2015, 2015, 2015, 2018, 2018, 2019, 2019, 2019, 2017, 2017, 2017, 2015, 2015, 2020, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2016, 2016, 2016, 2017, 2017, 2017, 2015, 2018, 2018, 2018, 2019, 2019, 2019, 2015, 2018, 2019, 2019, 2019, 2019, 2019, 2016, 2016, 2016, 2017, 2015, 2015, 2018, 2019, 2019, 2016, 2016, 2017, 2017, 2017, 2015, 2015, 2020, 2020, 2018, 2018, 2018, 2018, 2019, 2019, 2017, 2017, 2017, 2015, 2020, 2020, 2018, 2019, 2017, 2015, 2015, 2020, 2018, 2018, 2018, 2019, 2019, 2016, 2016, 2017, 2017, 2017, 2017, 2017, 2020, 2020, 2018, 2018, 2018, 2018, 2019, 2019, 2019, 2016, 2016, 2017, 2017, 2020, 2018, 2018, 2018, 2019, 2016, 2016, 2016, 2016, 2016, 2017, 2017, 2017, 2017, 2017, 2015, 2020, 2018, 2019, 2019, 2016, 2016, 2016, 2017, 2017, 2015, 2015, 2020, 2020, 2018, 2018, 2018, 2019, 2019, 2016, 2016, 2016, 2016, 2017, 2017, 2017, 2017, 2017, 2015, 2015, 2015, 2020, 2018, 2018, 2018, 2018, 2019, 2019, 201 ...

# %%
player_year_id = []
for i, player in enumerate(final_player_list):
    id_str = player + "-" + str(year_list[i])
    player_year_id.append(id_str)
print(player_year_id)
# Out:
# ['Jarrod Saltalamacchia-2016', 'Ryan Schimpf-2016', 'Joey Gallo-2017', 'Matt Carpenter-2018', 'Jay Bruce-2019', 'Matt Carpenter-2017', 'Joey Gallo-2018', 'Eric Thames-2018', 'Cavan Biggio-2019', 'Rhys Hoskins-2017', 'Joey Gallo-2019', 'Greg Bird-2018', 'Mike Trout-2019', 'Mike Napoli-2017', 'Kyle Seager-2017', 'Mitch Garver-2019', 'Eric Thames-2019', 'Stephen Vogt-2019', 'Jay Bruce-2018', 'Jake Marisnick-2017', 'Brandon Belt-2018', 'Robinson Chirinos-2017', 'Matt Carpenter-2019', 'Nick Castellanos-2016', 'Mike Trout-2020', 'Adam Duvall-2018', 'Chris Davis-2016', 'Rhys Hoskins-2018', 'Miguel Sano-2018', 'Chris Carter-2017', 'Adam Duvall-2020', 'Robinson Chirinos-2018', 'Justin Turner-2017', 'Matt Carpenter-2016', 'Luis Valbuena-2018', 'Lucas Duda-2017', 'Rhys Hoskins-2019', 'Colby Rasmus-2016', 'Eduardo Escobar-2019', 'Brandon Belt-2019', 'Chris Carter-2015', 'Kyle Seager-2020', 'Max Muncy-2018', 'Austin Riley-2019', 'Travis Shaw-2019', 'Mike Trout-2018', 'Miguel Sano-2016', 'Aaron Judge-2017', 'Freddie Freeman-2017', 'Brandon Moss-2017', 'Curtis Granderson-2019', 'Colby Rasmus-2015', 'Hunter Renfroe-2019', 'Luis Valbuena-2017', 'Jay Bruce-2017', 'Joey Votto-2020', 'Tom Murphy-2019', 'Khris Davis-2018', 'Christin Stewart-2019', 'Gary Sanchez-2019', 'Kyle Seager-2019', 'ByungHo Park-2016', 'Brandon Moss-2016', 'Daniel Descalso-2018', 'Miguel Sano-2019', 'Matt Adams-2016', 'Ryan Howard-2016', 'Brandon Belt-2017', 'Anthony Rendon-2017', 'Evan Gattis-2018', 'Teoscar Hernandez-2019', 'Ozzie Albies-2017', 'J.D. Martinez-2015', 'Gleyber Torres-2018', 'Kyle Seager-2018', 'John Ryan Murphy-2018', 'Matt Chapman-2017', 'Nick Castellanos-2015', 'Jesus Aguilar-2018', 'Yoenis Cespedes-2017', 'John Jaso-2017', 'Curt Casali-2019', 'J.D. Martinez-2017', 'Eugenio Suarez-2019', 'Mookie Betts-2018', 'Brandon Lowe-2019', 'Isan Diaz-2019', 'Alejandro De Aza-2016', 'Aristides Aquino-2019', 'Jake Lamb-2019', 'Rene Rivera-2017', 'Jake Marisnick-2018', 'Kris Bryant-2016', 'Chris Carter-2016', 'Jose Ramirez-2018', 'Mitch Haniger-2019', 'Jason Castro-2019', 'Edwin Encarnacion-2019', 'Matt Davidson-2017', 'Mike Zunino-2018', 'Clint Frazier-2019', 'Corey Dickerson-2016', 'James McCann-2016', 'Stephen Vogt-2016', 'Matt Olson-2017', 'Kris Bryant-2015', 'Teoscar Hernandez-2018', 'Joey Rickard-2018', 'Salvador Perez-2018', 'Kyle Schwarber-2017', 'Tyler Moore-2017', 'Yordan Alvarez-2019', 'Brian Dozier-2016', 'Adam Rosales-2016', 'Evan Longoria-2016', 'Michael Conforto-2016', 'Salvador Perez-2017', 'Miguel Montero-2017', 'Lucas Duda-2015', 'Eugenio Suarez-2018', 'David Ross-2016', 'Tony Kemp-2019', 'Mookie Betts-2019', 'Lonnie Chisenhall-2017', 'Curtis Granderson-2015', 'Cody Bellinger-2019', 'Justin Smoak-2019', 'Trevor Story-2017', 'Kris Bryant-2017', 'Curtis Granderson-2017', 'Jed Lowrie-2018', 'Justin Smoak-2018', 'Matt Olson-2019', 'Yan Gomes-2019', 'Logan Morrison-2017', 'Chris Davis-2015', 'Eugenio Suarez-2020', 'Tyler Austin-2018', 'Kendrys Morales-2018', 'Travis Shaw-2016', 'Jed Lowrie-2015', 'Brandon Moss-2015', 'Cavan Biggio-2020', 'Anthony Rendon-2019', 'Joey Votto-2019', 'Brian McCann-2016', 'Lucas Duda-2018', 'Edwin Encarnacion-2018', 'Gleyber Torres-2019', 'Alex Bregman-2016', 'Curtis Granderson-2016', 'Cody Bellinger-2017', 'Justin Turner-2018', 'Alex Bregman-2019', 'Brandon Belt-2016', 'Wilmer Flores-2017', 'Joey Votto-2017', 'Max Kepler-2019', 'Brian Dozier-2019', 'Max Muncy-2019', 'Justin Turner-2019', 'Chris Davis-2019', 'Jett Bandy-2016', 'Joey Gallo-2020', 'Carson Kelly-2019', 'Jose Ramirez-2019', 'Eddie Rosario-2019', 'Paul Goldschmidt-2019', 'Eric Thames-2017', 'Justin Smoak-2017', 'Chris Iannetta-2015', 'Eduardo Escobar-2018', 'Austin Meadows-2019', 'Michael Conforto-2019', 'Matt Adams-2019', 'Edwin Encarnacion-2017', 'Gregory Polanco-2018', 'Todd Frazier-2018', 'Eduardo Escobar-2017', 'Matt Joyce-2017', 'Jedd Gyorko-2018', 'Randal Grichuk-2018', 'Erik Kratz-2018', 'Neil Walker-2018', 'Ronald Acuna Jr.-2019', 'Justin Smoak-2016', 'Justin ...

# %%
savant_df['Player_Year_ID'] = player_year_id

# %%
savant_df.sample(15)
# Out:
#                   Player    Year   Age     PA      G  Avg EV (MPH)  \
# Rk.
# 1764       Freese, David  2015.0  32.0  470.0  121.0          89.1
# 156       Flores, Wilmer  2017.0  26.0  362.0  110.0          87.6
# 860    Souza Jr., Steven  2018.0  29.0  272.0   72.0          88.7
# 158          Kepler, Max  2019.0  26.0  596.0  134.0          89.7
# 796       Pujols, Albert  2017.0  37.0  636.0  149.0          88.7
# 178        Frazier, Todd  2018.0  32.0  472.0  115.0          89.6
# 1220       Owings, Chris  2015.0  24.0  552.0  147.0          86.9
# 555         Suzuki, Kurt  2016.0  33.0  373.0  106.0          87.3
# 975     Lucroy, Jonathan  2019.0  33.0  328.0  101.0          86.9
# 1865      Morse, Michael  2015.0  33.0  256.0   98.0          90.3
# 1010      Johnson, Chris  2016.0  32.0  264.0  113.0          90.6
# 1668          Bell, Josh  2020.0  28.0  223.0   57.0          91.7
# 488      Iannetta, Chris  2017.0  34.0  316.0   89.0          87.8
# 935      Cabrera, Miguel  2019.0  36.0  549.0  136.0          90.3
# 217          Canha, Mark  2020.0  31.0  243.0   59.0          89.7
#
#       Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  ...  \
# Rk.                                                     ...
# 1764         6.4      7.2              6.9        38.4  ...
# 156         16.9      5.9              5.6        34.2  ...
# 860         16.2      7.8              6.0        39.8  ...
# 158         18.2      8.9              7.5        42.1  ...
# 796         13.4      5.4              7.7        39.0  ...
# 178         18.6      6.9              7.6        36.9  ...
# 1220        14.6      2.6              3.9        24.7  ...
# 555         14.5      2.6              5.0        30.5  ...
# 975         12.5      2.9              6.9        32.5  ...
# 1865         0.4      9.8              4.6        39.2  ...
# 1010        11.5      4.8              7.2        42.8  ...
# 1668         5.9      8.6              3.6        42.9  ...
# 488         15.3      8.6              6.5        36.6  ...
# 935         12.3      6.4              7.2        44.7  ...
# 217         19.4      7.7              8.5        39.4  ...
#
#       Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# Rk.
# 1764                 28.9    31.6             38.4    30.0  55.0  15.0  25.6
# 156                  31.1    35.4             36.1    28.5  35.8  29.9  25.3
# 860                  22.2    37.3             37.3    25.3  38.0  22.9  28.9
# 158                  27.6    50.8             30.1    19.1  35.9  29.8  21.7
# 796                  32.0    37.9             43.1    19.0  43.5  23.4  25.0
# 178                  24.4    46.1             33.9    20.1  35.9  29.6  22.7
# 1220                 35.3    35.7             36.2    28.1  44.1  20.2  29.4
# 555                  28.8    39.7             35.8    24.5  40.7  25.2  23.8
# 975                  24.7    36.7             40.0    23.3  46.1  22.0  23.7
# 1865                 30.5    35.3             34.0    30.7  59.5  12.4  28.1
# 1010                 31.6    37.3             33.1    29.5  45.8  21.7  29.5
# 1668                 26.9    36.4             37.1    26.4  56.4  16.4  22.9
# 488                  20.0    34.9             37.1    28.0  38.2  25.8  25.3
# 935                  33.9    30.0             37.2    32.8  44.9  22.3  27.9
# 217                  19.3    39.4             38.7    21.8  33.8  28.9  28.9
#
#       Sprint Speed              Player Link         Player_Year_ID
# Rk.
# 1764          26.7  [/savant-player/501896]      David Freese-2015
# 156           25.7  [/savant-player/527038]     Wilmer Flores-2017
# 860           28.1  [/savant-player/519306]  Steven Souza Jr.-2018
# 158           27.7  [/savant-player/596146]        Max Kepler-2019
# 796           21.9  [/savant-player/405395]     Albert Pujols-2017
# 178           25.6  [/savant-player/453943]      Todd Frazier-2018
# 1220          28.6  [/savant-player/572008]      Chris Owings-2015
# 555           25.4  [/savant-player/435559]       Kurt Suzuki-2016
# 975           25.4  [/savant-player/518960]   Jonathan Lucroy-2019
# 1865          24.6  [/savant-player/434604]     Michael Morse-2015
# 1010          26.2  [/savant-player/453400]     Chris Johnson-2016
# 1668          26.2  [/savant-player/605137]         Josh Bell-2020
# 488           25.8  [/savant-player/455104]    Chris Iannetta-2017
# 935           23.5  [/savant-player/408234]    Miguel Cabrera-2019
# 217           27.6  [/savant-player/592192]        Mark Canha-2020
#
# [15 rows x 21 columns]

# %% [markdown]
# Actual merging:

# %%
combined_df = savant_df.merge(fg_df, how='left', on='Player_Year_ID')

# %%
combined_df
# Out:
#                        Player    Year   Age     PA      G  Avg EV (MPH)  \
# 0      Saltalamacchia, Jarrod  2016.0  31.0  292.0   92.0          89.2
# 1               Schimpf, Ryan  2016.0  28.0  330.0   89.0          90.3
# 2                 Gallo, Joey  2017.0  24.0  532.0  145.0          93.3
# 3             Carpenter, Matt  2018.0  33.0  677.0  156.0          90.7
# 4                  Bruce, Jay  2019.0  32.0  333.0   98.0          90.2
# ...                       ...     ...   ...    ...    ...           ...
# 1888        Jankowski, Travis  2016.0  25.0  383.0  131.0          86.2
# 1889             LeMahieu, DJ  2016.0  28.0  635.0  146.0          91.7
# 1890        Jankowski, Travis  2018.0  27.0  387.0  117.0          85.6
# 1891           Slater, Austin  2018.0  26.0  225.0   74.0          87.3
# 1892        Yelich, Christian  2015.0  24.0  525.0  126.0          91.7
#
#       Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  ...  Pull %  \
# 0           21.4     11.6              6.8        35.4  ...    44.2
# 1           29.7     16.7              8.0        41.4  ...    41.4
# 2           23.0     22.1              8.3        52.2  ...    50.2
# 3           21.6     13.7             11.5        44.7  ...    47.6
# 4           21.4     13.4              8.2        43.7  ...    42.9
# ...          ...      ...              ...         ...  ...     ...
# 1888         0.8      1.3              1.3        26.9  ...    20.2
# 1889         5.9      4.9              5.6        47.5  ...    20.8
# 1890         3.3      0.7              1.1        19.3  ...    30.1
# 1891         2.6      2.3              0.8        35.1  ...    23.7
# 1892         0.0      4.8              5.6        45.1  ...    26.7
#
#       Straight Away %  Oppo %   GB%   FB%  LD %  Sprint Speed  \
# 0                34.0    21.8  31.3  43.5  19.7          25.6
# 1                33.9    24.7  20.1  42.0  21.8          28.2
# 2                29.2    20.6  29.2  37.9  22.1          27.8
# 3                30.7    21.7  28.3  37.8  28.5          26.5
# 4                29.9    27.3  29.4  37.7  19.9          26.7
# ...               ...     ...   ...   ...   ...           ...
# 1888             43.3    36.6  62.2  10.1  26.5          29.5
# 1889             42.0    37.2  52.9  10.1  33.7          27.1
# 1890             39.9    30.1  60.1  10.1  25.4          29.0
# 1891             36.6    39.7  63.4   9.2  22.9          28.0
# 1892             46.4    26.9  63.7   8.5  27.5          28.8
#
#                   Player Link              Player_Year_ID wRC+
# 0     [/savant-player/457454]  Jarrod Saltalamacchia-2016   70
# 1     [/savant-player/572114]           Ryan Schimpf-2016  128
# 2     [/savant-player/608336]             Joey Gallo-2017  119
# 3     [/savant-player/572761]         Matt Carpenter-2018  140
# 4     [/savant-player/457803]              Jay Bruce-2019   98
# ...                       ...                         ...  ...
# 1888  [/savant-player/608671]       Travis Jankowski-2016   81
# 1889  [/savant-player/518934]            DJ LeMahieu-2016  130
# 1890  [/savant-player/608671]       Travis Jankowski-2018   90
# 1891  [/savant-player/596103]          Austin Slater-2018   81
# 1892  [/savant-player/592885]       Christian Yelich-2015  120
#
# [1893 rows x 22 columns]

# %% [markdown]
# 1893 rows as expected.

# %% [markdown]
# ### Exploring combined DF:

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1893 entries, 0 to 1892
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player               1893 non-null   object
#  1   Year                 1893 non-null   float64
#  2   Age                  1893 non-null   float64
#  3   PA                   1893 non-null   float64
#  4   G                    1893 non-null   float64
#  5   Avg EV (MPH)         1893 non-null   float64
#  6   Avg LA (°)           1893 non-null   float64
#  7   Barrel%              1893 non-null   float64
#  8   Solid Contact %      1893 non-null   float64
#  9   Hard Hit %           1893 non-null   float64
#  10  Zone Swing %         1893 non-null   float64
#  11  Out of Zone Swing %  1893 non-null   float64
#  12  Pull %               1893 non-null   float64
#  13  Straight Away %      1893 non-null   float64
#  14  Oppo %               1893 non-null   float64
#  15  GB%                  1893 non-null   float64
#  16  FB%                  1893 non-null   float64
#  17  LD %                 1893 non-null   float64
#  18  Sprint Speed         1893 non-null   float64
#  19  Player Link          1893 non-null   object
#  20  Player_Year_ID       1893 non-null   object
#  21  wRC+                 1887 non-null   object
# dtypes: float64(18), object(4)
# memory usage: 340.1+ KB

# %% [markdown]
# OK, still 6 null values for wRC+.  Who are they?

# %%
print(combined_df[combined_df['wRC+'].isnull()])
# Out:
#               Player    Year   Age     PA      G  Avg EV (MPH)  Avg LA (°)  \
# 94     Ramirez, Jose  2018.0  26.0  698.0  157.0          89.0        19.0
# 165    Ramirez, Jose  2019.0  27.0  542.0  129.0          89.2        19.8
# 470    Ramirez, Jose  2020.0  28.0  254.0   58.0          88.7        23.2
# 651    Ramirez, Jose  2017.0  25.0  645.0  152.0          88.2        15.0
# 807    Ramirez, Jose  2015.0  23.0  355.0   97.0          86.6        12.0
# 1226   Ramirez, Jose  2016.0  24.0  618.0  152.0          88.4        13.2
#
#       Barrel%  Solid Contact %  Hard Hit %  ...  Pull %  Straight Away %  \
# 94        8.3              7.9        35.1  ...    47.8             33.9
# 165       6.3              7.0        35.7  ...    48.1             31.2
# 470      10.2              6.2        35.6  ...    47.5             33.9
# 651       5.0              7.1        34.9  ...    42.8             34.9
# 807       1.8              2.8        24.0  ...    40.3             35.0
# 1226      3.0              5.5        32.9  ...    35.6             36.2
#
#       Oppo %   GB%   FB%  LD %  Sprint Speed              Player Link  \
# 94      18.3  33.9  31.2  23.4          27.5  [/savant-player/608070]
# 165     20.8  33.8  29.7  25.6          27.8  [/savant-player/608070]
# 470     18.6  29.9  26.0  28.2          27.2  [/savant-player/608070]
# 651     22.3  40.3  24.4  27.6          28.0  [/savant-player/608070]
# 807     24.7  49.8  23.3  19.8          28.0  [/savant-player/608070]
# 1226    28.1  41.5  20.1  31.7          27.9  [/savant-player/608070]
#
#          Player_Year_ID wRC+
# 94    Jose Ramirez-2018  NaN
# 165   Jose Ramirez-2019  NaN
# 470   Jose Ramirez-2020  NaN
# 651   Jose Ramirez-2017  NaN
# 807   Jose Ramirez-2015  NaN
# 1226  Jose Ramirez-2016  NaN
#
# [6 rows x 22 columns]

# %% [markdown]
# Just Jose Ramirez, but he has wRC+ data.  Since it's only 6 will enter manually. Based on above, those are indices 94, 165, 470, 651, 807, 1226.

# %%
combined_df.iloc[94, 21] = 146 #2018
combined_df.iloc[165, 21] = 104 #2019
combined_df.iloc[470, 21] = 163 #2020
combined_df.iloc[651, 21] = 146 #2017
combined_df.iloc[807, 21] = 72 #2015
combined_df.iloc[1226, 21] = 119 #2016

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1893 entries, 0 to 1892
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player               1893 non-null   object
#  1   Year                 1893 non-null   float64
#  2   Age                  1893 non-null   float64
#  3   PA                   1893 non-null   float64
#  4   G                    1893 non-null   float64
#  5   Avg EV (MPH)         1893 non-null   float64
#  6   Avg LA (°)           1893 non-null   float64
#  7   Barrel%              1893 non-null   float64
#  8   Solid Contact %      1893 non-null   float64
#  9   Hard Hit %           1893 non-null   float64
#  10  Zone Swing %         1893 non-null   float64
#  11  Out of Zone Swing %  1893 non-null   float64
#  12  Pull %               1893 non-null   float64
#  13  Straight Away %      1893 non-null   float64
#  14  Oppo %               1893 non-null   float64
#  15  GB%                  1893 non-null   float64
#  16  FB%                  1893 non-null   float64
#  17  LD %                 1893 non-null   float64
#  18  Sprint Speed         1893 non-null   float64
#  19  Player Link          1893 non-null   object
#  20  Player_Year_ID       1893 non-null   object
#  21  wRC+                 1893 non-null   object
# dtypes: float64(18), object(4)
# memory usage: 340.1+ KB

# %%
print(combined_df[combined_df['wRC+'].isnull()])
# Out:
# Empty DataFrame
# Columns: [Player, Year, Age, PA, G, Avg EV (MPH), Avg LA (°), Barrel%, Solid Contact %, Hard Hit %, Zone Swing %, Out of Zone Swing %, Pull %, Straight Away %, Oppo %, GB%, FB%, LD %, Sprint Speed, Player Link, Player_Year_ID, wRC+]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# We're all fixed!  Just need to change the wRC+ to a numerical value:

# %%
combined_df['wRC+'] = combined_df['wRC+'].apply(pd.to_numeric, errors='coerce')

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1893 entries, 0 to 1892
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player               1893 non-null   object
#  1   Year                 1893 non-null   float64
#  2   Age                  1893 non-null   float64
#  3   PA                   1893 non-null   float64
#  4   G                    1893 non-null   float64
#  5   Avg EV (MPH)         1893 non-null   float64
#  6   Avg LA (°)           1893 non-null   float64
#  7   Barrel%              1893 non-null   float64
#  8   Solid Contact %      1893 non-null   float64
#  9   Hard Hit %           1893 non-null   float64
#  10  Zone Swing %         1893 non-null   float64
#  11  Out of Zone Swing %  1893 non-null   float64
#  12  Pull %               1893 non-null   float64
#  13  Straight Away %      1893 non-null   float64
#  14  Oppo %               1893 non-null   float64
#  15  GB%                  1893 non-null   float64
#  16  FB%                  1893 non-null   float64
#  17  LD %                 1893 non-null   float64
#  18  Sprint Speed         1893 non-null   float64
#  19  Player Link          1893 non-null   object
#  20  Player_Year_ID       1893 non-null   object
#  21  wRC+                 1893 non-null   int64
# dtypes: float64(18), int64(1), object(3)
# memory usage: 340.1+ KB

# %%
combined_df.describe()
# Out:
#               Year          Age           PA            G  Avg EV (MPH)  \
# count  1893.000000  1893.000000  1893.000000  1893.000000   1893.000000
# mean   2017.206022    28.826730   435.196513   114.937137     88.413312
# std       1.557844     3.816009   155.619031    32.113398      2.215767
# min    2015.000000    20.000000   200.000000    46.000000     80.200000
# 25%    2016.000000    26.000000   284.000000    89.000000     87.000000
# 50%    2017.000000    28.000000   432.000000   119.000000     88.500000
# 75%    2019.000000    32.000000   570.000000   144.000000     89.900000
# max    2020.000000    44.000000   747.000000   162.000000     96.100000
#
#         Avg LA (°)      Barrel%  Solid Contact %   Hard Hit %  Zone Swing %  \
# count  1893.000000  1893.000000      1893.000000  1893.000000   1893.000000
# mean     12.229688     6.797834         5.770100    35.749234     66.659641
# std       4.386683     4.020786         2.023787     7.913946      5.884461
# min      -1.400000     0.000000         0.000000     7.300000     47.400000
# 25%       9.300000     3.700000         4.400000    31.000000     62.800000
# 50%      12.300000     6.300000         5.800000    36.200000     66.700000
# 75%      15.300000     9.300000         7.200000    41.000000     70.600000
# max      29.700000    25.700000        18.000000    62.200000     83.700000
#
#        Out of Zone Swing %       Pull %  Straight Away %       Oppo %  \
# count          1893.000000  1893.000000      1893.000000  1893.000000
# mean             28.202324    37.029900        37.787480    25.182831
# std               5.974287     5.844259         3.847019     4.225243
# min              10.200000    16.700000        25.900000    13.400000
# 25%              24.000000    33.400000        35.300000    22.300000
# 50%              28.100000    37.000000        37.800000    25.100000
# 75%              32.100000    40.900000        40.400000    27.900000
# max              51.300000    56.800000        53.800000    43.400000
#
#                GB%          FB%         LD %  Sprint Speed         wRC+
# count  1893.000000  1893.000000  1893.000000   1893.000000  1893.000000
# mean     44.503803    22.432224    25.902800     27.015742   101.157422
# std       6.920655     5.208745     3.629189      1.454924    26.002898
# min      20.100000     8.500000    14.900000     21.900000     0.000000
# 25%      39.600000    18.700000    23.500000     26.100000    84.000000
# 50%      44.400000    22.200000    25.700000     27.100000   101.000000
# 75%      49.300000    26.000000    28.200000     28.100000   118.000000
# max      66.200000    43.500000    40.400000     30.800000   197.000000

# %% [markdown]
# None of these values seem out of the ordinary or absurd.

# %% [markdown]
# Actual last think i'd like to do is add in player position via Savant - i know this will take a while, so here goes:

# %%
player_no_duplicate_df = pd.DataFrame(data=[savant_df['Player'],savant_df['Player Link']]).T
player_no_duplicate_df
# Out:
#                        Player              Player Link
# Rk.
# 1      Saltalamacchia, Jarrod  [/savant-player/457454]
# 2               Schimpf, Ryan  [/savant-player/572114]
# 3                 Gallo, Joey  [/savant-player/608336]
# 4             Carpenter, Matt  [/savant-player/572761]
# 5                  Bruce, Jay  [/savant-player/457803]
# ...                       ...                      ...
# 1889        Jankowski, Travis  [/savant-player/608671]
# 1890             LeMahieu, DJ  [/savant-player/518934]
# 1891        Jankowski, Travis  [/savant-player/608671]
# 1892           Slater, Austin  [/savant-player/596103]
# 1893        Yelich, Christian  [/savant-player/592885]
#
# [1893 rows x 2 columns]

# %% [markdown]
# Next step, remove duplicates from the player column, since their links point to the same page (removing work for the computer later)

# %%
player_no_duplicate_df.drop_duplicates(subset='Player', inplace=True)

# %%
player_no_duplicate_df
# Out:
#                        Player              Player Link
# Rk.
# 1      Saltalamacchia, Jarrod  [/savant-player/457454]
# 2               Schimpf, Ryan  [/savant-player/572114]
# 3                 Gallo, Joey  [/savant-player/608336]
# 4             Carpenter, Matt  [/savant-player/572761]
# 5                  Bruce, Jay  [/savant-player/457803]
# ...                       ...                      ...
# 1885            Venable, Will  [/savant-player/461416]
# 1886                Fuld, Sam  [/savant-player/453539]
# 1887          Schumaker, Skip  [/savant-player/435401]
# 1889        Jankowski, Travis  [/savant-player/608671]
# 1892           Slater, Austin  [/savant-player/596103]
#
# [646 rows x 2 columns]

# %% [markdown]
# Mission accomplished, down to only 646 rows! Now, make a list of all the links to feed into a soup generator:

# %%
link_list = player_no_duplicate_df['Player Link'].to_list()

# %%
savant_page_list = [('https://baseballsavant.mlb.com' + str(link).strip("'[]")) for link in link_list]

# %%
print(savant_page_list)
# Out:
# ['https://baseballsavant.mlb.com/savant-player/457454', 'https://baseballsavant.mlb.com/savant-player/572114', 'https://baseballsavant.mlb.com/savant-player/608336', 'https://baseballsavant.mlb.com/savant-player/572761', 'https://baseballsavant.mlb.com/savant-player/457803', 'https://baseballsavant.mlb.com/savant-player/519346', 'https://baseballsavant.mlb.com/savant-player/624415', 'https://baseballsavant.mlb.com/savant-player/656555', 'https://baseballsavant.mlb.com/savant-player/595885', 'https://baseballsavant.mlb.com/savant-player/545361', 'https://baseballsavant.mlb.com/savant-player/435063', 'https://baseballsavant.mlb.com/savant-player/572122', 'https://baseballsavant.mlb.com/savant-player/641598', 'https://baseballsavant.mlb.com/savant-player/519390', 'https://baseballsavant.mlb.com/savant-player/545350', 'https://baseballsavant.mlb.com/savant-player/474832', 'https://baseballsavant.mlb.com/savant-player/455139', 'https://baseballsavant.mlb.com/savant-player/592206', 'https://baseballsavant.mlb.com/savant-player/594807', 'https://baseballsavant.mlb.com/savant-player/448801', 'https://baseballsavant.mlb.com/savant-player/593934', 'https://baseballsavant.mlb.com/savant-player/474892', 'https://baseballsavant.mlb.com/savant-player/457759', 'https://baseballsavant.mlb.com/savant-player/472528', 'https://baseballsavant.mlb.com/savant-player/446263', 'https://baseballsavant.mlb.com/savant-player/458675', 'https://baseballsavant.mlb.com/savant-player/500871', 'https://baseballsavant.mlb.com/savant-player/571970', 'https://baseballsavant.mlb.com/savant-player/663586', 'https://baseballsavant.mlb.com/savant-player/543768', 'https://baseballsavant.mlb.com/savant-player/592450', 'https://baseballsavant.mlb.com/savant-player/518692', 'https://baseballsavant.mlb.com/savant-player/461235', 'https://baseballsavant.mlb.com/savant-player/434158', 'https://baseballsavant.mlb.com/savant-player/592669', 'https://baseballsavant.mlb.com/savant-player/458015', 'https://baseballsavant.mlb.com/savant-player/608596', 'https://baseballsavant.mlb.com/savant-player/501981', 'https://baseballsavant.mlb.com/savant-player/621514', 'https://baseballsavant.mlb.com/savant-player/596142', 'https://baseballsavant.mlb.com/savant-player/666560', 'https://baseballsavant.mlb.com/savant-player/518614', 'https://baseballsavant.mlb.com/savant-player/571431', 'https://baseballsavant.mlb.com/savant-player/429667', 'https://baseballsavant.mlb.com/savant-player/543685', 'https://baseballsavant.mlb.com/savant-player/594828', 'https://baseballsavant.mlb.com/savant-player/606192', 'https://baseballsavant.mlb.com/savant-player/645277', 'https://baseballsavant.mlb.com/savant-player/502110', 'https://baseballsavant.mlb.com/savant-player/650402', 'https://baseballsavant.mlb.com/savant-player/571974', 'https://baseballsavant.mlb.com/savant-player/656305', 'https://baseballsavant.mlb.com/savant-player/542583', 'https://baseballsavant.mlb.com/savant-player/493316', 'https://baseballsavant.mlb.com/savant-player/444379', 'https://baseballsavant.mlb.com/savant-player/592200', 'https://baseballsavant.mlb.com/savant-player/553993', 'https://baseballsavant.mlb.com/savant-player/605141', 'https://baseballsavant.mlb.com/savant-player/664040', 'https://baseballsavant.mlb.com/savant-player/656371', 'https://baseballsavant.mlb.com/savant-player/457477', 'https://baseballsavant.mlb.com/savant-player/606157', 'https://baseballsavant.mlb.com/savant-player/571875', 'https://baseballsavant.mlb.com/savant-player/425784', 'https://baseballsavant.mlb.com/savant-player/592178', 'https://baseballsavant.mlb.com/savant-player/608070', 'https://baseballsavant.mlb.com/savant-player/571745', 'https://baseballsavant.mlb.com/savant-player/488771', 'https://baseballsavant.mlb.com/savant-player/429665', 'https://baseballsavant.mlb.com/savant-player/571602', 'https://baseballsavant.mlb.com/savant-player/572287', 'https://baseballsavant.mlb.com/savant-player/640449', 'https://baseballsavant.mlb.com/savant- ...

# %%
#Running the len just to audit/sanity check:
len(savant_page_list)
# Out:
# 646

# %% [markdown]
# Defining a Function to generate the soup objects:

# %%
def Soup_Generator(link_list):
    '''
    Takes in a list of players and returns Beautiful Soup objects.
    '''
    response_list = [requests.get(url) for url in link_list]
    soup_list = []
    for response in response_list:
        page = response.text
        soup_list.append(BeautifulSoup(page,'lxml'))
    return soup_list

# %%
link_soup = Soup_Generator(savant_page_list)

# %%
def Position_Puller(soup_list):
    '''
    Takes in a list of Beautiful Soup Objects from BasebalL Savant
    and returns each player's position.
    '''
    position_list = []
    for player in soup_list:
        position = player.find('div', style='font-size: .8rem;')
        position_list.append(str(position.text))
    final_position = []
    for position in position_list:
        position = position.strip("\n")
        position = position.strip(" ")
        final_position.append(position[0:2].strip(" "))
    return final_position

# %%
final_list = Position_Puller(link_soup)

# %%
print(final_list)
