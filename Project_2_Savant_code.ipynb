# %% [markdown]
# ## Using BeautifulSoup/Selenium to Scrape BaseballSavant

# %% [markdown]
# First, importing needed packages:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 20,10
import numpy as np
import glob
from scipy import stats
from bs4 import BeautifulSoup
import requests
import re
from IPython.core.display import display, HTML    # make sure Jupyter knows to display it as HTML

# %% [markdown]
# Importing selenium and setting chrome driver:

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
savant_url = 'https://baseballsavant.mlb.com/leaderboard/custom?year=2020,2019,2018,2017&type=batter&filter=&sort=4&sortDir=desc&min=50&selections=player_age,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,solidcontact_percent,hard_hit_percent,z_swing_percent,oz_swing_percent,pull_percent,straightaway_percent,opposite_percent,groundballs_percent,flyballs_percent,linedrives_percent,sprint_speed,&chart=true&x=player_age&y=player_age&r=no&chartType=beeswarm'

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(savant_url)

# %%
driver.page_source[:1000]
# Out:
# '<html lang="en_US" class=" device-desktop"><head>\n    <title>Statcast Custom Leaderboards | baseballsavant.com </title>\n\n    <!-- meta meta tag -->\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge">\n    <meta http-equiv="Cache-Control" content="no-cache">\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="Expires" content="-1">\n    <meta name="keywords" content="Baseball Savant">\n    <!-- -->\n    <meta property="og:title" content="Statcast Custom Leaderboards">\n    <meta itemprop="name" content="Statcast Custom Leaderboards baseballsavant.com">\n    \n    <meta property="og:site_name" content="baseballsavant.com">\n    <meta property="og:type" content="website">\n    \n    <meta property="og:image" content="https://baseballsavant.mlb.com/site-core/images/statcast-logo-gcp-social.png">\n    <meta itemprop="image" content="https://baseballsavant.mlb.com/site-core/images/statcast-logo-gcp-social.png">\n     <meta name="twitter:card" content='

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
headers = soup.find('div', id='sortable_stats').find_all('th')

# %% [markdown]
# Finding Table Rows:

# %%
columns = [col.get_text() for col in headers]

# %%
print(columns)
# Out:
# ['Rk.', 'Player', 'Year', 'Age', 'Avg EV (MPH)', 'Avg LA (°)', 'Barrel%', 'Solid Contact %', 'Hard Hit %', 'Zone Swing %', 'Out of Zone Swing %', 'Pull %', 'Straight Away %', 'Oppo %', 'GB%', 'FB%', 'LD %', 'Sprint Speed']

# %%
savant_df = pd.DataFrame(columns=columns)
savant_df.head()
# Out:
# Empty DataFrame
# Columns: [Rk., Player, Year, Age, Avg EV (MPH), Avg LA (°), Barrel%, Solid Contact %, Hard Hit %, Zone Swing %, Out of Zone Swing %, Pull %, Straight Away %, Oppo %, GB%, FB%, LD %, Sprint Speed]
# Index: []

# %% [markdown]
# Finding Stats:

# %%
stats_test = soup.find('div', id='sortable_stats').find_all('tr')

# %%
stats = [col.get_text() for col in stats_test]

# %%
stat_lines = soup.find('div', id='sortable_stats').find_all('tr')
compiled_stats = []
for line_item in stat_lines:
    ind_stat_line = [item.get_text() for item in line_item.find_all('td')]
    compiled_stats.append(ind_stat_line)
    final_stats = compiled_stats[1:]

# %% [markdown]
# Building DataFrame:

# %%
savant_df = pd.DataFrame(final_stats, columns=columns)
num_cols = ['Age','Year','Avg EV (MPH)','Avg LA (°)','Barrel%','Solid Contact %','Hard Hit %','Zone Swing %','Out of Zone Swing %','Pull %','Straight Away %','Oppo %','GB%','FB%','LD %','Sprint Speed']
savant_df[num_cols] = savant_df[num_cols].apply(pd.to_numeric, errors='coerce', axis=1)
savant_df.head()
# Out:
#   Rk.             Player    Year   Age  Avg EV (MPH)  Avg LA (°)  Barrel%  \
# 0   1    Heineman, Tyler  2020.0  29.0          82.4        34.3      2.6
# 1   2      Schimpf, Ryan  2017.0  29.0          86.1        29.8     16.5
# 2   3   Higashioka, Kyle  2018.0  28.0          88.4        28.0     10.7
# 3   4       Zunino, Mike  2020.0  29.0          87.5        26.9     15.8
# 4   5        Gallo, Joey  2020.0  27.0          91.2        26.8     14.0
#
#    Solid Contact %  Hard Hit %  Zone Swing %  Out of Zone Swing %  Pull %  \
# 0              0.0        10.5          65.2                 24.2    44.7
# 1              4.1        30.9          59.3                 18.5    44.3
# 2              5.4        30.4          68.9                 23.5    42.9
# 3              7.9        36.8          66.3                 31.5    44.7
# 4              4.4        43.9          66.3                 19.2    48.2
#
#    Straight Away %  Oppo %   GB%   FB%  LD %  Sprint Speed
# 0             23.7    31.6  36.8  23.7  15.8          25.9
# 1             29.9    25.8  20.6  42.3  17.5          27.7
# 2             42.9    14.3  25.0  44.6  16.1          25.0
# 3             34.2    21.1  21.1  31.6  28.9          25.2
# 4             28.9    22.8  31.6  29.8  21.1          27.1

# %% [markdown]
# Driver's work here is done.

# %%
driver.close()

# %% [markdown]
# Creating a list of names that can feed into the BBREF code:

# %%
player_column = savant_df.Player

# %%
player_column.drop_duplicates(inplace=True)

# %%
player_list = player_column.tolist()

# %%
player_list_split = [player.split(', ') for player in player_list]
for player in player_list_split:
    player[0] = player[0].strip()

final_player_list = [(player[1] + ' ' + player[0]) for player in player_list_split]

# %%
final_player_list
# Out:
# ['Tyler Heineman',
#  'Ryan Schimpf',
#  'Kyle Higashioka',
#  'Mike Zunino',
#  'Joey Gallo',
#  'Jett Bandy',
#  'Grayson Greiner',
#  'Adam Duvall',
#  'Kyle Garlick',
#  'Chris Young',
#  'Travis Shaw',
#  'Rhys Hoskins',
#  'Jordan Luplow',
#  'Anthony Santander',
#  'Christin Stewart',
#  'Carlos Perez',
#  'Austin Meadows',
#  'Dilson Herrera',
#  'Nick Dini',
#  'Will Smith',
#  'Matt Chapman',
#  'Cody Asche',
#  'Byron Buxton',
#  'Aaron Hill',
#  'Brandon Belt',
#  'Brian McCann',
#  'Jose Ramirez',
#  'Franklin Barreto',
#  'Mike Trout',
#  'Chris Carter',
#  'Edwin Encarnacion',
#  'Matt Carpenter',
#  'Pete Kozma',
#  'Anthony Bemboom',
#  'Robel Garcia',
#  'Lucas Duda',
#  'Stephen Vogt',
#  'John Ryan Murphy',
#  'Mike Napoli',
#  "Tyler O'Neill",
#  'Curt Casali',
#  'Robinson Chirinos',
#  'Max Kepler',
#  'Kaleb Cowart',
#  'Austin Hedges',
#  'Noah Syndergaard',
#  'Paul DeJong',
#  'Zack Cozart',
#  'Sandy Leon',
#  'Dustin Garneau',
#  'Jay Bruce',
#  'Matt Adams',
#  'Cam Gallagher',
#  'Erik Kratz',
#  'Danny Jansen',
#  'Renato Nunez',
#  'Kyle Seager',
#  "Chase d'Arnaud",
#  'Tyler White',
#  'Greg Bird',
#  'Tom Murphy',
#  'Christian Villanueva',
#  'Lonnie Chisenhall',
#  'Derek Dietrich',
#  'Gregory Polanco',
#  'Trevor Story',
#  'Jake Arrieta',
#  'Brian Goodwin',
#  'Kris Bryant',
#  'Rougned Odor',
#  'Teoscar Hernandez',
#  'Devin Mesoraco',
#  'Austin Riley',
#  'C.J. Cron',
#  'Jeff Mathis',
#  'Stephen Drew',
#  'Logan Morrison',
#  'Todd Frazier',
#  'Victor Robles',
#  'Jesmuel Valentin',
#  'Miguel Sano',
#  'Cavan Biggio',
#  'Jacob Nottingham',
#  'Ryan McBroom',
#  'Derek Norris',
#  'Curtis Granderson',
#  'Pat Valaika',
#  'Chance Sisco',
#  'Jose Peraza',
#  'Mike Moustakas',
#  'Sean Rodriguez',
#  'Jose Bautista',
#  'Mark Canha',
#  'Raffy Lopez',
#  'Aramis Garcia',
#  'Yoenis Cespedes',
#  'Carlos Gomez',
#  'Jake Rogers',
#  'Francisco Mejia',
#  'Tucker Barnhart',
#  'Jason Castro',
#  'Jorge Soler',
#  'Hector Sanchez',
#  'Alex Bregman',
#  'Josh Harrison',
#  'Matt Olson',
#  'Ian Kinsler',
#  'Jake Marisnick',
#  'Ryan Cordell',
#  'Enrique Hernandez',
#  'Anthony Rendon',
#  'Josh Phegley',
#  'Yonder Alonso',
#  'Jorge Bonifacio',
#  'Eric Thames',
#  'Mookie Betts',
#  'Mike Yastrzemski',
#  'Eric Sogard',
#  'Marcus Semien',
#  'Dylan Moore',
#  'Brandon Lowe',
#  'Tim Federowicz',
#  'Gary Sanchez',
#  'John Jaso',
#  'Hunter Renfroe',
#  'Martin Maldonado',
#  'Josh Reddick',
#  'Nolan Arenado',
#  'Gleyber Torres',
#  'Wilmer Flores',
#  'Salvador Perez',
#  'Daniel Descalso',
#  'Eduardo Escobar',
#  'Jack Mayfield',
#  'Jorge Polanco',
#  'Brian Dozier',
#  'Kurt Suzuki',
#  'Khris Davis',
#  'Tony Kemp',
#  'Jed Lowrie',
#  'Billy McKinney',
#  'Christian Walker',
#  'Trayce Thompson',
#  'Randal Grichuk',
#  'Yan Gomes',
#  'Omar Narvaez',
#  'Kyle Schwarber',
#  'J.P. Crawford',
#  'Matt Wieters',
#  'Isan Diaz',
#  'Mitch Garver',
#  'Justin Upton',
#  'Ronald Acuna Jr.',
#  'Drew Butera',
#  'Luis Valbuena',
#  'Justin Turner',
#  'Daulton Varsho',
#  'Justin Ruggiano',
#  'Joey Rickard',
#  'Leonys Martin',
#  'Mark Reynolds',
#  'Rene Rivera',
#  'George Springer',
#  'Max Muncy',
#  'Cody Bellinger',
#  'Aristides Aquino',
#  'Kevin Kramer',
#  'Mitch Haniger',
#  'Jason Kipnis',
#  'Andrew McCutchen',
#  'Kyle Farmer',
#  'Willi Castro',
#  'Eddie Rosario',
#  'Ryder Jones',
#  'John Andreoli',
#  'Michael Perez',
#  'Eugenio Suarez',
#  'Evan Gattis',
#  'Scott Kingery',
#  'Ozzie Albies',
#  'Didi Gregorius',
#  'Alex Dickerson',
#  'DJ Stewart',
#  'Matt Davidson',
#  "Ryan O'Hearn",
#  'Brad Miller',
#  'Tyler Moore',
#  'Manny Pina',
#  'Willie Calhoun',
#  'Brandon Moss',
#  'Chris Herrmann',
#  'Seth Brown',
#  'Matt Skole',
#  'Adam Rosales',
#  'Matt Szczur',
#  'Daniel Murphy',
#  'Andrew Benintendi',
#  'Tim Locastro',
#  'Justin Smoak',
#  'Dominic Smith',
#  'Isaac Galloway',
#  'Chase Utley',
#  'Daniel Vogelbach',
#  'Breyvic Valera',
#  'Yoshi Tsutsugo',
#  'Freddie Freeman',
#  'Tommy La Stella',
#  'Neil Walker',
#  'Patrick Wisdom',
#  'Tyler Saladino',
#  'Ryon Healy',
#  'Kole Calhoun',
#  'Hunter Dozier',
#  'David Dahl',
#  'Whit Merrifield',
#  'Brandon Dixon',
#  'Kevin Pillar',
#  'Luis Guillorme',
#  'Aaron Altherr',
#  'Matt Joyce',
#  'Starlin Castro',
#  'Phillip Ervin',
#  'Mauricio Dubon',
#  'Anthony Rizzo',
#  'Carson Kelly',
#  'Jake Lamb',
#  'Luis Robert',
#  "Peter O'Brien",
#  'Josh VanMeter',
#  'Nick Castellanos',
#  'Orlando Calixte',
#  'Chris Taylor',
#  'Pedro Florimon',
#  'Austin Barnes',
#  'Marcell Ozuna',
#  'Bradley Zimmer',
#  'Albert Pujols',
#  'Ehire Adrianza',
#  'Francisco Cervelli',
#  'Kyle Tucker',
#  'Jedd Gyorko',
#  'Austin Nola',
#  'Ronny Rodriguez',
#  'Nick Senzel',
#  'Gavin Cecchini',
#  'Taylor Ward',
#  'James McCann',
#  'Jesus Aguilar',
#  'Steven Souza Jr.',
#  'Brandon Guyer',
#  'Corey Dickerson',
#  'John Hicks',
#  'Tyler Flowers',
#  'Travis Demeritte',
#  'Andrew Knapp',
#  'Nick Hundley',
#  'Keston Hiura',
#  'Ian Happ',
#  'Trent Grisham',
#  'Michael Conforto',
#  'Niko Goodrum',
#  'Bryce Harper',
#  'Matt Thaiss',
#  'Nicky Delmonico',
#  'Myles Straw',
#  'Aaron Judge',
#  'J.D. Martinez',
#  'Rickie Weeks Jr.',
#  'Joc Pederson',
#  'Gregorio Petit',
#  'Matt Kemp',
#  'Jeimer Candelario',
#  'Jose Reyes',
#  'Paul Goldschmidt',
#  'Ji-Man Choi',
#  'Harrison Bader',
#  'Chris Gimenez',
#  'Mike Ford',
#  'Manny Machado',
#  'Cedric Mullins',
#  'Yasmani Grandal',
#  'Jazz Chisholm',
#  'Jeff McNeil',
#  'Welington Castillo',
#  'Zach Davies',
#  'Donovan Solano',
#  'Pete Alonso',
#  'Wil Myers',
#  'Yoan Moncada',
#  'Carlos Asuaje',
#  'Billy Hamilton',
#  'Carlos Santana',
#  'Yadier Molina',
#  'Clint Frazier',
#  'Willians Astudillo',
#  'Eli White',
#  'Joey Votto',
#  'Chris Iannetta',
#  'Luke Voit',
#  'Zack Collins',
#  'Kevin Plawecki',
#  'Adam Eaton',
#  'Madison Bumgarner',
#  'Ryan Braun',
#  'Max Moroff',
#  'Colby Rasmus',
#  'Robbie Grossman',
#  'Freddy Galvis',
#  'Cliff Pennington',
#  'Tyler Austin',
#  'Chris Davis',
#  'Ty France',
#  'Zach Eflin',
#  'Phil Gosselin',
#  'Mike Brosseau',
#  'Stuart Turner',
#  'Dustin Fowler',
#  'Bryan Holaday',
#  'Jake Bauers',
#  'Daniel Palka',
#  'Max Stassi',
#  'Brett Gardner',
#  'Jesus Sucre',
#  'Cheslor Cuthbert',
#  'Tyler Collins',
#  'Jabari Blash',
#  'Ruben Tejada',
#  'Gregor Blanco',
#  'Maikel Franco',
#  'Bobby Dalbec',
#  'Adam Engel',
#  'Addison Russell',
#  'T.J. Rivera',
#  'Yangervis Solarte',
#  'Francisco Lindor',
#  'Oscar Mercado',
#  'Jose Osuna',
#  'Danny Santana',
#  'Dansby Swanson',
#  'Sean Murphy',
#  'Gordon Beckham',
#  'Asdrubal Cabrera',
#  'Ramon Laureano',
#  'Ronald Guzman',
#  "Travis d'Arnaud",
#  'Adam Wainwright',
#  'J.T. Realmuto',
#  'Charlie Blackmon',
#  'Edwin Rios',
#  'Santiago Espinal',
#  'Miguel Montero',
#  'Ryan Rua',
#  'Lourdes Gurriel Jr.',
#  'Luis Castillo',
#  'Garrett Hampson',
#  'Christian Vazquez',
#  'Drew Robinson',
#  'Dusty Coleman',
#  'Shane Peterson',
#  'Adrian Gonzalez',
#  'Pedro Severino',
#  'Yuli Gurriel',
#  'Leody Taveras',
#  'Anderson Tejeda',
#  'Brock Stassi',
#  'Jayson Werth',
#  'Johnny Field',
#  'Tommy Edman',
#  'Manuel Margot',
#  'Kevin Cron',
#  'Yolmer Sanchez',
#  'Jurickson Profar',
#  'Alex Gordon',
#  'Victor Martinez',
#  'Jared Walsh',
#  'Corey Seager',
#  'Dee Strange-Gordon',
#  'Chad Pinder',
#  'Austin Dean',
#  'Scooter Gennett',
#  'Rowdy Tellez',
#  'Brett Phillips',
#  'JaCoby Jones',
#  'Evan Longoria',
#  'Devon Travis',
#  'Tommy Joseph',
#  'Steve Pearce',
#  'Blake Swihart',
#  'Rafael Ortega',
#  'Miguel Andujar',
#  'Luis Torrens',
#  'Gavin Lux',
#  'Danny Espinosa',
#  'Alcides Escobar',
#  'Alen Hanson',
#  'Yasiel Puig',
#  'Brandon Drury',
#  'Jeremy Hazelbaker',
#  'Aledmys Diaz',
#  'Adalberto Mondesi',
#  'Jung Ho Kang',
#  'AJ Pollock',
#  'Evan White',
#  'Tzu-Wei Lin',
#  'Jae-Gyun Hwang',
#  'Josh Donaldson',
#  'Jesse Winker',
#  'Adrian Beltre',
#  'Aaron Hicks',
#  'Adeiny Hechavarria',
#  'Jonathan Lucroy',
#  'Delino DeShields',
#  'Gio Urshela',
#  'Andres Gimenez',
#  'Stephen Piscotty',
#  'Ty Kelly',
#  'Jaff Decker',
#  'Chris Heisey',
#  'Carlos Beltran',
#  'David Fletcher',
#  'Chris Owings',
#  'Chad Wallach',
#  'Adam Jones',
#  'Tyler Wade',
#  'Lane Adams',
#  'Denard Span',
#  'Yordan Alvarez',
#  'Cole Tucker',
#  'Raimel Tapia',
#  'Brett Nicholas',
#  'Alejandro De Aza',
#  'Odubel Herrera',
#  'Shane Robinson',
#  'Xander Bogaerts',
#  'Luke Maile',
#  'Charlie Culberson',
#  'Jordy Mercer',
#  'Hanser Alberto',
#  'Tyler Anderson',
#  'Reese McGuire',
#  'Nelson Cruz',
#  'Jonathan Schoop',
#  'Dexter Fowler',
#  'Steven Duggar',
#  'Richard Urena',
#  'Caleb Joseph',
#  'Nate Lowe',
#  'Adam Frazier',
#  'Braden Bishop',
#  'Tyler Naquin',
#  'Sam Haggerty',
#  'Michael Hermosillo',
#  'Guillermo Heredia',
#  'Joe Panik',
#  'Josh Bell',
#  'Elias Diaz',
#  'Jose Rondon',
#  'Matt Holliday',
#  'Wilmer Difo',
#  'Kolten Wong',
#  'Ty Blach',
#  'Hanley Ramirez',
#  'Johan Camargo',
#  'Rob Refsnyder',
#  'Gorkys Hernandez',
#  'Carlos Correa',
#  'Joey Bart',
#  'Alex Avila',
#  'Marwin Gonzalez',
#  'Mark Trumbo',
#  'Miguel Cabrera',
#  'Juan Soto',
#  'Jonathan Davis',
#  'Mitch Moreland',
#  'Willy Adames',
#  'Darin Ruf',
#  'Taylor Motter',
#  'Michael A. Taylor',
#  'Mike Aviles',
#  'Shohei Ohtani',
#  'Carlos Tocci',
#  'Spencer Kieboom',
#  'Mikie Mahtook',
#  'Alex Blandino',
#  'Colin Moran',
#  'Brandon Crawford',
#  'Jon Jay',
#  'Jacob Stallings',
#  'Logan Forsythe',
#  'Chris Shaw',
#  'Jackie Bradley Jr.',
#  'Jose Abreu',
#  'Pedro Alvarez',
#  'A.J. Ellis',
#  'Pablo Reyes',
#  'Brandon Nimmo',
#  'Michael Saunders',
#  'Paulo Orlando',
#  'Jose Iglesias',
#  'Zack Wheeler',
#  'Bubba Starling',
#  'Luis Arraez',
#  'Carlos Ruiz',
#  'Bo Bichette',
#  'Nick Ahmed',
#  'Carter Kieboom',
#  'Miguel Rojas',
#  'Trevor Plouffe',
#  'Greg Garcia',
#  'Rosell Herrera',
#  'Cameron Maybin',
#  'Scott Schebler',
#  'Chase Headley',
#  'Jose Miguel Fernandez',
#  'Giancarlo Stanton',
#  'Roman Quinn',
#  'Darwin Barney',
#  'Zack Greinke',
#  'LaMonte Wade Jr',
#  'Joey Wendle',
#  'Harold Castro',
#  'Jose Martinez',
#  'Buster Posey',
#  'Domingo Santana',
#  'Hernan Perez',
#  'Cesar Hernandez',
#  'Austin Hays',
#  'Ketel Marte',
#  'Ben Gamel',
#  'Boog Powell',
#  'Rajai Davis',
#  'David Freitas',
#  'Ryan LaMarre',
#  'Michael Chavis',
#  'Jo Adell',
#  'Shin-Soo Choo',
#  'Nomar Mazara',
#  'Kennys Vargas',
#  'Rafael Devers',
#  'Mike Tauchman',
#  'Joe Musgrove',
#  'Christian Yelich',
#  'Rio Ruiz',
#  'Jason Heyward',
#  'Ramon Torres',
#  'Preston Tucker',
#  'Noel Cuevas',
#  'Francisco Arcia',
#  'Andrew Romine',
#  'Austin Jackson',
#  'Jim Adduci',
#  'Brock Holt',
#  'Jean Segura',
#  'Franmil Reyes',
#  'Jhonny Peralta',
#  'Brian Anderson',
#  'Stevie Wilkerson',
#  'Kyle Lewis',
#  'Dixon Machado',
#  'Jarrod Dyson',
#  'Bobby Wilson',
#  'David Freese',
#  'Daniel Nava',
#  'Pablo Sandoval',
#  'Nick Williams',
#  'Austin Romine',
#  'Austin Slater',
#  'Conor Gillaspie',
#  'Juan Centeno',
#  'Tim Anderson',
#  'Ender Inciarte',
#  'Tim Beckham',
#  'Julio Teheran',
#  'Howie Kendrick',
#  'Sam Hilliard',
#  'Ryan Mountcastle',
#  'Mike Freeman',
#  'Adam Lind',
#  'Scott Heineman',
#  'Juan Lagares',
#  'Michael Brantley',
#  'Victor Reyes',
#  'Chris Coghlan',
#  'Jace Peterson',
#  'Shed Long Jr.',
#  'J.D. Davis',
#  'Russell Martin',
#  'Josh Fuentes',
#  'Jake Cronenworth',
#  'Robbie Ray',
#  'Keon Broxton',
#  'Jake Cave',
#  'Jose Marmolejos',
#  'Patrick Kivlehan',
#  'Dustin Pedroia',
#  'Ronald Torreyes',
#  'Justin Bour',
#  'Franchy Cordero',
#  'Travis Taijeron',
#  'Lorenzo Cain',
#  'Jose Briceno',
#  'Josh Rojas',
#  'Ryan Jeffers',
#  'Javier Baez',
#  'Jarrett Parker',
#  'Jared Hoying',
#  'Willy Garcia',
#  'Craig Gentry',
#  'Matt Beaty',
#  'Bryan Reynolds',
#  'Chris Stewart',
#  'Jose Altuve',
#  'Luis Urias',
#  'Tony Wolters',
#  'Hunter Pence',
#  'Jose Trevino',
#  'Chadwick Tromp',
#  'Jacoby Ellsbury',
#  'Nick Markakis',
#  'Kendrys Morales',
#  'Lewis Brinson',
#  'Gerardo Parra',
#  'Cory Spangenberg',
#  'Ryan Goins',
#  'Seth Smith',
#  'Yu Chang',
#  'Trea Turner',
#  'JT Riddle',
#  'Kristopher Negron',
#  'Allen Cordoba',
#  'Mason Williams',
#  'Avisail Garcia',
#  'Hyun Soo Kim',
#  'Alexi Amarista',
#  'Ryan Raburn',
#  'Steven Matz',
#  'Ryan Zimmerman',
#  'Orlando Arcia',
#  'Jacob deGrom',
#  'Alex Presley',
#  'Austin Allen',
#  'Andrelton Simmons',
#  'Garrett Cooper',
#  'Eduardo Nunez',
#  'Greg Allen',
#  'Richie Martin',
#  'German Marquez',
#  'Nick Solak',
#  'Jonathan Arauz',
#  'Gio Gonzalez',
#  'Ben Zobrist',
#  'Jose Lobaton',
#  'Luis Rengifo',
#  'Eloy Jimenez',
#  'Humberto Arteaga',
#  'Corban Joseph',
#  'David Bote',
#  'Daz Cameron',
#  'Dylan Carlson',
#  'Rey Fuentes',
#  'Starling Marte',
#  'Troy Tulowitzki',
#  'Danny Valencia',
#  'Derek Fisher',
#  'Randy Arozarena',
#  'Ryan McMahon',
#  'Elvis Andrus',
#  'Yasmany Tomas',
#  'J.J. Hardy',
#  'Melky Cabrera',
#  'Martin Prado',
#  'Willson Contreras',
#  'Carlos Gonzalez',
#  'Dwight Smith',
#  'Amed Rosario',
#  'Andres Blanco',
#  'Tomas Nido',
#  'Alex Verdugo',
#  'Albert Almora Jr.',
#  'Jefry Marte',
#  'Tim Lopes',
#  'Ian Desmond',
#  'Fernando Tatis Jr.',
#  'Eric Hosmer',
#  'Kevin Newman',
#  'Adrian Sanchez',
#  'Mac Williamson',
#  'Cameron Rupp',
#  'Jorge Alfaro',
#  'Sheldon Neuse',
#  'Daniel Robertson',
#  'Marco Hernandez',
#  'Brandon Phillips',
#  'Roberto Perez',
#  'Robinson Cano',
#  'Efren Navarro',
#  'Jonathan Villar',
#  'Kevin Kiermaier',
#  'Jose Urena',
#  'Austin Wynns',
#  'Sam Travis',
#  'Dawel Lugo',
#  'Matt Reynolds',
#  'Trey Mancini',
#  'Kenta Maeda',
#  'Christian Arroyo',
#  'Josh Naylor',
#  'Tomas Telis',
#  'Andrew Stevenson',
#  'Abraham Almonte',
#  'Jose Garcia',
#  'Zack Granite',
#  'Juan Graterol',
#  'Abraham Toro',
#  'Edward Olivares',
#  'Erick Aybar',
#  'Mallex Smith',
#  'Leury Garcia',
#  'Isaac Paredes',
#  'Zack Godley',
#  'Danny Mendick',
#  "Ke'Bryan Hayes",
#  'Andrew Knizner',
#  'Thairo Estrada',
#  'Jaycob Brugman',
#  'Nick Franklin',
#  'Francisco Pena',
#  'Jhoulys Chacin',
#  'Brendan Rodgers',
#  'Jon Berti',
#  'Bruce Maxwell',
#  'Cameron Perkins',
#  'Arismendy Alcantara',
#  'Isiah Kiner-Falefa',
#  'JB Shuck',
#  'Victor Caratini',
#  'Tommy Pham',
#  'Wilfredo Tovar',
#  'Andrew Toles',
#  'David Peralta',
#  'Vladimir Guerrero Jr.',
#  'Jack Flaherty',
#  'Andrew Velazquez',
#  'Kelby Tomlinson',
#  'Peter Bourjos',
#  'Terrance Gore',
#  'DJ LeMahieu',
#  'Wilson Ramos',
#  'Vimael Machin',
#  'Adonis Garcia',
#  'Miles Mikolas',
#  'Joe Mauer',
#  'Deven Marrero',
#  'Yairo Munoz',
#  'Jose Pirela',
#  'Steven Brault',
#  'Yandy Diaz',
#  'Kevan Smith',
#  'Matt Duffy',
#  'Erik Gonzalez',
#  'Eric Fryer',
#  'Ezequiel Carrera',
#  'Nick Martini',
#  'Kyle Hendricks',
#  'Ichiro Suzuki',
#  'Adam Haseley',
#  'Moises Sierra',
#  'Meibrys Viloria',
#  'Charlie Tilson',
#  'Jon Lester',
#  'Mike Leake',
#  'Yonathan Daza',
#  'Alec Bohm',
#  'Ben Revere',
#  'Gerrit Cole',
#  'Christian Colon',
#  'Norichika Aoki',
#  'Clayton Richard',
#  'Lance Lynn',
#  'Nick Madrigal',
#  'Hyun Jin Ryu',
#  'Clayton Kershaw',
#  'Monte Harrison',
#  'Nico Hoerner',
#  'Harold Ramirez',
#  'Magneuris Sierra',
#  'Luis Perdomo',
#  'Yadiel Rivera',
#  'Travis Jankowski',
#  'Nicky Lopez',
#  'Ildemaro Vargas',
#  'Ryan Hanigan',
#  'Shogo Akiyama',
#  'Eric Young Jr.',
#  'Yunel Escobar',
#  'Aaron Nola',
#  'Matt Moore',
#  'Kyle Freeland',
#  'Josh Rutledge',
#  'Matt Harvey',
#  'Jon Gray',
#  'R.A. Dickey',
#  'Ryan Flaherty',
#  'Franklin Gutierrez',
#  'Luis Sardinas',
#  'Chris Stratton',
#  'Jeff Samardzija',
#  'Stephen Strasburg',
#  'Tanner Roark',
#  'Max Scherzer',
#  'Michael Lorenzen',
#  'Anibal Sanchez',
#  'Kelvin Gutierrez',
#  'Chad Kuhl',
#  'Trevor Williams',
#  'Yu Darvish',
#  'Michael Wacha',
#  'Derek Holland',
#  'Chase Anderson',
#  'Jameson Taillon',
#  'Max Fried',
#  'Cesar Puello',
#  'Luis Garcia',
#  'Taijuan Walker',
#  'Gift Ngoepe',
#  'Joey Lucchesi',
#  'Patrick Corbin',
#  'John Lackey',
#  'Ivan Nova',
#  'Alex Wood',
#  'Walker Buehler',
#  'Carlos Martinez',
#  'Johnny Cueto',
#  'Anthony DeSclafani',
#  'Mike Soroka',
#  'Dan Straily',
#  'Jose Quintana',
#  'Sandy Alcantara',
#  'Merrill Kelly',
#  'Mike Foltynewicz',
#  'Dakota Hudson',
#  'Sonny Gray',
#  'Jimmy Nelson',
#  'Andrew Suarez',
#  'Sean Newcomb']

# %%
len(final_player_list)
# Out:
# 845

# %%
#Checking to make sure length of unique names matches player list.
savant_df.Player.value_counts()
# Out:
#  McCutchen, Andrew    4
#  Gardner, Brett       4
#  Devers, Rafael       4
#  Lindor, Francisco    4
#  Gregorius, Didi      4
#                      ..
#  Alcantara, Sandy     1
#  Paredes, Isaac       1
#  Cecchini, Gavin      1
#  Robert, Luis         1
#  Leake, Mike          1
# Name: Player, Length: 845, dtype: int64

# %% [markdown]
# ## Moving in BBREF Data

# %%
def Player_URL_Generator(player_list):
    '''
    Takes a list of player names, with each name being an entry of first name and last name.
    Returns a URL on baseball reference to each player's original page.
    '''
    separated_names = [player.split(" ") for player in player_list]
    url_list = []
    for i, player in enumerate(separated_names):
        if len(separated_names[i][1]) <= 5:
            url = 'https://www.baseball-reference.com/players/{}/{}{}01.shtml'.format(separated_names[i][1][0].lower(), separated_names[i][1].lower(), separated_names[i][0][0:2].lower())
        else:
            url = 'https://www.baseball-reference.com/players/{}/{}{}01.shtml'.format(separated_names[i][1][0].lower(), separated_names[i][1][0:5].lower(), separated_names[i][0][0:2].lower())
        url_list.append(url)
    return url_list

# %%
def Player_Soup_Generator(player_list):
    '''
    Takes in a list of players and returns Beautiful Soup objects.
    '''
    url_list = Player_URL_Generator(player_list)
    response_list = [requests.get(url) for url in url_list]
    soup_list = []
    for response in response_list:
        page = response.text
        soup_list.append(BeautifulSoup(page,'lxml'))
    return soup_list

# %%
def Pull_Player_Seasons(player_soup):
    '''
    Takes in a player's soup object.
    Returns a list of the season the player played in.
    '''
    seasons = player_soup.find_all('tr', attrs={'id':re.compile('batting_standard.')})
    #seasons = player_soup.find_all('tr', attrs={'data-stat':re.compile('')})
    seasons_played = []
    for season in seasons:
        season_item = [str(item.get_text()) for item in season.find_all('th')]
        seasons_played.append(season_item)
    return seasons_played

# %%
def Pull_Player_Stats(player_soup):
    '''
    Takes in a player's soup object.
    Returns a list of stat lines by season.
    '''
    stat_line = player_soup.find_all('tr', attrs={'id':re.compile('batting_standard.')})
    career_stats = []
    for season in stat_line:
        season_stat_line = [item.get_text() for item in season.find_all('td')]
        career_stats.append(season_stat_line)
    for i,year in enumerate(career_stats):
        career_stats[i].insert(0,Pull_Player_Seasons(player_soup)[i][0])
    return career_stats

# %%
def Player_Dataframe_Builder(player_soup_list):
    '''
    Takes in a list of BeautifulSoup Objects, returns a data frame of their Baseball-Reference stats.
    '''
    i = 0
    for player in player_soup_list:
        header = player.find_all('th', attrs={'class': 'poptip'})
        columns = [col.get_text() for col in header]
        if i == 0:
            compiled_player_df = pd.DataFrame(columns=columns)
            compiled_player_df['Name'] = ''
            i += 1
        
        current_player_df = pd.DataFrame(Pull_Player_Stats(player), columns=columns)
  
        #Adding Player Name as a column:
        name = player.title.text.split("Stats")[0]
        current_player_df['Name'] = name
            
        compiled_player_df = pd.concat([compiled_player_df, current_player_df], ignore_index=True)
    num_cols = ['Age', 'G', 'PA', 'AB', 'R','H','2B','3B','HR','RBI','SB','CS','BB','SO','BA','OBP','SLG','OPS','OPS+','TB','GDP','HBP','SH','SF','IBB']
    compiled_player_df[num_cols] = compiled_player_df[num_cols].apply(pd.to_numeric, errors='coerce', axis=1)
    return compiled_player_df

# %%
my_soup_list = Player_Soup_Generator(final_player_list)

# %%
for player in my_soup_list:
        i = 0
        header = player.find_all('th', attrs={'class': 'poptip'})
        columns = [col.get_text() for col in header]
        if i == 0:
            compiled_player_df = pd.DataFrame(columns=columns)
            compiled_player_df['Name'] = ''
            i += 1
        current_player_df = pd.DataFrame(Pull_Player_Stats(player), columns=columns)
  
        #Adding Player Name as a column:
        name = player.title.text.split("Stats")[0]
        current_player_df['Name'] = name
            
        compiled_player_df = pd.concat([compiled_player_df, current_player_df], ignore_index=True)

# %%
multiple_player_df = Player_Dataframe_Builder(my_soup_list)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     567     try:
# --> 568         columns = _validate_or_indexify_columns(content, columns)
#     569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     691             # caller's responsibility to check for this...
# --> 692             raise AssertionError(
#     693                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 34 columns passed, passed data had 30 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-bcb0cf3d5dc3> in <module>
# ----> 1 multiple_player_df = Player_Dataframe_Builder(my_soup_list)
#
# <ipython-input-51-d513a3c6627e> in Player_Dataframe_Builder(player_soup_list)
#      12             i += 1
#      13
# ---> 14         current_player_df = pd.DataFrame(Pull_Player_Stats(player), columns=columns)
#      15
#      16         #Adding Player Name as a column:
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     526         return [], []  # columns if columns is not None else []
#     527     if isinstance(data[0], (list, tuple)):
# --> 528         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     529     elif isinstance(data[0], abc.Mapping):
#     530         return _list_of_dict_to_arrays(
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#     570     except AssertionError as e:
# --> 571         raise ValueError(e) from e
#     572     return result, columns
#     573
#
# ValueError: 34 columns passed, passed data had 30 columns

# %%
multiple_player_df.Name.value_counts()

# %%
multiple_player_df.head()
