# %% [markdown]
# ## Using BeautifulSoup/Selenium to Scrape BaseballSavant

# %% [markdown]
# First, importing needed packages:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 20,10
import numpy as np
import glob
from scipy import stats
from bs4 import BeautifulSoup
import requests
import re
from IPython.core.display import display, HTML    # make sure Jupyter knows to display it as HTML

# %% [markdown]
# Importing selenium and setting chrome driver:

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
#Data from 2015-2020, players with at least 200 PA in that given season:
savant_url = 'https://baseballsavant.mlb.com/leaderboard/custom?year=2020,2019,2018,2017,2016,2015&type=batter&filter=&sort=16&sortDir=desc&min=200&selections=player_age,b_total_pa,b_game,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,solidcontact_percent,hard_hit_percent,z_swing_percent,oz_swing_percent,pull_percent,straightaway_percent,opposite_percent,groundballs_percent,flyballs_percent,linedrives_percent,sprint_speed,&chart=true&x=player_age&y=player_age&r=no&chartType=beeswarm'

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(savant_url)

# %%
driver.page_source[:1000]
# Out:
# '<html lang="en_US" class=" device-desktop"><head>\n    <title>Statcast Custom Leaderboards | baseballsavant.com </title>\n\n    <!-- meta meta tag -->\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge">\n    <meta http-equiv="Cache-Control" content="no-cache">\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="Expires" content="-1">\n    <meta name="keywords" content="Baseball Savant">\n    <!-- -->\n    <meta property="og:title" content="Statcast Custom Leaderboards">\n    <meta itemprop="name" content="Statcast Custom Leaderboards baseballsavant.com">\n    \n    <meta property="og:site_name" content="baseballsavant.com">\n    <meta property="og:type" content="website">\n    \n    <meta property="og:image" content="https://baseballsavant.mlb.com/site-core/images/statcast-logo-gcp-social.png">\n    <meta itemprop="image" content="https://baseballsavant.mlb.com/site-core/images/statcast-logo-gcp-social.png">\n     <meta name="twitter:card" content='

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
headers = soup.find('div', id='sortable_stats').find_all('th')

# %% [markdown]
# Finding Table Rows:

# %%
columns = [col.get_text() for col in headers]

# %%
print(columns)
# Out:
# ['Rk.', 'Player', 'Year', 'Age', 'PA', 'G', 'Avg EV (MPH)', 'Avg LA (°)', 'Barrel%', 'Solid Contact %', 'Hard Hit %', 'Zone Swing %', 'Out of Zone Swing %', 'Pull %', 'Straight Away %', 'Oppo %', 'GB%', 'FB%', 'LD %', 'Sprint Speed']

# %%
savant_df = pd.DataFrame(columns=columns)
savant_df.head()
# Out:
# Empty DataFrame
# Columns: [Rk., Player, Year, Age, PA, G, Avg EV (MPH), Avg LA (°), Barrel%, Solid Contact %, Hard Hit %, Zone Swing %, Out of Zone Swing %, Pull %, Straight Away %, Oppo %, GB%, FB%, LD %, Sprint Speed]
# Index: []

# %% [markdown]
# Finding Stats:

# %%
stats_test = soup.find('div', id='sortable_stats').find_all('tr')

# %%
stats = [col.get_text() for col in stats_test]

# %%
stat_lines = soup.find('div', id='sortable_stats').find_all('tr')
compiled_stats = []
for line_item in stat_lines:
    ind_stat_line = [item.get_text() for item in line_item.find_all('td')]
    compiled_stats.append(ind_stat_line)
    final_stats = compiled_stats[1:]

# %% [markdown]
# Building DataFrame:

# %%
savant_df = pd.DataFrame(final_stats, columns=columns)
num_cols = ['Age','G','PA','Year','Avg EV (MPH)','Avg LA (°)','Barrel%','Solid Contact %','Hard Hit %','Zone Swing %','Out of Zone Swing %','Pull %','Straight Away %','Oppo %','GB%','FB%','LD %','Sprint Speed']
savant_df[num_cols] = savant_df[num_cols].apply(pd.to_numeric, errors='coerce', axis=1)
savant_df.set_index(savant_df['Rk.'], inplace=True)
savant_df.drop(columns='Rk.',inplace=True)
savant_df.head()
# Out:
#                       Player    Year   Age     PA      G  Avg EV (MPH)  \
# Rk.
# 1     Saltalamacchia, Jarrod  2016.0  31.0  292.0   92.0          89.2
# 2              Schimpf, Ryan  2016.0  28.0  330.0   89.0          90.3
# 3                Gallo, Joey  2017.0  24.0  532.0  145.0          93.3
# 4            Carpenter, Matt  2018.0  33.0  677.0  156.0          90.7
# 5                 Bruce, Jay  2019.0  32.0  333.0   98.0          90.2
#
#      Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  Zone Swing %  \
# Rk.
# 1          21.4     11.6              6.8        35.4          65.7
# 2          29.7     16.7              8.0        41.4          64.7
# 3          23.0     22.1              8.3        52.2          72.7
# 4          21.6     13.7             11.5        44.7          57.1
# 5          21.4     13.4              8.2        43.7          79.6
#
#      Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# Rk.
# 1                   23.9    44.2             34.0    21.8  31.3  43.5  19.7
# 2                   23.4    41.4             33.9    24.7  20.1  42.0  21.8
# 3                   28.2    50.2             29.2    20.6  29.2  37.9  22.1
# 4                   18.5    47.6             30.7    21.7  28.3  37.8  28.5
# 5                   37.0    42.9             29.9    27.3  29.4  37.7  19.9
#
#      Sprint Speed
# Rk.
# 1            25.6
# 2            28.2
# 3            27.8
# 4            26.5
# 5            26.7

# %%
savant_df.Player.value_counts()
# Out:
#  McCutchen, Andrew         6
#  Sano, Miguel              6
#  Ramirez, Jose             6
#  Semien, Marcus            6
#  Martinez, J.D.            6
#                           ..
#  Bourgeois, Jason          1
#  Castillo, Rusney          1
#  Morneau, Justin           1
#  Navarro, Dioner           1
#  Bethancourt, Christian    1
# Name: Player, Length: 646, dtype: int64

# %%
savant_df
# Out:
#        Rk.                   Player    Year   Age    PA     G  Avg EV (MPH)  \
# 0        1   Saltalamacchia, Jarrod  2016.0  31.0   292    92          89.2
# 1        2            Schimpf, Ryan  2016.0  28.0   330    89          90.3
# 2        3              Gallo, Joey  2017.0  24.0   532   145          93.3
# 3        4          Carpenter, Matt  2018.0  33.0   677   156          90.7
# 4        5               Bruce, Jay  2019.0  32.0   333    98          90.2
# ...    ...                      ...     ...   ...   ...   ...           ...
# 1888  1889        Jankowski, Travis  2016.0  25.0   383   131          86.2
# 1889  1890             LeMahieu, DJ  2016.0  28.0   635   146          91.7
# 1890  1891        Jankowski, Travis  2018.0  27.0   387   117          85.6
# 1891  1892           Slater, Austin  2018.0  26.0   225    74          87.3
# 1892  1893        Yelich, Christian  2015.0  24.0   525   126          91.7
#
#       Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  Zone Swing %  \
# 0           21.4     11.6              6.8        35.4          65.7
# 1           29.7     16.7              8.0        41.4          64.7
# 2           23.0     22.1              8.3        52.2          72.7
# 3           21.6     13.7             11.5        44.7          57.1
# 4           21.4     13.4              8.2        43.7          79.6
# ...          ...      ...              ...         ...           ...
# 1888         0.8      1.3              1.3        26.9          56.9
# 1889         5.9      4.9              5.6        47.5          59.2
# 1890         3.3      0.7              1.1        19.3          59.2
# 1891         2.6      2.3              0.8        35.1          65.9
# 1892         0.0      4.8              5.6        45.1          63.7
#
#       Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# 0                    23.9    44.2             34.0    21.8  31.3  43.5  19.7
# 1                    23.4    41.4             33.9    24.7  20.1  42.0  21.8
# 2                    28.2    50.2             29.2    20.6  29.2  37.9  22.1
# 3                    18.5    47.6             30.7    21.7  28.3  37.8  28.5
# 4                    37.0    42.9             29.9    27.3  29.4  37.7  19.9
# ...                   ...     ...              ...     ...   ...   ...   ...
# 1888                 21.4    20.2             43.3    36.6  62.2  10.1  26.5
# 1889                 23.0    20.8             42.0    37.2  52.9  10.1  33.7
# 1890                 18.7    30.1             39.9    30.1  60.1  10.1  25.4
# 1891                 28.0    23.7             36.6    39.7  63.4   9.2  22.9
# 1892                 24.5    26.7             46.4    26.9  63.7   8.5  27.5
#
#       Sprint Speed
# 0             25.6
# 1             28.2
# 2             27.8
# 3             26.5
# 4             26.7
# ...            ...
# 1888          29.5
# 1889          27.1
# 1890          29.0
# 1891          28.0
# 1892          28.8
#
# [1893 rows x 20 columns]

# %% [markdown]
# Driver's work here is done.

# %%
driver.close()

# %% [markdown]
# Creating a list of names that can feed into the BBREF code:

# %%
player_column = savant_df.Player

# %%
player_column.drop_duplicates(inplace=True)

# %%
player_list = player_column.tolist()

# %%
player_list_split = [player.split(', ') for player in player_list]
for player in player_list_split:
    player[0] = player[0].strip()

final_player_list = [(player[1] + ' ' + player[0]) for player in player_list_split]

# %%
final_player_list
# Out:
# ['Tim Locastro',
#  'Byron Buxton',
#  'Adam Engel',
#  'Delino DeShields',
#  'Trea Turner',
#  'Billy Hamilton',
#  'Garrett Hampson',
#  'Mallex Smith',
#  'Bradley Zimmer',
#  'Harrison Bader',
#  'Adalberto Mondesi',
#  'Keon Broxton',
#  'Peter Bourjos',
#  'Paulo Orlando',
#  'Jon Berti',
#  'Cesar Hernandez',
#  'Kevin Kiermaier',
#  'Rajai Davis',
#  'Mike Trout',
#  'Starling Marte',
#  'Justin Maxwell',
#  'Trevor Story',
#  'Dee Strange-Gordon',
#  'Ronald Acuna Jr.',
#  'Oscar Mercado',
#  'Lewis Brinson',
#  'Richie Martin',
#  'Brett Lawrie',
#  'Jarrod Dyson',
#  'Travis Jankowski',
#  'Tommy Edman',
#  'Nick Senzel',
#  'Manuel Margot',
#  'Jake Marisnick',
#  'Jeremy Hazelbaker',
#  "Shawn O'Malley",
#  'Fernando Tatis Jr.',
#  'Scott Kingery',
#  'Amed Rosario',
#  'Dansby Swanson',
#  'Victor Robles',
#  'Ryan Cordell',
#  'Allen Cordoba',
#  'Billy Burns',
#  'Alen Hanson',
#  'Whit Merrifield',
#  'Victor Reyes',
#  'Teoscar Hernandez',
#  'Nick Williams',
#  'Ketel Marte',
#  'Wilmer Difo',
#  'Avisail Garcia',
#  'Cameron Maybin',
#  'Aledmys Diaz',
#  "Chase d'Arnaud",
#  'Andrew McCutchen',
#  'Lorenzo Cain',
#  'Trent Grisham',
#  'Luis Robert',
#  'Dustin Fowler',
#  'JaCoby Jones',
#  'Niko Goodrum',
#  'Brett Gardner',
#  'Greg Allen',
#  'Harold Ramirez',
#  'Chris Taylor',
#  'Jose Pirela',
#  'Gorkys Hernandez',
#  'AJ Pollock',
#  'Phil Gosselin',
#  'Michael A. Taylor',
#  'Aaron Altherr',
#  'Yoan Moncada',
#  'Kris Bryant',
#  'Steven Souza Jr.',
#  'Adam Eaton',
#  'Marcus Semien',
#  'Javier Baez',
#  'Christian Yelich',
#  'Chris Owings',
#  'JB Shuck',
#  'Cory Spangenberg',
#  'Cody Bellinger',
#  'Jorge Alfaro',
#  'Ian Happ',
#  'Jose Peraza',
#  'Mikie Mahtook',
#  'Gregor Blanco',
#  'J.T. Realmuto',
#  'Adeiny Hechavarria',
#  'George Springer',
#  'Danny Santana',
#  'Hunter Pence',
#  'Tim Anderson',
#  'Jace Peterson',
#  'Jorge Polanco',
#  'Tyler Holt',
#  'Carlos Gomez',
#  'Aristides Aquino',
#  'Matt Chapman',
#  'Ozzie Albies',
#  'Brandon Nimmo',
#  'Tommy Pham',
#  'Kevin Pillar',
#  'Mookie Betts',
#  'Jean Segura',
#  'Ian Desmond',
#  'Joey Wendle',
#  'Raimel Tapia',
#  'Jose Altuve',
#  'Guillermo Heredia',
#  'Leury Garcia',
#  'Juan Lagares',
#  'Randal Grichuk',
#  'Eduardo Nunez',
#  'Tyler Goeddel',
#  'Nick Solak',
#  'Hunter Dozier',
#  'Nicky Lopez',
#  'Ramon Laureano',
#  'Brandon Dixon',
#  'Kevin Newman',
#  'Jorge Bonifacio',
#  'Wil Myers',
#  'Francisco Lindor',
#  'Eddie Rosario',
#  'Brock Holt',
#  'Gregory Polanco',
#  'Logan Forsythe',
#  'Abraham Almonte',
#  'Dexter Fowler',
#  'David Dahl',
#  'Addison Russell',
#  'Nick Ahmed',
#  'Jose Iglesias',
#  'Tyler Saladino',
#  'Rosell Herrera',
#  'Bo Bichette',
#  'Dylan Moore',
#  'Albert Almora Jr.',
#  'Paul DeJong',
#  'Ben Gamel',
#  'Joey Rickard',
#  'Yolmer Sanchez',
#  'Aaron Hicks',
#  'Alex Presley',
#  'Yasiel Puig',
#  'Didi Gregorius',
#  'Ben Revere',
#  'Yoenis Cespedes',
#  'Jason Bourgeois',
#  'Hernan Perez',
#  'Jefry Marte',
#  'Shohei Ohtani',
#  'Willy Adames',
#  'Jordan Luplow',
#  'Cavan Biggio',
#  'Stevie Wilkerson',
#  'Bryce Harper',
#  'Andrew Benintendi',
#  'Patrick Kivlehan',
#  'Scott Schebler',
#  'Xander Bogaerts',
#  'Ronald Torreyes',
#  'Matt Szczur',
#  'Justin Upton',
#  'Matt Duffy',
#  'Carlos Correa',
#  'Anthony Gose',
#  'Alex Bregman',
#  'Adam Duvall',
#  'Trayce Thompson',
#  'Tyler Naquin',
#  'Christian Bethancourt',
#  'Charlie Culberson',
#  'Steven Duggar',
#  'Aaron Judge',
#  'Adam Rosales',
#  'Charlie Blackmon',
#  'Mark Canha',
#  'Devon Travis',
#  'Tim Beckham',
#  'Marcell Ozuna',
#  'Austin Jackson',
#  'Angel Pagan',
#  'Alex Rios',
#  'Willson Contreras',
#  'Ryan Schimpf',
#  'Rafael Ortega',
#  'Ezequiel Carrera',
#  'B.J. Upton',
#  'Coco Crisp',
#  'Evan White',
#  'Bryan Reynolds',
#  'Jorge Soler',
#  'Austin Meadows',
#  'Rougned Odor',
#  'Nick Castellanos',
#  'Jacoby Ellsbury',
#  'Leonys Martin',
#  'Sam Fuld',
#  'Brandon Guyer',
#  'Adam Jones',
#  'Omar Infante',
#  'Max Kepler',
#  'Anthony Rendon',
#  'Michael Bourn',
#  'Isiah Kiner-Falefa',
#  'David Fletcher',
#  'Yairo Munoz',
#  'Michael Chavis',
#  'Luis Rengifo',
#  'Rafael Devers',
#  'Jose Ramirez',
#  'Kelby Tomlinson',
#  'JT Riddle',
#  'Joey Butler',
#  'Ender Inciarte',
#  'Will Middlebrooks',
#  'Colby Rasmus',
#  'Erick Aybar',
#  'Marlon Byrd',
#  'Jonathan Villar',
#  'Eduardo Escobar',
#  'Lourdes Gurriel Jr.',
#  'Phillip Ervin',
#  'Johnny Field',
#  'Austin Slater',
#  'Ronny Rodriguez',
#  'Mike Tauchman',
#  'Brian Goodwin',
#  'Mike Freeman',
#  'Mitch Haniger',
#  'Robbie Grossman',
#  'Stephen Piscotty',
#  'Johnny Giavotella',
#  'Derek Norris',
#  'Elian Herrera',
#  'Ichiro Suzuki',
#  'Ryan Rua',
#  'Josh Harrison',
#  'Oswaldo Arcia',
#  'Brett Eibner',
#  'Nolan Reimold',
#  'Denard Span',
#  'Kyle Lewis',
#  'Austin Riley',
#  'Adam Haseley',
#  'Joey Gallo',
#  'Giancarlo Stanton',
#  'Josh Reddick',
#  'Blake Swihart',
#  'Brian Dozier',
#  'Odubel Herrera',
#  'J.D. Martinez',
#  'Will Venable',
#  'Danny Espinosa',
#  'Miguel Sano',
#  'Brad Miller',
#  'Jeff McNeil',
#  'Jake Bauers',
#  'Michael Conforto',
#  'Miguel Andujar',
#  'Jackie Bradley Jr.',
#  'Jake Cave',
#  'Corey Dickerson',
#  'Enrique Hernandez',
#  'Brandon Lowe',
#  'Eloy Jimenez',
#  'Max Muncy',
#  'Alcides Escobar',
#  'Jordy Mercer',
#  'Elvis Andrus',
#  'Alejandro De Aza',
#  'Chris Young',
#  'Mike Aviles',
#  'Aaron Hill',
#  'Orlando Arcia',
#  'Greg Garcia',
#  'Alex Dickerson',
#  'Jake Smolinski',
#  'Jason Heyward',
#  'Derek Dietrich',
#  'Rickie Weeks Jr.',
#  'Jose Reyes',
#  'David Bote',
#  'Daniel Robertson',
#  'Dixon Machado',
#  'Kolten Wong',
#  'Yuli Gurriel',
#  'Trey Mancini',
#  'Chad Pinder',
#  'Jose Martinez',
#  'Chase Utley',
#  'Tyler Collins',
#  'David Peralta',
#  'Curtis Granderson',
#  'Freddy Galvis',
#  'Desmond Jennings',
#  'Kyle Tucker',
#  'Tony Kemp',
#  'Jurickson Profar',
#  'Anthony Santander',
#  'Dawel Lugo',
#  'Mike Yastrzemski',
#  'Adam Frazier',
#  'Andrelton Simmons',
#  'Jonathan Schoop',
#  'Starlin Castro',
#  'Michael Saunders',
#  'Rusney Castillo',
#  'Scott Van Slyke',
#  'Kelly Johnson',
#  'Alex Verdugo',
#  'Carlos Gonzalez',
#  'Billy McKinney',
#  'J.P. Crawford',
#  'Clint Frazier',
#  'Matt Beaty',
#  'Andrew Romine',
#  'Darwin Barney',
#  'Alex Guerrero',
#  'Evan Gattis',
#  'Manny Machado',
#  'Daniel Descalso',
#  'Jimmy Paredes',
#  'Paul Goldschmidt',
#  'Eric Campbell',
#  'Evan Longoria',
#  'Andre Ethier',
#  'Eugenio Suarez',
#  'Ryan Braun',
#  'Carlos Asuaje',
#  'Austin Barnes',
#  'John Ryan Murphy',
#  'Juan Soto',
#  'Danny Jansen',
#  'Jeimer Candelario',
#  'Ildemaro Vargas',
#  'Jose Osuna',
#  'Yasmany Tomas',
#  'Ryan Goins',
#  'Jason Kipnis',
#  'DJ LeMahieu',
#  'Domonic Brown',
#  'Brandon Barnes',
#  'Zack Cozart',
#  'Brandon Drury',
#  'Ramon Flores',
#  'Cristhian Adames',
#  'Ben Zobrist',
#  'Renato Nunez',
#  'Pedro Severino',
#  'Hunter Renfroe',
#  "Ryan O'Hearn",
#  'Luis Urias',
#  'Garrett Cooper',
#  'Francisco Mejia',
#  'Harold Castro',
#  'Christian Walker',
#  'Josh Bell',
#  'Domingo Santana',
#  'Elias Diaz',
#  'Norichika Aoki',
#  'Joc Pederson',
#  'Cliff Pennington',
#  'Shane Victorino',
#  'Michael Cuddyer',
#  'Jake Lamb',
#  'J.D. Davis',
#  'Tyler Austin',
#  'Nicky Delmonico',
#  'Kyle Schwarber',
#  'Austin Nola',
#  'Eric Hosmer',
#  'Chris Herrmann',
#  'Eric Thames',
#  'Lonnie Chisenhall',
#  'Shane Peterson',
#  'Sean Rodriguez',
#  'Mark Trumbo',
#  'Jimmy Rollins',
#  'Tony Wolters',
#  'Kirk Nieuwenhuis',
#  'Josh Donaldson',
#  "Travis d'Arnaud",
#  'Khris Davis',
#  'Ryan Zimmerman',
#  'Gleyber Torres',
#  'Brian Anderson',
#  'Nomar Mazara',
#  'Danny Valencia',
#  'Miguel Rojas',
#  'Dustin Pedroia',
#  'Corey Seager',
#  'Keston Hiura',
#  'Isan Diaz',
#  'Luis Arraez',
#  'Christin Stewart',
#  'Grayson Greiner',
#  'Andrew Knapp',
#  'Jose Abreu',
#  'Trevor Plouffe',
#  'Steve Pearce',
#  'Ian Kinsler',
#  'Kevin Plawecki',
#  'Preston Tucker',
#  'Matt Carpenter',
#  'David Murphy',
#  'Brandon Moss',
#  'Chris Davis',
#  'Shin-Soo Choo',
#  'Tyler White',
#  'Cody Asche',
#  'David Freese',
#  'Yan Gomes',
#  'Ehire Adrianza',
#  'Yordan Alvarez',
#  'Josh VanMeter',
#  'Hanser Alberto',
#  'Scooter Gennett',
#  'James McCann',
#  'Brandon Crawford',
#  'Alexi Amarista',
#  'Wilin Rosario',
#  'Ryan Flaherty',
#  'Martin Prado',
#  'Andres Blanco',
#  'Logan Morrison',
#  'Jay Bruce',
#  'Hanley Ramirez',
#  'Ryan Raburn',
#  'Franmil Reyes',
#  'Johan Camargo',
#  'T.J. Rivera',
#  'Taylor Motter',
#  'Marwin Gonzalez',
#  'Jed Lowrie',
#  'Brandon Belt',
#  'Howie Kendrick',
#  'Jung Ho Kang',
#  'Joe Panik',
#  'Maikel Franco',
#  'Ben Paulsen',
#  'Gio Urshela',
#  'Jonny Gomes',
#  'ByungHo Park',
#  'Travis Shaw',
#  'Freddie Freeman',
#  'Cheslor Cuthbert',
#  'John Hicks',
#  'Kevan Smith',
#  'Ryon Healy',
#  'Eric Sogard',
#  'Mike Zunino',
#  'Travis Snider',
#  'Gordon Beckham',
#  'Alexei Ramirez',
#  'Gerardo Parra',
#  'Asdrubal Cabrera',
#  'Stephen Drew',
#  'Jason Castro',
#  'Chris Carter',
#  'Donovan Solano',
#  'Daniel Palka',
#  'Justin Turner',
#  'Yandy Diaz',
#  'Pete Alonso',
#  'Stephen Vogt',
#  'Austin Romine',
#  'Matt Joyce',
#  'Todd Frazier',
#  'John Jaso',
#  'Kole Calhoun',
#  'Dustin Ackley',
#  'Chris Coghlan',
#  'Chris Denorfia',
#  'Seth Smith',
#  'Skip Schumaker',
#  'Grady Sizemore',
#  'Joe Mauer',
#  'Torii Hunter',
#  'Carlos Perez',
#  'Daniel Murphy',
#  'Neil Walker',
#  'Ryan McMahon',
#  'Willie Calhoun',
#  'Kyle Seager',
#  'Michael Brantley',
#  'Austin Hedges',
#  'Jon Jay',
#  'Caleb Joseph',
#  'J.J. Hardy',
#  'Jeff Francoeur',
#  'Adrian Beltre',
#  'Adonis Garcia',
#  'Hyun Soo Kim',
#  'Nick Markakis',
#  'Vladimir Guerrero Jr.',
#  'Mitch Garver',
#  'Josh Phegley',
#  'Tyler Moore',
#  'Jarrod Saltalamacchia',
#  'Russell Martin',
#  'David DeJesus',
#  'Juan Uribe',
#  'Nolan Arenado',
#  'Gregorio Petit',
#  'Rhys Hoskins',
#  'C.J. Cron',
#  'Matt Olson',
#  'Tom Murphy',
#  'Melky Cabrera',
#  'Alex Gordon',
#  'Francisco Cervelli',
#  'Nelson Cruz',
#  'Gary Sanchez',
#  'Chris Johnson',
#  'Jhonny Peralta',
#  'Ronald Guzman',
#  'Matt Kemp',
#  'Josh Naylor',
#  'Dwight Smith',
#  'Carlos Santana',
#  'Anthony Rizzo',
#  'Chris Colabello',
#  'Troy Tulowitzki',
#  'Clint Barmes',
#  'Matt Adams',
#  'Nick Hundley',
#  'Ruben Tejada',
#  'Ryan Hanigan',
#  'Matt Holliday',
#  'Jayson Werth',
#  'Clint Robinson',
#  'Brandon Phillips',
#  'Jesse Winker',
#  'Ty France',
#  'Daniel Nava',
#  'Ivan De Jesus Jr.',
#  'Salvador Perez',
#  'Carlos Ruiz',
#  'Luke Maile',
#  'Luke Voit',
#  'Rio Ruiz',
#  'Jeff Mathis',
#  'Christian Vazquez',
#  'Chris Iannetta',
#  'Tyler Flowers',
#  'Manny Pina',
#  'Kurt Suzuki',
#  'Wilmer Flores',
#  'Mike Moustakas',
#  'Mark Reynolds',
#  'Chase Headley',
#  'Tommy La Stella',
#  'Mitch Moreland',
#  'Robinson Chirinos',
#  'Carlos Beltran',
#  'Victor Caratini',
#  'Ji-Man Choi',
#  'Christian Villanueva',
#  'Max Stassi',
#  'Lucas Duda',
#  'Darin Ruf',
#  'Tucker Barnhart',
#  'Roberto Perez',
#  'Jonathan Lucroy',
#  'Yunel Escobar',
#  'Jose Bautista',
#  'Luis Valbuena',
#  'Matt Davidson',
#  'Geovany Soto',
#  'Conor Gillaspie',
#  'David Ross',
#  'Devin Mesoraco',
#  'Yangervis Solarte',
#  'Pedro Alvarez',
#  'Buster Posey',
#  'Joey Votto',
#  'Colin Moran',
#  'Tommy Joseph',
#  'Omar Narvaez',
#  'Pablo Sandoval',
#  'Cameron Rupp',
#  'Martin Maldonado',
#  'Edwin Encarnacion',
#  'Carson Kelly',
#  'Curt Casali',
#  'Kennys Vargas',
#  'Mike Napoli',
#  'Jedd Gyorko',
#  'Franklin Gutierrez',
#  'Justin Morneau',
#  'Greg Bird',
#  'Alex Avila',
#  'Ike Davis',
#  'Sandy Leon',
#  'Matt Wieters',
#  'Chris Gimenez',
#  'Welington Castillo',
#  'Adam Lind',
#  'Rene Rivera',
#  'Miguel Cabrera',
#  'A.J. Ellis',
#  'Alberto Callaspo',
#  'Prince Fielder',
#  'Brett Wallace',
#  'Rowdy Tellez',
#  'Yonder Alonso',
#  'Robinson Cano',
#  'Casey McGehee',
#  'Jesus Aguilar',
#  'Michael Morse',
#  'James Loney',
#  'Erik Kratz',
#  'Jacob Stallings',
#  'Brayan Pena',
#  'Mark Teixeira',
#  'Yasmani Grandal',
#  'Justin Bour',
#  'Hank Conger',
#  'Miguel Montero',
#  'Adam LaRoche',
#  'A.J. Pierzynski',
#  'Kendrys Morales',
#  'Nick Swisher',
#  'Ryan Howard',
#  'Aramis Ramirez',
#  'Justin Smoak',
#  'Willians Astudillo',
#  'Daniel Vogelbach',
#  'Wilson Ramos',
#  'Adrian Gonzalez',
#  'Alex Rodriguez',
#  'Bobby Wilson',
#  'Bruce Maxwell',
#  'Yadier Molina',
#  'Jett Bandy',
#  'Billy Butler',
#  'David Ortiz',
#  'Albert Pujols',
#  'Brian McCann',
#  'Dioner Navarro',
#  'Victor Martinez',
#  'Dae-Ho Lee']

# %%
len(final_player_list)
# Out:
# 646

# %%
#Checking to make sure length of unique names matches player list.
savant_df.Player.value_counts()
# Out:
#  Rosario, Eddie         6
#  Rendon, Anthony        6
#  Reddick, Josh          6
#  Hicks, Aaron           6
#  Betts, Mookie          6
#                        ..
#  Freeman, Mike          1
#  Park, ByungHo          1
#  Palka, Daniel          1
#  Ortega, Rafael         1
#  Astudillo, Willians    1
# Name: Player, Length: 646, dtype: int64

# %% [markdown]
# ## Moving in BBREF Data

# %% [markdown]
# Creating a Baseball reference URL based on a player list input:

# %%
def Player_URL_Generator(player_list):
    '''
    Takes a list of player names, with each name being an entry of first name and last name.
    Returns a URL on baseball reference to each player's original page.
    '''
    separated_names = [player.split(" ") for player in player_list]
    url_list = []
    for i, player in enumerate(separated_names):
        #Stripping punctuation from names:
        new_name = [name.replace(".","") for name in player]
        new_name = [name.replace("'","") for name in new_name]
        #print(len(new_name))
        #In other words, if a player has 3 names not two:
        if len(new_name) == 3:
            comb_name = [new_name[0], new_name[1]+new_name[2]]
            #print(comb_name)
            if len(comb_name[1]) <= 5:
                url = 'https://www.baseball-reference.com/players/{}/{}{}01.shtml'.format(comb_name[1][0].lower(), comb_name[1].lower(), comb_name[0][0:2].lower())
            else:
                url = 'https://www.baseball-reference.com/players/{}/{}{}01.shtml'.format(comb_name[1][0].lower(), comb_name[1][0:5].lower(), comb_name[0][0:2].lower())
        else:    
            if len(new_name[1]) <= 5:
                url = 'https://www.baseball-reference.com/players/{}/{}{}01.shtml'.format(new_name[1][0].lower(), new_name[1].lower(), new_name[0][0:2].lower())
            else:
                url = 'https://www.baseball-reference.com/players/{}/{}{}01.shtml'.format(new_name[1][0].lower(), new_name[1][0:5].lower(), new_name[0][0:2].lower())
        url_list.append(url)
    return url_list

# %% [markdown]
# Testing URL Generator w/ edge cases (apostrophes, periods in name, spaces in name, etc.)

# %%
Player_URL_Generator(["Tyler O'Neill", "Chase d'Arnaud", "C.J. Cron", 'Tommy La Stella','Alejandro De Aza'])
# Out:
# ['https://www.baseball-reference.com/players/o/oneilty01.shtml',
#  'https://www.baseball-reference.com/players/d/darnach01.shtml',
#  'https://www.baseball-reference.com/players/c/croncj01.shtml',
#  'https://www.baseball-reference.com/players/l/lasteto01.shtml',
#  'https://www.baseball-reference.com/players/d/deazaal01.shtml']

# %% [markdown]
# From the Player URL Function, generating a BS4 object:

# %%
def Player_Soup_Generator(player_list):
    '''
    Takes in a list of players and returns Beautiful Soup objects.
    '''
    url_list = Player_URL_Generator(player_list)
    response_list = [requests.get(url) for url in url_list]
    soup_list = []
    for response in response_list:
        page = response.text
        soup_object = BeautifulSoup(page,'lxml')
        name = player.title.text.split("Stats")[0]
        if player_list[i].strip() != name.strip():
            #Add in code for updating URL in this case
        soup_list.append(BeautifulSoup(page,'lxml'))
    return soup_list

# %% [markdown]
# Pull the years the player played from baseball reference:

# %%
def Pull_Player_Seasons(player_soup):
    '''
    Takes in a player's soup object.
    Returns a list of the season the player played in.
    '''
    seasons = player_soup.find_all('tr', attrs={'id':re.compile('batting_standard.')})
    #seasons = player_soup.find_all('tr', attrs={'data-stat':re.compile('')})
    seasons_played = []
    for season in seasons:
        season_item = [str(item.get_text()) for item in season.find_all('th')]
        seasons_played.append(season_item)
    return seasons_played

# %% [markdown]
# Pull the year by year stas from BBREF:

# %%
def Pull_Player_Stats(player_soup):
    '''
    Takes in a player's soup object.
    Returns a list of stat lines by season.
    '''
    stat_line = player_soup.find_all('tr', attrs={'id':re.compile('batting_standard.')})
    career_stats = []
    for season in stat_line:
        season_stat_line = [item.get_text() for item in season.find_all('td')]
        career_stats.append(season_stat_line)
    for i,year in enumerate(career_stats):
        career_stats[i].insert(0,Pull_Player_Seasons(player_soup)[i][0])
    return career_stats

# %% [markdown]
# From the years and stats, build a pandas dataframe:

# %%
def Player_Dataframe_Builder(player_soup_list):
    '''
    Takes in a list of BeautifulSoup Objects, returns a data frame of their Baseball-Reference stats.
    '''
    i=0
    
    for player in player_soup_list:
        header = player.find_all('th', attrs={'class': 'poptip'})
        columns = [col.get_text() for col in header]
        current_player_df = pd.DataFrame(Pull_Player_Stats(player), columns=columns)
        if i ==0:
            compiled_player_df = pd.DataFrame(columns=columns)
            compiled_player_df['Name'] = ''
            i += 1
        #Adding Player Name as a column:
        name = player.title.text.split("Stats")[0]
        current_player_df['Name'] = name
            
        compiled_player_df = pd.concat([compiled_player_df, current_player_df], ignore_index=True)
    num_cols = ['Age', 'G', 'PA', 'AB', 'R','H','2B','3B','HR','RBI','SB','CS','BB','SO','BA','OBP','SLG','OPS','OPS+','TB','GDP','HBP','SH','SF','IBB']
    compiled_player_df[num_cols] = compiled_player_df[num_cols].apply(pd.to_numeric, errors='coerce', axis=1)
    return compiled_player_df

# %% [markdown]
# Test Case, using the final_player_list from the BasebalL Savant Data:

# %%
my_soup_list = Player_Soup_Generator(final_player_list)

# %% [markdown]
# Testing for players whose URL and names don't match using the normal method:

# %%
for i, player in enumerate(my_soup_list):
    name = player.title.text.split("Stats")[0]
    if final_player_list[i].strip() != name.strip():
        print('WRONG!')
        print(name, final_player_list[i])
# Out:
# WRONG!
# Mayo Smith  Mallex Smith
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Adalberto Mondesi
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Dee Strange-Gordon
# WRONG!
# Fernando Tatis  Fernando Tatis Jr.
# WRONG!
# Bill Burns  Billy Burns
# WRONG!
# Alex Diaz  Aledmys Diaz
# WRONG!
# Ri Jones  JaCoby Jones
# WRONG!
# Hanley Ramirez  Harold Ramirez
# WRONG!
# Chink Taylor  Chris Taylor
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Michael A. Taylor
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com JB Shuck
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Tommy Pham
# WRONG!
# Leo Garcia  Leury Garcia
# WRONG!
# Ed Nunez  Eduardo Nunez
# WRONG!
# Adam Russell  Addison Russell
# WRONG!
# José Iglesias  Jose Iglesias
# WRONG!
# Ronald Herrera  Rosell Herrera
# WRONG!
# Albert Almora  Albert Almora Jr.
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Yolmer Sanchez
# WRONG!
# Yoenis Céspedes  Yoenis Cespedes
# WRONG!
# Brian Harper  Bryce Harper
# WRONG!
# Charlie Blackburn  Charlie Blackmon
# WRONG!
# Melvin Upton Jr.  B.J. Upton
# WRONG!
# Nicholas Castellanos  Nick Castellanos
# WRONG!
# Leonys Martín  Leonys Martin
# WRONG!
# Darrin Fletcher  David Fletcher
# WRONG!
# John Butler  Joey Butler
# WRONG!
# Phil Ervin  Phillip Ervin
# WRONG!
# Jocko Fields  Johnny Field
# WRONG!
# Roberto Rodriguez  Ronny Rodriguez
# WRONG!
# Joe Harrington  Josh Harrison
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Giancarlo Stanton
# WRONG!
# J.D. Martin  J.D. Martinez
# WRONG!
# Bruce Miller  Brad Miller
# WRONG!
# Jack Bradley  Jackie Bradley Jr.
# WRONG!
# Enzo Hernandez  Enrique Hernandez
# WRONG!
# Elvio Jimenez  Eloy Jimenez
# WRONG!
# Alex Escobar  Alcides Escobar
# WRONG!
# John Mercer  Jordy Mercer
# WRONG!
# Charlie Young  Chris Young
# WRONG!
# Rickie Weeks  Rickie Weeks Jr.
# WRONG!
# Dave Robertson  Daniel Robertson
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Yuli Gurriel
# WRONG!
# Joe Martin  Jose Martinez
# WRONG!
# Andres Santana  Anthony Santander
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Rusney Castillo
# WRONG!
# Ken Johnson  Kelly Johnson
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com John Ryan Murphy
# WRONG!
# Yasmany Tomás  Yasmany Tomas
# WRONG!
# Brian Barnes  Brandon Barnes
# WRONG!
# Randy Flores  Ramon Flores
# WRONG!
# Gary Cooper  Garrett Cooper
# WRONG!
# Chico Walker  Christian Walker
# WRONG!
# Nori Aoki  Norichika Aoki
# WRONG!
# John Donaldson  Josh Donaldson
# WRONG!
# Brady Anderson  Brian Anderson
# WRONG!
# Minnie Rojas  Miguel Rojas
# WRONG!
# Chris Stewart  Christin Stewart
# WRONG!
# Joe Abreu  Jose Abreu
# WRONG!
# Danny Murphy  David Murphy
# WRONG!
# Chili Davis  Chris Davis
# WRONG!
# Yordan Álvarez  Yordan Alvarez
# WRONG!
# Jack McCandless  James McCann
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Jung Ho Kang
# WRONG!
# Matt Franco  Maikel Franco
# WRONG!
# Joe Hicks  John Hicks
# WRONG!
# Keith Smith  Kevan Smith
# WRONG!
# Allan Ramirez  Alexei Ramirez
# WRONG!
# Yandy Díaz  Yandy Diaz
# WRONG!
# Matthew Joyce  Matt Joyce
# WRONG!
# Danny Murphy  Daniel Murphy
# WRONG!
# Mickey Brantley  Michael Brantley
# WRONG!
# Joey Jay  Jon Jay
# WRONG!
# Jeff Francis  Jeff Francoeur
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Hyun Soo Kim
# WRONG!
# Vladimir Guerrero  Vladimir Guerrero Jr.
# WRONG!
# Marv Olson  Matt Olson
# WRONG!
# Tony Murphy  Tom Murphy
# WRONG!
# Gaby Sanchez  Gary Sanchez
# WRONG!
# Charlie Johnson  Chris Johnson
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com Ivan De Jesus Jr.
# WRONG!
# Santiago Perez  Salvador Perez
# WRONG!
# Robert Perez  Roberto Perez
# WRONG!
# Mark Davidson  Matt Davidson
# WRONG!
# Casey Kelly  Carson Kelly
# WRONG!
# Mike Morse  Michael Morse
# WRONG!
# Page Not Found (404 error) | Baseball-Reference.com A.J. Pierzynski
# WRONG!
# Bob Wilson  Bobby Wilson
# WRONG!
# Bill Butler  Billy Butler
# WRONG!
# David Lee  Dae-Ho Lee

# %%
multiple_player_df = Player_Dataframe_Builder(my_soup_list)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     567     try:
# --> 568         columns = _validate_or_indexify_columns(content, columns)
#     569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     691             # caller's responsibility to check for this...
# --> 692             raise AssertionError(
#     693                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 34 columns passed, passed data had 30 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-bcb0cf3d5dc3> in <module>
# ----> 1 multiple_player_df = Player_Dataframe_Builder(my_soup_list)
#
# <ipython-input-153-44aede9be046> in Player_Dataframe_Builder(player_soup_list)
#       8         header = player.find_all('th', attrs={'class': 'poptip'})
#       9         columns = [col.get_text() for col in header]
# ---> 10         current_player_df = pd.DataFrame(Pull_Player_Stats(player), columns=columns)
#      11         if i ==0:
#      12             compiled_player_df = pd.DataFrame(columns=columns)
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     526         return [], []  # columns if columns is not None else []
#     527     if isinstance(data[0], (list, tuple)):
# --> 528         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     529     elif isinstance(data[0], abc.Mapping):
#     530         return _list_of_dict_to_arrays(
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#     570     except AssertionError as e:
# --> 571         raise ValueError(e) from e
#     572     return result, columns
#     573
#
# ValueError: 34 columns passed, passed data had 30 columns

# %%
multiple_player_df.Name.value_counts()

# %%
multiple_player_df.head()

# %%
my_list = ['Eloy Jimenez','Jose Abreu','Mike Trout','Adam Eaton','Frank Thomas']

# %%
url_list = Player_URL_Generator(my_list)
response_list = [requests.get(url) for url in url_list]
soup_list = []
for response in response_list:
    page = response.text
    soup_list.append(BeautifulSoup(page,'lxml'))
# Out:
# <built-in method title of str object at 0x7f90e6498000>
# <built-in method title of str object at 0x7f90ed79c000>
# <built-in method title of str object at 0x7f90fd200000>
# <built-in method title of str object at 0x7f9124e6d000>
# <built-in method title of str object at 0x7f90e6498000>

# %%
for i, player in enumerate(soup_list):
    name = player.title.text.split("Stats")[0]
    print(name)
    print(my_list[i])
    if str(name) != str(my_list[i]):
        print('WRONG!')
    else:
        print('MATC!')
# Out:
# Elvio Jimenez
# Eloy Jimenez
# WRONG!
# Joe Abreu
# Jose Abreu
# WRONG!
# Mike Trout
# Mike Trout
# WRONG!
# Adam Eaton
# Adam Eaton
# WRONG!
# Frosty Thomas
# Frank Thomas
# WRONG!
