# %% [markdown]
# ## Using BeautifulSoup/Selenium to Scrape BaseballSavant

# %% [markdown]
# First, importing needed packages:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 20,10
import numpy as np
import glob
from scipy import stats
from bs4 import BeautifulSoup
import requests
import re
from IPython.core.display import display, HTML    # make sure Jupyter knows to display it as HTML

# %% [markdown]
# Importing selenium and setting chrome driver:

# %%
import time, os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
#Data from 2015-2020, players with at least 200 PA in that given season:
savant_url = 'https://baseballsavant.mlb.com/leaderboard/custom?year=2020,2019,2018,2017,2016,2015&type=batter&filter=&sort=16&sortDir=desc&min=200&selections=player_age,b_total_pa,b_game,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,solidcontact_percent,hard_hit_percent,z_swing_percent,oz_swing_percent,pull_percent,straightaway_percent,opposite_percent,groundballs_percent,flyballs_percent,linedrives_percent,sprint_speed,&chart=true&x=player_age&y=player_age&r=no&chartType=beeswarm'

# %% [markdown]
# If using wOBA, insert this link above:
# https://baseballsavant.mlb.com/leaderboard/custom?year=2020,2019,2018,2017,2016,2015&type=batter&filter=&sort=16&sortDir=desc&min=200&selections=player_age,b_total_pa,b_game,woba,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,solidcontact_percent,hard_hit_percent,z_swing_percent,oz_swing_percent,pull_percent,straightaway_percent,opposite_percent,groundballs_percent,flyballs_percent,linedrives_percent,sprint_speed,&chart=true&x=player_age&y=player_age&r=no&chartType=beeswarm

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(savant_url)

# %%
driver.page_source[:1000]
# Out:
# '<html lang="en_US" class=" device-desktop"><head>\n    <title>Statcast Custom Leaderboards | baseballsavant.com </title>\n\n    <!-- meta meta tag -->\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge">\n    <meta http-equiv="Cache-Control" content="no-cache">\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="Expires" content="-1">\n    <meta name="keywords" content="Baseball Savant">\n    <!-- -->\n    <meta property="og:title" content="Statcast Custom Leaderboards">\n    <meta itemprop="name" content="Statcast Custom Leaderboards baseballsavant.com">\n    \n    <meta property="og:site_name" content="baseballsavant.com">\n    <meta property="og:type" content="website">\n    \n    <meta property="og:image" content="https://baseballsavant.mlb.com/site-core/images/statcast-logo-gcp-social.png">\n    <meta itemprop="image" content="https://baseballsavant.mlb.com/site-core/images/statcast-logo-gcp-social.png">\n     <meta name="twitter:card" content='

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
headers = soup.find('div', id='sortable_stats').find_all('th')

# %% [markdown]
# Finding Table Rows:

# %%
columns = [col.get_text() for col in headers]

# %%
print(columns)
# Out:
# ['Rk.', 'Player', 'Year', 'Age', 'PA', 'G', 'Avg EV (MPH)', 'Avg LA (°)', 'Barrel%', 'Solid Contact %', 'Hard Hit %', 'Zone Swing %', 'Out of Zone Swing %', 'Pull %', 'Straight Away %', 'Oppo %', 'GB%', 'FB%', 'LD %', 'Sprint Speed']

# %%
savant_df = pd.DataFrame(columns=columns)
savant_df.head()
# Out:
# Empty DataFrame
# Columns: [Rk., Player, Year, Age, PA, G, Avg EV (MPH), Avg LA (°), Barrel%, Solid Contact %, Hard Hit %, Zone Swing %, Out of Zone Swing %, Pull %, Straight Away %, Oppo %, GB%, FB%, LD %, Sprint Speed]
-player/592178'], ['/savant-player/572816'], ['/savant-player/543510'], ['/savant-player/519390'], ['/savant-player/606192'], ['/savant-player/572073'], ['/savant-player/521692'], ['/savant-player/621566'], ['/savant-player/640449'], ['/savant-player/656941'], ['/savant-player/489138'], ['/savant-player/572821'], ['/savant-player/489267'], ['/savant-player/446334'], ['/savant-player/670541'], ['/savant-player/446263'], ['/savant-player/624424'], ['/savant-player/553993'], ['/savant-player/521692'], ['/savant-player/471083'], ['/savant-player/424325'], ['/savant-player/434158'], ['/savant-player/502082'], ['/savant-player/643393'], ['/savant-player/605141'], ['/savant-player/476704'], ['/savant-player/475253'], ['/savant-player/596115'], ['/savant-player/592178'], ['/savant-player/434158'], ['/savant-player/641355'], ['/savant-player/475253'], ['/savant-player/448801'], ['/savant-player/592122'], ['/savant-player/434778'], ['/savant-player/553993'], ['/savant-player/489149'], ['/savant-player/621566'], ['/savant-player/543228'], ['/savant-player/476704'], ['/savant-player/461235'], ['/savant-player/543768'], ['/savant-player/624415'], ['/savant-player/435263'], ['/savant-player/446263'], ['/savant-player/429665'], ['/savant-player/543685'], ['/savant-player/458015'], ['/ ...

# %% [markdown]
# Building DataFrame:

# %%
savant_df = pd.DataFrame(final_stats, columns=columns)
num_cols = ['Age','G','PA','Year','Avg EV (MPH)','Avg LA (°)','Barrel%','Solid Contact %','Hard Hit %','Zone Swing %','Out of Zone Swing %','Pull %','Straight Away %','Oppo %','GB%','FB%','LD %','Sprint Speed']
savant_df[num_cols] = savant_df[num_cols].apply(pd.to_numeric, errors='coerce', axis=1)
savant_df.set_index(savant_df['Rk.'], inplace=True)
savant_df.drop(columns='Rk.',inplace=True)
savant_df['Player Link'] = final_link
savant_df.head()
# Out:
#                       Player    Year   Age     PA      G  Avg EV (MPH)  \
# Rk.
# 1     Saltalamacchia, Jarrod  2016.0  31.0  292.0   92.0          89.2
# 2              Schimpf, Ryan  2016.0  28.0  330.0   89.0          90.3
# 3                Gallo, Joey  2017.0  24.0  532.0  145.0          93.3
# 4            Carpenter, Matt  2018.0  33.0  677.0  156.0          90.7
# 5            Carpenter, Matt  2017.0  32.0  622.0  145.0          89.9
#
#      Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  Zone Swing %  \
# Rk.
# 1          21.4     11.6              6.8        35.4          65.7
# 2          29.7     16.7              8.0        41.4          64.7
# 3          23.0     22.1              8.3        52.2          72.7
# 4          21.6     13.7             11.5        44.7          57.1
# 5          22.7      8.2              8.4        37.7          55.1
#
#      Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# Rk.
# 1                   23.9    44.2             34.0    21.8  31.3  43.5  19.7
# 2                   23.4    41.4             33.9    24.7  20.1  42.0  21.8
# 3                   28.2    50.2             29.2    20.6  29.2  37.9  22.1
# 4                   18.5    47.6             30.7    21.7  28.3  37.8  28.5
# 5                   14.0    45.9             31.4    22.7  29.0  37.7  26.6
#
#      Sprint Speed              Player Link
# Rk.
# 1            25.6  [/savant-player/457454]
# 2            28.2  [/savant-player/572114]
# 3            27.8  [/savant-player/608336]
# 4            26.5  [/savant-player/572761]
# 5            26.6  [/savant-player/572761]

# %%
savant_df.Player.value_counts()
# Out:
#  Rizzo, Anthony      6
#  Escobar, Eduardo    6
#  Abreu, Jose         6
#  Sano, Miguel        6
#  Ramirez, Jose       6
#                     ..
#  White, Evan         1
#  Crisp, Coco         1
#  Butler, Joey        1
#  Munoz, Yairo        1
#  Slater, Austin      1
# Name: Player, Length: 646, dtype: int64

# %%
savant_df
# Out:
#                        Player    Year   Age     PA      G  Avg EV (MPH)  \
# Rk.
# 1      Saltalamacchia, Jarrod  2016.0  31.0  292.0   92.0          89.2
# 2               Schimpf, Ryan  2016.0  28.0  330.0   89.0          90.3
# 3                 Gallo, Joey  2017.0  24.0  532.0  145.0          93.3
# 4             Carpenter, Matt  2018.0  33.0  677.0  156.0          90.7
# 5             Carpenter, Matt  2017.0  32.0  622.0  145.0          89.9
# ...                       ...     ...   ...    ...    ...           ...
# 1889        Jankowski, Travis  2016.0  25.0  383.0  131.0          86.2
# 1890             LeMahieu, DJ  2016.0  28.0  635.0  146.0          91.7
# 1891        Jankowski, Travis  2018.0  27.0  387.0  117.0          85.6
# 1892           Slater, Austin  2018.0  26.0  225.0   74.0          87.3
# 1893        Yelich, Christian  2015.0  24.0  525.0  126.0          91.7
#
#       Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  Zone Swing %  \
# Rk.
# 1           21.4     11.6              6.8        35.4          65.7
# 2           29.7     16.7              8.0        41.4          64.7
# 3           23.0     22.1              8.3        52.2          72.7
# 4           21.6     13.7             11.5        44.7          57.1
# 5           22.7      8.2              8.4        37.7          55.1
# ...          ...      ...              ...         ...           ...
# 1889         0.8      1.3              1.3        26.9          56.9
# 1890         5.9      4.9              5.6        47.5          59.2
# 1891         3.3      0.7              1.1        19.3          59.2
# 1892         2.6      2.3              0.8        35.1          65.9
# 1893         0.0      4.8              5.6        45.1          63.7
#
#       Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# Rk.
# 1                    23.9    44.2             34.0    21.8  31.3  43.5  19.7
# 2                    23.4    41.4             33.9    24.7  20.1  42.0  21.8
# 3                    28.2    50.2             29.2    20.6  29.2  37.9  22.1
# 4                    18.5    47.6             30.7    21.7  28.3  37.8  28.5
# 5                    14.0    45.9             31.4    22.7  29.0  37.7  26.6
# ...                   ...     ...              ...     ...   ...   ...   ...
# 1889                 21.4    20.2             43.3    36.6  62.2  10.1  26.5
# 1890                 23.0    20.8             42.0    37.2  52.9  10.1  33.7
# 1891                 18.7    30.1             39.9    30.1  60.1  10.1  25.4
# 1892                 28.0    23.7             36.6    39.7  63.4   9.2  22.9
# 1893                 24.5    26.7             46.4    26.9  63.7   8.5  27.5
#
#       Sprint Speed              Player Link
# Rk.
# 1             25.6  [/savant-player/457454]
# 2             28.2  [/savant-player/572114]
# 3             27.8  [/savant-player/608336]
# 4             26.5  [/savant-player/572761]
# 5             26.6  [/savant-player/572761]
# ...            ...                      ...
# 1889          29.5  [/savant-player/608671]
# 1890          27.1  [/savant-player/518934]
# 1891          29.0  [/savant-player/608671]
# 1892          28.0  [/savant-player/596103]
# 1893          28.8  [/savant-player/592885]
#
# [1893 rows x 20 columns]

# %% [markdown]
# Driver's work here is done.

# %%
driver.close()

# %% [markdown]
# ### Use player links to pull position data from their individual BS page:

# %% [markdown]
# Making a list of players' names first, so i don't make duplicate links (for time's sake):

# %%
player_no_duplicate_df = pd.DataFrame(data=[savant_df['Player'],savant_df['Player Link']]).T

# %%
player_no_duplicate_df
# Out:
#                        Player              Player Link
# Rk.
# 1      Saltalamacchia, Jarrod  [/savant-player/457454]
# 2               Schimpf, Ryan  [/savant-player/572114]
# 3                 Gallo, Joey  [/savant-player/608336]
# 4             Carpenter, Matt  [/savant-player/572761]
# 5             Carpenter, Matt  [/savant-player/572761]
# ...                       ...                      ...
# 1889        Jankowski, Travis  [/savant-player/608671]
# 1890             LeMahieu, DJ  [/savant-player/518934]
# 1891        Jankowski, Travis  [/savant-player/608671]
# 1892           Slater, Austin  [/savant-player/596103]
# 1893        Yelich, Christian  [/savant-player/592885]
#
# [1893 rows x 2 columns]

# %% [markdown]
# *1893 rows match above dataframe, with only the two needed columns.*

# %% [markdown]
# Next step, remove duplicates from the player column, since their links point to the same page (removing work for the computer later)

# %%
player_no_duplicate_df.drop_duplicates(subset='Player', inplace=True)

# %%
player_no_duplicate_df
# Out:
#                        Player              Player Link
# Rk.
# 1      Saltalamacchia, Jarrod  [/savant-player/457454]
# 2               Schimpf, Ryan  [/savant-player/572114]
# 3                 Gallo, Joey  [/savant-player/608336]
# 4             Carpenter, Matt  [/savant-player/572761]
# 6                  Bruce, Jay  [/savant-player/457803]
# ...                       ...                      ...
# 1885            Venable, Will  [/savant-player/461416]
# 1886                Fuld, Sam  [/savant-player/453539]
# 1887          Schumaker, Skip  [/savant-player/435401]
# 1889        Jankowski, Travis  [/savant-player/608671]
# 1892           Slater, Austin  [/savant-player/596103]
#
# [646 rows x 2 columns]

# %% [markdown]
# Mission accomplished, down to only 646 rows!

# %% [markdown]
# Now, make a list of all the links to feed into a soup generator:

# %%
link_list = player_no_duplicate_df['Player Link'].to_list()

# %%
savant_page_list = [('https://baseballsavant.mlb.com' + str(link).strip("'[]")) for link in link_list]

# %%
print(savant_page_list)
# Out:
# ['https://baseballsavant.mlb.com/savant-player/457454', 'https://baseballsavant.mlb.com/savant-player/572114', 'https://baseballsavant.mlb.com/savant-player/608336', 'https://baseballsavant.mlb.com/savant-player/572761', 'https://baseballsavant.mlb.com/savant-player/457803', 'https://baseballsavant.mlb.com/savant-player/519346', 'https://baseballsavant.mlb.com/savant-player/656555', 'https://baseballsavant.mlb.com/savant-player/624415', 'https://baseballsavant.mlb.com/savant-player/595885', 'https://baseballsavant.mlb.com/savant-player/435063', 'https://baseballsavant.mlb.com/savant-player/545361', 'https://baseballsavant.mlb.com/savant-player/572122', 'https://baseballsavant.mlb.com/savant-player/641598', 'https://baseballsavant.mlb.com/savant-player/519390', 'https://baseballsavant.mlb.com/savant-player/474832', 'https://baseballsavant.mlb.com/savant-player/545350', 'https://baseballsavant.mlb.com/savant-player/455139', 'https://baseballsavant.mlb.com/savant-player/592206', 'https://baseballsavant.mlb.com/savant-player/594807', 'https://baseballsavant.mlb.com/savant-player/448801', 'https://baseballsavant.mlb.com/savant-player/593934', 'https://baseballsavant.mlb.com/savant-player/474892', 'https://baseballsavant.mlb.com/savant-player/457759', 'https://baseballsavant.mlb.com/savant-player/472528', 'https://baseballsavant.mlb.com/savant-player/446263', 'https://baseballsavant.mlb.com/savant-player/458675', 'https://baseballsavant.mlb.com/savant-player/571970', 'https://baseballsavant.mlb.com/savant-player/500871', 'https://baseballsavant.mlb.com/savant-player/663586', 'https://baseballsavant.mlb.com/savant-player/543768', 'https://baseballsavant.mlb.com/savant-player/592450', 'https://baseballsavant.mlb.com/savant-player/518692', 'https://baseballsavant.mlb.com/savant-player/461235', 'https://baseballsavant.mlb.com/savant-player/434158', 'https://baseballsavant.mlb.com/savant-player/458015', 'https://baseballsavant.mlb.com/savant-player/592669', 'https://baseballsavant.mlb.com/savant-player/501981', 'https://baseballsavant.mlb.com/savant-player/608596', 'https://baseballsavant.mlb.com/savant-player/621514', 'https://baseballsavant.mlb.com/savant-player/596142', 'https://baseballsavant.mlb.com/savant-player/666560', 'https://baseballsavant.mlb.com/savant-player/518614', 'https://baseballsavant.mlb.com/savant-player/571431', 'https://baseballsavant.mlb.com/savant-player/429667', 'https://baseballsavant.mlb.com/savant-player/594828', 'https://baseballsavant.mlb.com/savant-player/543685', 'https://baseballsavant.mlb.com/savant-player/502110', 'https://baseballsavant.mlb.com/savant-player/650402', 'https://baseballsavant.mlb.com/savant-player/571974', 'https://baseballsavant.mlb.com/savant-player/645277', 'https://baseballsavant.mlb.com/savant-player/606192', 'https://baseballsavant.mlb.com/savant-player/542583', 'https://baseballsavant.mlb.com/savant-player/656305', 'https://baseballsavant.mlb.com/savant-player/493316', 'https://baseballsavant.mlb.com/savant-player/444379', 'https://baseballsavant.mlb.com/savant-player/592200', 'https://baseballsavant.mlb.com/savant-player/605141', 'https://baseballsavant.mlb.com/savant-player/553993', 'https://baseballsavant.mlb.com/savant-player/664040', 'https://baseballsavant.mlb.com/savant-player/457477', 'https://baseballsavant.mlb.com/savant-player/656371', 'https://baseballsavant.mlb.com/savant-player/425784', 'https://baseballsavant.mlb.com/savant-player/606157', 'https://baseballsavant.mlb.com/savant-player/571875', 'https://baseballsavant.mlb.com/savant-player/592178', 'https://baseballsavant.mlb.com/savant-player/608070', 'https://baseballsavant.mlb.com/savant-player/572287', 'https://baseballsavant.mlb.com/savant-player/571602', 'https://baseballsavant.mlb.com/savant-player/571745', 'https://baseballsavant.mlb.com/savant-player/488771', 'https://baseballsavant.mlb.com/savant-player/429665', 'https://baseballsavant.mlb.com/savant-player/572816', 'https://baseballsavant.mlb.com/savant- ...

# %%
#Running the len just to audit/sanity check:
len(savant_page_list)
# Out:
# 646

# %% [markdown]
# Defining a Function to generate the soup objects:

# %%
def Soup_Generator(link_list):
    '''
    Takes in a list of players and returns Beautiful Soup objects.
    '''
    response_list = [requests.get(url) for url in link_list]
    soup_list = []
    for response in response_list:
        page = response.text
        soup_list.append(BeautifulSoup(page,'html'))
    return soup_list

# %% [markdown]
# Find Player Position Data:

# %%
link_soup = Soup_Generator(savant_page_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-5c3033ef9946> in <module>
# ----> 1 link_soup = Soup_Generator(savant_page_list)
#
# <ipython-input-36-422636003b11> in Soup_Generator(link_list)
#       3     Takes in a list of players and returns Beautiful Soup objects.
#       4     '''
# ----> 5     response_list = [requests.get(url) for url in link_list]
#       6     soup_list = []
#       7     for response in response_list:
#
# <ipython-input-36-422636003b11> in <listcomp>(.0)
#       3     Takes in a list of players and returns Beautiful Soup objects.
#       4     '''
# ----> 5     response_list = [requests.get(url) for url in link_list]
#       6     soup_list = []
#       7     for response in response_list:
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
position_list = []
for player in link_soup:
    position = player.find('div', style='font-size: .8rem;')
    position_list.append(str(position.text))

# %%
print(position_list)

# %%
final_position = []
for position in position_list:
    position = position.strip("\n")
    position = position.strip(" ")
    final_position.append(position[0:2].strip(" "))
print(final_position)

# %% [markdown]
# Defining function for position generation:

# %%
def Position_Puller(soup_list):
    '''
    Takes in a list of Beautiful Soup Objects from BasebalL Savant
    and returns each player's position.
    '''
    position_list = []
    for player in soup_list:
        position = player.find('div', style='font-size: .8rem;')
        position_list.append(str(position.text))
    final_position = []
    for position in position_list:
        position = position.strip("\n")
        position = position.strip(" ")
        final_position.append(position[0:2].strip(" "))
    return final_position

# %%
link_soup = Soup_Generator(savant_page_list[0:20])

# %%
#Verify first 20:
Position_Puller(link_soup)
# Out:
# ['C',
#  '3B',
#  'CF',
#  '3B',
#  '3B',
#  'RF',
#  'CF',
#  '1B',
#  '1B',
#  '2B',
#  'CF',
#  '1B',
#  '1B',
#  'CF',
#  '3B',
#  'C',
#  '1B',
#  'C',
#  'RF',
#  'CF']

# %% [markdown]
# ### Trying to Merge FanGraphs wRC+ (target stat) data with above dataframe:

# %% [markdown]
# Link to use:
# https://www.fangraphs.com/leaders/season-stat-grid?position=B&seasonStart=2015&seasonEnd=2020&stat=wRC%2B&pastMinPt=200&curMinPt=0&mode=normal

# %% [markdown]
# Importing all functions from my fangraphs_wrc_code.py file:

# %%
from fangraphs_wrc_code import *

# %%
fg_url = 'https://www.fangraphs.com/leaders/season-stat-grid?position=B&seasonStart=2015&seasonEnd=2020&stat=wRC%2B&pastMinPt=200&curMinPt=0&mode=normal'

# %% [markdown]
# Using the wRC_DataFrame_shifter function to pull the wRC+ dataframe from the URL above:

# %%
wrc_df = wRC_DataFrame_Shifter(fg_url)

# %% [markdown]
# Spitting out a sample of 15 to make sure everything is working:

# %%
wrc_df.sample(15)
# Out:
#                   Name-Year wRC+
# 2840   Ildemaro Vargas-2017    0
# 199   Mike Yastrzemski-2016    0
# 2721     Daniel Murphy-2018  110
# 4980        Seth Smith-2015  113
# 325      Clint Frazier-2016    0
# 2177     Lewis Brinson-2020   73
# 1618         Ben Gamel-2019   87
# 4062       Jonny Gomes-2015   84
# 1454      Luis Torrens-2017    0
# 2997    Logan Forsythe-2018   71
# 344       Mookie Betts-2017  107
# 4109   Shane Victorino-2020    0
# 1438        Nick Ahmed-2019   91
# 4012         Alex Rios-2019    0
# 4662    Tyler Saladino-2015   64

# %% [markdown]
# It's here!  Next Step: need to use name-year as an ID to match with the baseball savant dataframe

# %% [markdown]
# Renaming column for later merging:

# %%
wrc_df.rename(columns={'Name-Year':'Player_Year_ID'}, inplace=True)

# %%
wrc_df.head(2)
# Out:
#           Player_Year_ID wRC+
# 0  Michael Lorenzen-2015    0
# 1  Michael Lorenzen-2016    0

# %% [markdown]
# ## Merging Baseball Savant and FanGraphs Data:

# %% [markdown]
# Reminding myself how the savant dataframe looks:

# %%
savant_df.head()
# Out:
#                       Player    Year   Age     PA      G  Avg EV (MPH)  \
# Rk.
# 1     Saltalamacchia, Jarrod  2016.0  31.0  292.0   92.0          89.2
# 2              Schimpf, Ryan  2016.0  28.0  330.0   89.0          90.3
# 3                Gallo, Joey  2017.0  24.0  532.0  145.0          93.3
# 4            Carpenter, Matt  2018.0  33.0  677.0  156.0          90.7
# 5            Carpenter, Matt  2017.0  32.0  622.0  145.0          89.9
#
#      Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  Zone Swing %  \
# Rk.
# 1          21.4     11.6              6.8        35.4          65.7
# 2          29.7     16.7              8.0        41.4          64.7
# 3          23.0     22.1              8.3        52.2          72.7
# 4          21.6     13.7             11.5        44.7          57.1
# 5          22.7      8.2              8.4        37.7          55.1
#
#      Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# Rk.
# 1                   23.9    44.2             34.0    21.8  31.3  43.5  19.7
# 2                   23.4    41.4             33.9    24.7  20.1  42.0  21.8
# 3                   28.2    50.2             29.2    20.6  29.2  37.9  22.1
# 4                   18.5    47.6             30.7    21.7  28.3  37.8  28.5
# 5                   14.0    45.9             31.4    22.7  29.0  37.7  26.6
#
#      Sprint Speed              Player Link
# Rk.
# 1            25.6  [/savant-player/457454]
# 2            28.2  [/savant-player/572114]
# 3            27.8  [/savant-player/608336]
# 4            26.5  [/savant-player/572761]
# 5            26.6  [/savant-player/572761]

# %% [markdown]
# First, handling player names:

# %%
player_list = savant_df.Player.tolist()

# %%
player_list_split = [player.split(', ') for player in player_list]
for player in player_list_split:
    player[0] = player[0].strip()

final_player_list = [(player[1] + ' ' + player[0]) for player in player_list_split]

# %% [markdown]
# Verify:

# %%
print(final_player_list)
# Out:
# ['Jarrod Saltalamacchia', 'Ryan Schimpf', 'Joey Gallo', 'Matt Carpenter', 'Matt Carpenter', 'Jay Bruce', 'Joey Gallo', 'Eric Thames', 'Rhys Hoskins', 'Cavan Biggio', 'Greg Bird', 'Joey Gallo', 'Mike Napoli', 'Mike Trout', 'Kyle Seager', 'Mitch Garver', 'Eric Thames', 'Stephen Vogt', 'Jay Bruce', 'Brandon Belt', 'Jake Marisnick', 'Robinson Chirinos', 'Nick Castellanos', 'Matt Carpenter', 'Adam Duvall', 'Mike Trout', 'Chris Davis', 'Rhys Hoskins', 'Miguel Sano', 'Chris Carter', 'Adam Duvall', 'Robinson Chirinos', 'Justin Turner', 'Matt Carpenter', 'Luis Valbuena', 'Lucas Duda', 'Rhys Hoskins', 'Colby Rasmus', 'Chris Carter', 'Max Muncy', 'Kyle Seager', 'Eduardo Escobar', 'Brandon Belt', 'Mike Trout', 'Austin Riley', 'Travis Shaw', 'Miguel Sano', 'Aaron Judge', 'Freddie Freeman', 'Brandon Moss', 'Colby Rasmus', 'Curtis Granderson', 'Joey Votto', 'Luis Valbuena', 'Jay Bruce',
avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  ...  \
# Rk.                                                     ...
# 210         21.0      8.9              5.6        32.7  ...
# 367         15.7      3.9              7.1        26.1  ...
# 1286        10.5      9.4              6.0        40.4  ...
# 148         15.3      6.9              5.7        38.2  ...
# 583         12.7      7.3              5.5        40.9  ...
# 1698         9.4      2.4              3.9        25.2  ...
# 1474         7.8      4.5              6.2        30.8  ...
# 1658         6.9      7.1              8.7        39.3  ...
# 209         18.2      3.9              6.8        35.0  ...
# 1550         9.8      3.0              5.2        34.7  ...
# 1609         9.4      3.9              7.8        35.9  ...
# 1314         9.2      2.4              4.0        34.3  ...
# 1010        10.6      2.1              3.5        21.5  ...
# 968         12.4      3.6              3.9        27.6  ...
# 705         14.0      4.8              7.7        37.4  ...
#
#       Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# Rk.
# 210                  31.4    42.8             31.5    25.7  33.4  29.0  24.3
# 367                  36.0    41.3             32.9    25.8  39.2  26.9  26.5
# 1286                 24.2    33.4             38.6    28.0  46.6  19.7  31.1
# 148                  18.5    35.3             39.5    25.2  37.8  30.1  28.9
# 583                  14.5    43.3             36.0    20.7  45.7  25.0  23.2
# 1698                 34.9    31.1             43.2    25.7  52.4  16.0  21.8
# 1474                 35.2    38.0             32.5    29.5  50.3  18.2  25.3
# 1658                 26.6    26.8             44.5    28.7  50.4  16.5  29.9
# 209                  33.7    47.7             33.9    18.4  36.5  29.0  24.8
# 1550                 41.4    33.0             35.2    31.8  49.8  17.6  26.2
# 1609                 37.8    39.9             32.7    27.5  48.4  17.0  29.4
# 1314                 25.9    24.7             39.0    36.3  47.8  19.5  22.3
# 1010                 31.3    35.9             38.5    25.5  48.5  21.7  24.1
# 968                  37.7    32.0             39.9    28.1  43.4  22.1  26.7
# 705                  30.5    37.0             38.5    24.5  42.6  24.0  27.2
#
#       Sprint Speed              Player Link           Player_Year_ID
# Rk.
# 210           27.7  [/savant-player/594807]         Adam Duvall-2017
# 367           27.1  [/savant-player/543281]       Josh Harrison-2018
# 1286          27.2  [/savant-player/570267]     Domingo Santana-2017
# 148           25.0  [/savant-player/458015]          Joey Votto-2019
# 583           28.8  [/savant-player/457705]    Andrew McCutchen-2019
# 1698          29.5  [/savant-player/621006]       Richie Martin-2019
# 1474          27.2  [/savant-player/150212]     Michael Cuddyer-2015
# 1658          26.2  [/savant-player/500874]       Jose Martinez-2019
# 209           25.6  [/savant-player/435559]         Kurt Suzuki-2018
# 1550          28.0  [/savant-player/588751]  Adeiny Hechavarria-2017
# 1609          25.1  [/savant-player/408047]      Justin Morneau-2016
# 1314          26.1  [/savant-player/553869]          Elias Diaz-2019
# 1010          27.6  [/savant-player/444876]     Alcides Escobar-2018
# 968           28.3  [/savant-player/572008]        Chris Owings-2017
# 705           26.3  [/savant-player/435522]         Neil Walker-2015
#
# [15 rows x 21 columns]

# %% [markdown]
# Perfect!  They all match in the random 15 line item sample.  Final step: loading the wRC+ data into the same dataframe.

# %%
combined_df = savant_df.merge(wrc_df, how='left', on='Player_Year_ID')

# %%
combined_df
# Out:
#                        Player    Year   Age     PA      G  Avg EV (MPH)  \
# 0      Saltalamacchia, Jarrod  2016.0  31.0  292.0   92.0          89.2
# 1               Schimpf, Ryan  2016.0  28.0  330.0   89.0          90.3
# 2                 Gallo, Joey  2017.0  24.0  532.0  145.0          93.3
# 3             Carpenter, Matt  2018.0  33.0  677.0  156.0          90.7
# 4             Carpenter, Matt  2017.0  32.0  622.0  145.0          89.9
# ...                       ...     ...   ...    ...    ...           ...
# 1888        Jankowski, Travis  2016.0  25.0  383.0  131.0          86.2
# 1889             LeMahieu, DJ  2016.0  28.0  635.0  146.0          91.7
# 1890        Jankowski, Travis  2018.0  27.0  387.0  117.0          85.6
# 1891           Slater, Austin  2018.0  26.0  225.0   74.0          87.3
# 1892        Yelich, Christian  2015.0  24.0  525.0  126.0          91.7
#
#       Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  ...  Pull %  \
# 0           21.4     11.6              6.8        35.4  ...    44.2
# 1           29.7     16.7              8.0        41.4  ...    41.4
# 2           23.0     22.1              8.3        52.2  ...    50.2
# 3           21.6     13.7             11.5        44.7  ...    47.6
# 4           22.7      8.2              8.4        37.7  ...    45.9
# ...          ...      ...              ...         ...  ...     ...
# 1888         0.8      1.3              1.3        26.9  ...    20.2
# 1889         5.9      4.9              5.6        47.5  ...    20.8
# 1890         3.3      0.7              1.1        19.3  ...    30.1
# 1891         2.6      2.3              0.8        35.1  ...    23.7
# 1892         0.0      4.8              5.6        45.1  ...    26.7
#
#       Straight Away %  Oppo %   GB%   FB%  LD %  Sprint Speed  \
# 0                34.0    21.8  31.3  43.5  19.7          25.6
# 1                33.9    24.7  20.1  42.0  21.8          28.2
# 2                29.2    20.6  29.2  37.9  22.1          27.8
# 3                30.7    21.7  28.3  37.8  28.5          26.5
# 4                31.4    22.7  29.0  37.7  26.6          26.6
# ...               ...     ...   ...   ...   ...           ...
# 1888             43.3    36.6  62.2  10.1  26.5          29.5
# 1889             42.0    37.2  52.9  10.1  33.7          27.1
# 1890             39.9    30.1  60.1  10.1  25.4          29.0
# 1891             36.6    39.7  63.4   9.2  22.9          28.0
# 1892             46.4    26.9  63.7   8.5  27.5          28.8
#
#                   Player Link              Player_Year_ID wRC+
# 0     [/savant-player/457454]  Jarrod Saltalamacchia-2016   70
# 1     [/savant-player/572114]           Ryan Schimpf-2016  128
# 2     [/savant-player/608336]             Joey Gallo-2017  119
# 3     [/savant-player/572761]         Matt Carpenter-2018  140
# 4     [/savant-player/572761]         Matt Carpenter-2017  124
# ...                       ...                         ...  ...
# 1888  [/savant-player/608671]       Travis Jankowski-2016   81
# 1889  [/savant-player/518934]            DJ LeMahieu-2016  130
# 1890  [/savant-player/608671]       Travis Jankowski-2018   90
# 1891  [/savant-player/596103]          Austin Slater-2018   81
# 1892  [/savant-player/592885]       Christian Yelich-2015  120
#
# [1893 rows x 22 columns]

# %%
savant_df
# Out:
#                        Player    Year   Age     PA      G  Avg EV (MPH)  \
# Rk.
# 1      Saltalamacchia, Jarrod  2016.0  31.0  292.0   92.0          89.2
# 2               Schimpf, Ryan  2016.0  28.0  330.0   89.0          90.3
# 3                 Gallo, Joey  2017.0  24.0  532.0  145.0          93.3
# 4             Carpenter, Matt  2018.0  33.0  677.0  156.0          90.7
# 5             Carpenter, Matt  2017.0  32.0  622.0  145.0          89.9
# ...                       ...     ...   ...    ...    ...           ...
# 1889        Jankowski, Travis  2016.0  25.0  383.0  131.0          86.2
# 1890             LeMahieu, DJ  2016.0  28.0  635.0  146.0          91.7
# 1891        Jankowski, Travis  2018.0  27.0  387.0  117.0          85.6
# 1892           Slater, Austin  2018.0  26.0  225.0   74.0          87.3
# 1893        Yelich, Christian  2015.0  24.0  525.0  126.0          91.7
#
#       Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  ...  \
# Rk.                                                     ...
# 1           21.4     11.6              6.8        35.4  ...
# 2           29.7     16.7              8.0        41.4  ...
# 3           23.0     22.1              8.3        52.2  ...
# 4           21.6     13.7             11.5        44.7  ...
# 5           22.7      8.2              8.4        37.7  ...
# ...          ...      ...              ...         ...  ...
# 1889         0.8      1.3              1.3        26.9  ...
# 1890         5.9      4.9              5.6        47.5  ...
# 1891         3.3      0.7              1.1        19.3  ...
# 1892         2.6      2.3              0.8        35.1  ...
# 1893         0.0      4.8              5.6        45.1  ...
#
#       Out of Zone Swing %  Pull %  Straight Away %  Oppo %   GB%   FB%  LD %  \
# Rk.
# 1                    23.9    44.2             34.0    21.8  31.3  43.5  19.7
# 2                    23.4    41.4             33.9    24.7  20.1  42.0  21.8
# 3                    28.2    50.2             29.2    20.6  29.2  37.9  22.1
# 4                    18.5    47.6             30.7    21.7  28.3  37.8  28.5
# 5                    14.0    45.9             31.4    22.7  29.0  37.7  26.6
# ...                   ...     ...              ...     ...   ...   ...   ...
# 1889                 21.4    20.2             43.3    36.6  62.2  10.1  26.5
# 1890                 23.0    20.8             42.0    37.2  52.9  10.1  33.7
# 1891                 18.7    30.1             39.9    30.1  60.1  10.1  25.4
# 1892                 28.0    23.7             36.6    39.7  63.4   9.2  22.9
# 1893                 24.5    26.7             46.4    26.9  63.7   8.5  27.5
#
#       Sprint Speed              Player Link              Player_Year_ID
# Rk.
# 1             25.6  [/savant-player/457454]  Jarrod Saltalamacchia-2016
# 2             28.2  [/savant-player/572114]           Ryan Schimpf-2016
# 3             27.8  [/savant-player/608336]             Joey Gallo-2017
# 4             26.5  [/savant-player/572761]         Matt Carpenter-2018
# 5             26.6  [/savant-player/572761]         Matt Carpenter-2017
# ...            ...                      ...                         ...
# 1889          29.5  [/savant-player/608671]       Travis Jankowski-2016
# 1890          27.1  [/savant-player/518934]            DJ LeMahieu-2016
# 1891          29.0  [/savant-player/608671]       Travis Jankowski-2018
# 1892          28.0  [/savant-player/596103]          Austin Slater-2018
# 1893          28.8  [/savant-player/592885]       Christian Yelich-2015
#
# [1893 rows x 21 columns]

# %% [markdown]
# Same number of rows with the added column!  Join is complete.

# %% [markdown]
# ### Now, initial exploring of combined dataframe:

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1893 entries, 0 to 1892
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player               1893 non-null   object
#  1   Year                 1893 non-null   float64
#  2   Age                  1893 non-null   float64
#  3   PA                   1893 non-null   float64
#  4   G                    1893 non-null   float64
#  5   Avg EV (MPH)         1893 non-null   float64
#  6   Avg LA (°)           1893 non-null   float64
#  7   Barrel%              1893 non-null   float64
#  8   Solid Contact %      1893 non-null   float64
#  9   Hard Hit %           1893 non-null   float64
#  10  Zone Swing %         1893 non-null   float64
#  11  Out of Zone Swing %  1893 non-null   float64
#  12  Pull %               1893 non-null   float64
#  13  Straight Away %      1893 non-null   float64
#  14  Oppo %               1893 non-null   float64
#  15  GB%                  1893 non-null   float64
#  16  FB%                  1893 non-null   float64
#  17  LD %                 1893 non-null   float64
#  18  Sprint Speed         1893 non-null   float64
#  19  Player Link          1893 non-null   object
#  20  Player_Year_ID       1893 non-null   object
#  21  wRC+                 1675 non-null   object
# dtypes: float64(18), object(4)
# memory usage: 340.1+ KB

# %% [markdown]
# Good news: no null values, besides wRC+.  Bad news: over 200 Null data points in wRC+... let's see why that is

# %%
print(combined_df[combined_df['wRC+'].isnull()])
# Out:
#                    Player    Year   Age     PA      G  Avg EV (MPH)  \
# 28           Sano, Miguel  2018.0  25.0  299.0   71.0          90.3
# 46           Sano, Miguel  2016.0  23.0  495.0  116.0          92.4
# 59          Sanchez, Gary  2019.0  27.0  446.0  106.0          91.2
# 65           Sano, Miguel  2019.0  26.0  439.0  105.0          94.4
# 75     Hernandez, Teoscar  2019.0  27.0  464.0  125.0          91.2
# ...                   ...     ...   ...    ...    ...           ...
# 1845       Nunez, Eduardo  2015.0  28.0  204.0   72.0          88.7
# 1854        Garcia, Leury  2018.0  27.0  275.0   82.0          88.0
# 1858       Blanco, Andres  2016.0  32.0  209.0   90.0          88.5
# 1874       Iglesias, Jose  2015.0  25.0  454.0  120.0          83.8
# 1879       Tomas, Yasmany  2015.0  25.0  426.0  118.0          89.3
#
#       Avg LA (°)  Barrel%  Solid Contact %  Hard Hit %  ...  Pull %  \
# 28          12.6     11.1              8.5        44.8  ...    37.3
# 46          16.9     14.1              8.8        49.2  ...    32.4
# 59          19.0     19.1              4.4        42.3  ...    47.8
# 65          15.9     21.2              6.3        57.2  ...    52.7
# 75          15.3     11.7             10.6        42.3  ...    42.6
# ...          ...      ...              ...         ...  ...     ...
# 1845         2.7      2.5              3.1        31.5  ...    34.6
# 1854         6.9      2.6              4.6        31.6  ...    27.8
# 1858         6.4      2.0              6.0        34.7  ...    34.7
# 1874         4.6      0.0              1.3        19.0  ...    33.0
# 1879         4.9      4.0              6.1        38.0  ...    31.3
#
#       Straight Away %  Oppo %   GB%   FB%  LD %  Sprint Speed  \
# 28               35.3    27.5  43.8  34.6  16.3          26.8
# 46               45.0    22.5  35.5  33.2  24.8          27.8
# 59               31.3    21.0  32.4  32.7  22.8          25.5
# 65               32.4    14.9  36.0  32.4  22.5          26.5
# 75               35.1    22.3  38.9  32.1  20.4          29.1
# ...               ...     ...   ...   ...   ...           ...
# 1845             36.4    29.0  59.3  13.0  21.0          28.6
# 1854             41.2    30.9  52.1  12.9  32.0          28.6
# 1858             40.0    25.3  52.0  12.7  28.7          26.4
# 1874             38.8    28.2  59.1  11.6  21.9          28.4
# 1879             39.4    29.3  56.6  11.1  30.3          27.3
#
#                   Player Link          Player_Year_ID wRC+
# 28    [/savant-player/593934]        Miguel Sano-2018  NaN
# 46    [/savant-player/593934]        Miguel Sano-2016  NaN
# 59    [/savant-player/596142]       Gary Sanchez-2019  NaN
# 65    [/savant-player/593934]        Miguel Sano-2019  NaN
# 75    [/savant-player/606192]  Teoscar Hernandez-2019  NaN
# ...                       ...                     ...  ...
# 1845  [/savant-player/456488]      Eduardo Nunez-2015  NaN
# 1854  [/savant-player/544725]       Leury Garcia-2018  NaN
# 1858  [/savant-player/433217]      Andres Blanco-2016  NaN
# 1874  [/savant-player/578428]      Jose Iglesias-2015  NaN
# 1879  [/savant-player/630111]      Yasmany Tomas-2015  NaN
#
# [218 rows x 22 columns]

# %% [markdown]
# Ah... Accent marks in the name (i.e. Miguel Sano should be Sanó, Gary Sanchez should be Sánchez, Teoscar Hernandez should be Hernández, Yasmany Tomas should be Tomás, etc.).  Let's see how many different players have null values:

# %%
players_to_fix = combined_df.Player[combined_df['wRC+'].isnull()].drop_duplicates()

# %%
players_to_fix.to_list()
# Out:
# [' Sano, Miguel',
#  ' Sanchez, Gary',
#  ' Hernandez, Teoscar',
#  ' Aguilar, Jesus',
#  ' Cespedes, Yoenis',
#  ' Suarez, Eugenio',
#  ' Diaz, Isan',
#  ' Rivera, Rene',
#  ' Ramirez, Jose',
#  ' Encarnacion, Edwin',
#  ' Acuna Jr., Ronald',
#  ' Pina, Manny',
#  ' Gomez, Carlos',
#  ' Narvaez, Omar',
#  ' Hechavarria, Adeiny',
#  ' Cabrera, Asdrubal',
#  ' Bautista, Jose',
#  ' Nunez, Renato',
#  ' Hernandez, Enrique',
#  ' Laureano, Ramon',
#  ' Moncada, Yoan',
#  ' Rodriguez, Ronny',
#  ' Leon, Sandy',
#  ' Beltran, Carlos',
#  ' Mejia, Francisco',
#  ' Diaz, Aledmys',
#  ' Peraza, Jose',
#  ' Beltre, Adrian',
#  ' Maldonado, Martin',
#  ' Vazquez, Christian',
#  ' Gonzalez, Adrian',
#  ' Perez, Roberto',
#  ' Garcia, Avisail',
#  ' Urias, Luis',
#  ' Guzman, Ronald',
#  ' Perez, Hernan',
#  ' Jimenez, Eloy',
#  ' Osuna, Jose',
#  ' Pagan, Angel',
#  ' Reyes, Jose',
#  ' Andujar, Miguel',
#  ' Sanchez, Yolmer',
#  ' Baez, Javier',
#  ' Perez, Carlos',
#  ' Martinez, Jose',
#  ' Gonzalez, Carlos',
#  ' Diaz, Elias',
#  ' Herrera, Odubel',
#  ' Rodriguez, Sean',
#  ' Tejada, Ruben',
#  ' Cano, Robinson',
#  ' Abreu, Jose',
#  ' Blanco, Gregor',
#  ' Nunez, Eduardo',
#  ' Hernandez, Gorkys',
#  ' Alvarez, Pedro',
#  ' Tomas, Yasmany',
#  ' Prado, Martin',
#  ' Blanco, Andres',
#  ' Cordoba, Allen',
#  ' Diaz, Yandy',
#  ' Iglesias, Jose',
#  ' Munoz, Yairo',
#  ' Garcia, Leury',
#  ' Pena, Brayan',
#  ' De Jesus Jr., Ivan',
#  ' Garcia, Adonis',
#  ' Flores, Ramon']

# %%
len(players_to_fix)
# Out:
# 68

# %% [markdown]
# OK, 68 players to fix...

# %% [markdown]
# ### **Next step:** is there a better way to do this besides brute force?
